# %% [markdown]
# # MODEL 3: GRU solution

# %% [markdown]
# In this exercise, we are asked to build a `Seq2Vec` model using at least one nn.LSTM() layer. Using the values of a set of features at timepoints $t-k$ through $t-1$, we are asked to predict the following targets at timepoint $t$:
#
# - `p(mbar)`, atmospheric pressure
# - `T (degC)`, air temperature
# - `rh (%)`, relative humidity
# - `wv(m/s)`, wind velocity
#
# For simplicity, we will first initialize this model at  $k=4$. Then, once we get that model working, we will set  `k`  as a hyperparameter and iterate through `{4, 6, 8}`, along with two learning rate values `{0.01, 0.001}` and batch size `{32, 64}` .

# %%
# First we will import the necessary dependencies
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
import torchmetrics
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms
from torch.utils.data import SubsetRandomSampler
import pytorch_lightning as L
import torch.utils.data
import datetime

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

# %%
# We can check the current working directory
import os
print(os.getcwd())

# We determine whether CUDA is available 
if torch.cuda.is_available():
    device = torch.device("cuda")
    print (f"Using GPU: {torch.cuda.get_device_name(device)}")
else: 
    device = torch.device("cpu")
    print (f"Using CPU")

# We empty the cuda cache for good measure and make sure both the cache and the RAM are at zero
torch.cuda.empty_cache()
print(f"CUDA cache used: {torch.cuda.memory_reserved() / 1e6:.1f} MB")
print(f"CUDA RAM used: {torch.cuda.memory_allocated() / 1e6:.1f} MB")
# Out:
# C:\Users\usuario\RecogniChess
# Using GPU: NVIDIA GeForce GTX 960M
# CUDA cache used: 0.0 MB
# CUDA RAM used: 0.0 MB

# %%
############################# 
### HYPERPARAMETER TUNING CELL ###
#############################

dir_path = r'C:\Users\usuario\RecogniChess\HW4\Snapshots\GRU\BEST'

# Tweak the value of these HPs when re-running the model
lookback = 8
batch_size = 64
lr = 0.002

# %% [markdown]
# Before we do anything else, we will import the data and take a look at it:

# %%
# We import the training data
df = pd.read_csv(r"C:\Users\usuario\RecogniChess\HW4\weather_train.csv", header=0, parse_dates=[0])
print(df.shape)
# Out:
# (56072, 15)

# %%
df.dropna(inplace=True)
print(df.shape)
# Out:
# (56072, 15)

# %%
# First, we will turn the first column into a Pandas datetime object
df['Date Time'] = pd.to_datetime(df['Date Time'])

# %%
# Let's take a look
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.14          0.19       1.96             3.15
# 1          3.12          2.90          0.21       1.81             2.91
# 2          3.13          2.93          0.20       1.83             2.94
# 3          3.07          2.85          0.23       1.78             2.85
# 4          2.94          2.71          0.23       1.69             2.71
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.86      0.21           0.63     192.7
# 1       1312.25      0.25           0.63     190.3
# 2       1312.18      0.18           0.63     167.2
# 3       1313.61      0.10           0.38     240.0
# 4       1317.19      0.40           0.88     157.0

# %%
df = df.drop(columns=["sh (g/kg)", "H2OC (mmol/mol)", "rho (g/m**3)"])
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0          3.33          3.14          0.19      0.21           0.63     192.7
# 1          3.12          2.90          0.21      0.25           0.63     190.3
# 2          3.13          2.93          0.20      0.18           0.63     167.2
# 3          3.07          2.85          0.23      0.10           0.38     240.0
# 4          2.94          2.71          0.23      0.40           0.88     157.0

# %% [markdown]
# Data looks good, but we need to apply a couple of changes:
# - First, we need to separate out the first column, which doesn't hold feature values but rather keeps time
# - Second, we seriously need to minmax scale the other columns because they're on vastly different scales right now.

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rh (%)', 'wv (m/s)']
plot_features = df[plot_cols]
plot_features.index = df['Date Time']
_ = plot_features.plot(subplots=True)

plot_features = df[plot_cols][:500]
plot_features.index = pd.DatetimeIndex(df['Date Time'][:500])
_ = plot_features.plot(subplots=True)

# %% [markdown]
# Data looks good except fo values after 2015, where there is clearly an anomaly.

# %%
# Let's investigate deeper
df.describe().transpose()
# Out:
#                  count        mean        std     min       25%      50%  \
# p (mbar)       56072.0  988.832928   8.350194  913.60  983.8100  989.240
# T (degC)       56072.0    8.987746   8.440986  -22.76    2.8800    8.970
# Tpot (K)       56072.0  283.059875   8.518036  250.85  277.0000  283.100
# Tdew (degC)    56072.0    4.551409   6.830787  -24.80   -0.1200    4.745
# rh (%)         56072.0   76.208224  16.498261   13.88   65.4975   79.500
# VPmax (mbar)   56072.0   13.170791   7.479040    0.97    7.5200   11.470
# VPact (mbar)   56072.0    9.297106   4.150333    0.81    6.0500    8.575
# VPdef (mbar)   56072.0    3.873606   4.673326    0.00    0.8200    2.090
# wv (m/s)       56072.0    2.149853   1.542047    0.00    1.0100    1.790
# max. wv (m/s)  56072.0    3.558251   2.337514    0.00    1.8000    3.000
# wd (deg)       56072.0  174.029077  87.062724    0.00  123.4000  197.400
#
#                     75%      max
# p (mbar)       994.3100  1013.91
# T (degC)        15.0700    35.65
# Tpot (K)       289.1300   309.73
# Tdew (degC)      9.7325    23.06
# rh (%)          89.6000   100.00
# VPmax (mbar)    17.1600    58.34
# VPact (mbar)    12.0800    28.25
# VPdef (mbar)     5.1000    41.78
# wv (m/s)         2.8900    14.01
# max. wv (m/s)    4.7600    23.50
# wd (deg)       233.9000   360.00

# %%
# We need to preprocess the variables that are expressed in radians

wv = df.pop('wv (m/s)')
max_wv = df.pop('max. wv (m/s)')

# Convert to radians.
wd_rad = df.pop('wd (deg)')*np.pi / 180

# Calculate the wind x and y components.
df['Wx'] = wv*np.cos(wd_rad)
df['Wy'] = wv*np.sin(wd_rad)

# Calculate the max wind x and y components.
df['max Wx'] = max_wv*np.cos(wd_rad)
df['max Wy'] = max_wv*np.sin(wd_rad)

# %%
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0          3.33          3.14          0.19 -0.204862 -0.046168 -0.614587
# 1          3.12          2.90          0.21 -0.245971 -0.044701 -0.619848
# 2          3.13          2.93          0.20 -0.175527  0.039879 -0.614344
# 3          3.07          2.85          0.23 -0.050000 -0.086603 -0.190000
# 4          2.94          2.71          0.23 -0.368202  0.156292 -0.810044
#
#      max Wy
# 0 -0.138503
# 1 -0.112645
# 2  0.139576
# 3 -0.329090
# 4  0.343843

# %%
timestamp_s = df['Date Time'].map(pd.Timestamp.timestamp)

# %%
day = 24*60*60
year = (365.2425)*day

df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %%
plt.plot(np.array(df['Day sin'])[:25])
plt.plot(np.array(df['Day cos'])[:25])
plt.xlabel('Time [h]')
plt.title('Time of day signal')
# Out:
# Text(0.5, 1.0, 'Time of day signal')

# %%
plt.plot(np.array(df['Year sin'])[:365])
plt.plot(np.array(df['Year cos'])[:365])
plt.xlabel('Time [d]')
plt.title('Time of year signal')
# Out:
# Text(0.5, 1.0, 'Time of year signal')

# %%
df.tail()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 56067 2015-05-24 14:00:00    991.94     17.16    290.99         9.83   62.00
# 56068 2015-05-24 15:00:00    991.52     17.77    291.64         9.29   57.52
# 56069 2015-05-24 16:00:00    990.96     19.40    293.32         9.07   51.17
# 56070 2015-05-24 17:00:00    990.56     19.03    292.98         9.04   52.25
# 56071 2015-05-24 18:00:00    990.23     18.46    292.44         8.97   53.89
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 56067         19.60         12.15          7.45  2.520849  1.626445  3.865301
# 56068         20.37         11.72          8.66 -0.143727  0.868184 -0.372383
# 56069         22.56         11.55         11.02 -0.495154  0.373125 -1.086144
# 56070         22.05         11.52         10.53 -0.755076 -0.232292 -1.299879
# 56071         21.28         11.47          9.81  0.724710  0.840771  1.710577
#
#          max Wy   Day sin       Day cos  Year sin  Year cos
# 56067  2.493882 -0.500000 -8.660254e-01  0.621029 -0.783787
# 56068  2.249385 -0.707107 -7.071068e-01  0.620467 -0.784232
# 56069  0.818468 -0.866025 -5.000000e-01  0.619905 -0.784677
# 56070 -0.399895 -0.965926 -2.588190e-01  0.619343 -0.785121
# 56071  1.984522 -1.000000 -2.947092e-12  0.618780 -0.785565

# %%
df = df[df['Date Time'].dt.year != 2015] # Remove all rows whose year is 2015
df.reset_index(drop=True, inplace=True) # Reset the index of the resulting dataframe

# %%
# Then, set Date Time as the index variable
df.tail() # We take a look
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 52616 2014-12-31 19:00:00   1006.20      2.27    274.94         1.96    97.8
# 52617 2014-12-31 20:00:00   1006.28      2.14    274.81         1.89    98.2
# 52618 2014-12-31 21:00:00   1006.69      1.96    274.60         1.72    98.3
# 52619 2014-12-31 22:00:00   1006.92      1.94    274.56         1.75    98.6
# 52620 2014-12-31 23:00:00   1007.11      2.18    274.78         2.01    98.8
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 52616          7.19          7.04          0.16 -0.242173  0.414430 -0.645795
# 52617          7.13          7.00          0.13 -0.332780  0.593007 -0.822163
# 52618          7.04          6.92          0.12 -0.550837  0.381417 -1.282545
# 52619          7.03          6.93          0.10 -0.452571  0.547064 -1.147363
# 52620          7.15          7.06          0.09 -0.271231  0.221210 -0.666452
#
#          max Wy   Day sin   Day cos  Year sin  Year cos
# 52616  1.105146 -0.965926  0.258819 -0.002079  0.999998
# 52617  1.465076 -0.866025  0.500000 -0.001362  0.999999
# 52618  0.888076 -0.707107  0.707107 -0.000645  1.000000
# 52619  1.386924 -0.500000  0.866025  0.000072  1.000000
# 52620  0.543545 -0.258819  0.965926  0.000788  1.000000

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rh (%)', 'Wx', 'Wy']
plot_features = df[plot_cols]
plot_features.index = df['Date Time']
_ = plot_features.plot(subplots=True)

plot_features = df[plot_cols][:500]
plot_features.index = pd.DatetimeIndex(df['Date Time'][:500])
_ = plot_features.plot(subplots=True)

# %% [markdown]
# The trimming worked, so we are now ready to create columns containing the prior timepoints:

# %%
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
train_df = df[0:int(n*0.8)]
val_df = df[int(n*0.8):]

num_features = df.shape[1]

# %%
train_df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0          3.33          3.14          0.19 -0.204862 -0.046168 -0.614587
# 1          3.12          2.90          0.21 -0.245971 -0.044701 -0.619848
# 2          3.13          2.93          0.20 -0.175527  0.039879 -0.614344
# 3          3.07          2.85          0.23 -0.050000 -0.086603 -0.190000
# 4          2.94          2.71          0.23 -0.368202  0.156292 -0.810044
#
#      max Wy   Day sin   Day cos  Year sin  Year cos
# 0 -0.138503  0.258819  0.965926  0.010049  0.999950
# 1 -0.112645  0.500000  0.866025  0.010766  0.999942
# 2  0.139576  0.707107  0.707107  0.011483  0.999934
# 3 -0.329090  0.866025  0.500000  0.012199  0.999926
# 4  0.343843  0.965926  0.258819  0.012916  0.999917

# %%
val_df.head()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 42096 2013-10-20 01:30:00    987.36     14.46    288.67        10.89    79.1
# 42097 2013-10-20 02:30:00    987.35     14.27    288.48        10.93    80.3
# 42098 2013-10-20 03:30:00    987.61     13.96    288.15        11.03    82.5
# 42099 2013-10-20 04:30:00    987.66     15.90    290.09        12.38    79.6
# 42100 2013-10-20 05:30:00    987.67     15.04    289.22        12.51    84.8
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 42096         16.49         13.05          3.45 -1.088430  1.159060 -1.834586
# 42097         16.29         13.08          3.21 -1.455654 -0.878107 -1.883788
# 42098         15.97         13.17          2.79 -0.859674  0.230349 -2.009126
# 42099         18.09         14.40          3.69 -2.657367 -1.615704 -4.144125
# 42100         17.12         14.52          2.60 -2.865470 -1.735390 -4.285375
#
#          max Wy   Day sin   Day cos  Year sin  Year cos
# 42096  1.953636  0.382683  0.923880 -0.948685  0.316223
# 42097 -1.136373  0.608761  0.793353 -0.948458  0.316903
# 42098  0.538344  0.793353  0.608761 -0.948231  0.317583
# 42099 -2.519668  0.923880  0.382683 -0.948003  0.318262
# 42100 -2.595315  0.991445  0.130526 -0.947774  0.318942

# %%
numeric_cols = train_df.select_dtypes(include=[np.number]).columns
train_mean = train_df[numeric_cols].mean(numeric_only=True)
train_std = train_df[numeric_cols].std(numeric_only=True)

train_df[numeric_cols] = (train_df[numeric_cols] - train_mean) / train_std
val_df[numeric_cols] = (val_df[numeric_cols] - train_mean) / train_std
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\1788790050.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[numeric_cols] = (train_df[numeric_cols] - train_mean) / train_std
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\1788790050.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df[numeric_cols] = (val_df[numeric_cols] - train_mean) / train_std

# %%
train_df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  \
# 0 2009-01-01 01:00:00  0.933933 -1.930717 -1.989975    -1.855824  1.116628
# 1 2009-01-01 02:00:00  0.948382 -2.024689 -2.084404    -1.994185  1.044124
# 2 2009-01-01 03:00:00  0.974873 -2.016763 -2.078783    -1.978812  1.062250
# 3 2009-01-01 04:00:00  0.992935 -2.043936 -2.106887    -2.029125  1.007872
# 4 2009-01-01 05:00:00  1.049529 -2.109603 -2.176584    -2.117173  0.983704
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0     -1.289666     -1.459553     -0.788278  0.181904  0.222705  0.099683
# 1     -1.316755     -1.516124     -0.784135  0.161361  0.223641  0.097991
# 2     -1.315465     -1.509053     -0.786206  0.196563  0.277578  0.099761
# 3     -1.323204     -1.527910     -0.779993  0.259291  0.196920  0.236239
# 4     -1.339974     -1.560910     -0.779993  0.100280  0.351816  0.036820
#
#      max Wy   Day sin   Day cos  Year sin  Year cos
# 0  0.219956  0.366030  1.365974 -0.006048  1.449683
# 1  0.229785  0.707109  1.224696 -0.005038  1.449672
# 2  0.325662  1.000000  0.999954 -0.004028  1.449661
# 3  0.147509  1.224743  0.707066 -0.003018  1.449649
# 4  0.403309  1.366022  0.365990 -0.002007  1.449636

# %%
val_df.head()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 42096 2013-10-20 01:30:00 -0.166644  0.617844  0.628177     0.893231
# 42097 2013-10-20 02:30:00 -0.167848  0.596332  0.606818     0.898821
# 42098 2013-10-20 03:30:00 -0.136541  0.561235  0.569721     0.912797
# 42099 2013-10-20 04:30:00 -0.130520  0.780880  0.787807     1.101472
# 42100 2013-10-20 05:30:00 -0.129316  0.683511  0.690005     1.119640
#
#          rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy  \
# 42096  0.192197      0.407899      0.876383     -0.113041 -0.259630  0.991289
# 42097  0.264702      0.382100      0.883455     -0.162752 -0.443138 -0.307829
# 42098  0.397626      0.340822      0.904669     -0.249745 -0.145317  0.399042
# 42099  0.222407      0.614289      1.194598     -0.063330 -1.043654 -0.778200
# 42100  0.536593      0.489165      1.222884     -0.289100 -1.147646 -0.854525
#
#          max Wx    max Wy   Day sin   Day cos  Year sin  Year cos
# 42096 -0.292694  1.015235  0.541199  1.306512 -1.357294  0.478819
# 42097 -0.308518 -0.159361  0.860919  1.121923 -1.356975  0.479785
# 42098 -0.348830  0.477244  1.121970  0.860875 -1.356654  0.480750
# 42099 -1.035489 -0.685189  1.306560  0.541158 -1.356333  0.481715
# 42100 -1.080918 -0.713945  1.402111  0.184559 -1.356011  0.482679

# %%
# Now we MinMax scale every column except the first column
scaler = MinMaxScaler(feature_range=(-1, 1)) # This is the scaler we will use to scale every column to values from 0 to 1
train_df = pd.DataFrame(scaler.fit_transform(train_df.iloc[:, 1:]), columns=train_df.columns[1:]) # Take all columns except the first
#train_df.insert(0, 'Date Time', train_df['Date Time'], True) # Insert the first column into the new dataframe

# Now we MinMax scale every column except the first column
scaler = MinMaxScaler(feature_range=(-1, 1)) # This is the scaler we will use to scale every column to values from 0 to 1
val_df = pd.DataFrame(scaler.fit_transform(val_df.iloc[:, 1:]), columns=val_df.columns[1:]) # Take all columns except the first
#val_df.insert(0, 'Date Time', val_df['Date Time'], True) # Insert the first column into the new dataframe

# %%
train_df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0      0.670866 -0.496319 -0.506454    -0.330547  0.869949     -0.917727
# 1      0.673284 -0.524739 -0.534986    -0.371918  0.842081     -0.925048
# 2      0.677718 -0.522342 -0.533288    -0.367321  0.849048     -0.924699
# 3      0.680742 -0.530560 -0.541780    -0.382365  0.828147     -0.926791
# 4      0.690215 -0.550419 -0.562840    -0.408692  0.818857     -0.931323
# ...         ...       ...       ...          ...       ...           ...
# 42091  0.478182  0.229584  0.241168     0.422482  0.468184     -0.505665
# 42092  0.486849  0.234720  0.244905     0.421229  0.447283     -0.500436
# 42093  0.485035  0.242253  0.252717     0.436272  0.465862     -0.492766
# 42094  0.479391  0.251840  0.263247     0.454242  0.484440     -0.483005
# 42095  0.482616  0.275809  0.286685     0.479315  0.475151     -0.457208
#
#        VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx    max Wy  \
# 0         -0.830175     -0.990905  0.135604  0.027999  0.205966  0.010418
# 1         -0.847668     -0.989947  0.131399  0.028183  0.205632  0.012190
# 2         -0.845481     -0.990426  0.138605  0.038750  0.205981  0.029474
# 3         -0.851312     -0.988990  0.151447  0.022948  0.232877 -0.002642
# 4         -0.861516     -0.988990  0.118894  0.053294  0.193577  0.043472
# ...             ...           ...       ...       ...       ...       ...
# 42091     -0.207726     -0.833892 -0.144928 -0.228866  0.013750 -0.158367
# 42092     -0.209913     -0.825754 -0.023027  0.018046  0.047673  0.004623
# 42093     -0.188047     -0.829105 -0.190039 -0.065514 -0.026594 -0.048943
# 42094     -0.163265     -0.831977 -0.092795  0.019939  0.016979  0.008718
# 42095     -0.126093     -0.820967  0.110061  0.127908  0.172894  0.148999
#
#         Day sin   Day cos  Year sin  Year cos
# 0      0.258819  0.965926  0.010049  0.999950
# 1      0.500000  0.866025  0.010766  0.999942
# 2      0.707107  0.707107  0.011483  0.999934
# 3      0.866025  0.500000  0.012199  0.999926
# 4      0.965926  0.258819  0.012916  0.999917
# ...         ...       ...       ...       ...
# 42091 -0.793353  0.608761 -0.949812  0.312821
# 42092 -0.608761  0.793353 -0.949588  0.313502
# 42093 -0.382683  0.923880 -0.949363  0.314182
# 42094 -0.130526  0.991445 -0.949137  0.314863
# 42095  0.130526  0.991445 -0.948911  0.315543
#
# [42096 rows x 16 columns]

# %%
val_df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0      0.087719  0.118349  0.117362     0.404948  0.451659     -0.449141
# 1      0.087297  0.109633  0.108600     0.407454  0.483143     -0.457230
# 2      0.098288  0.095413  0.093383     0.413718  0.540863     -0.470172
# 3      0.100402  0.184404  0.182845     0.498277  0.464778     -0.384429
# 4      0.100824  0.144954  0.142725     0.506420  0.601207     -0.423660
# ...         ...       ...       ...          ...       ...           ...
# 10520  0.884168 -0.440826 -0.515794    -0.154400  0.942280     -0.825278
# 10521  0.887550 -0.446789 -0.521789    -0.158785  0.952774     -0.827705
# 10522  0.904883 -0.455046 -0.531473    -0.169433  0.955398     -0.831345
# 10523  0.914606 -0.455963 -0.533318    -0.167554  0.963269     -0.831749
# 10524  0.922638 -0.444954 -0.523173    -0.151268  0.968516     -0.826896
#
#        VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx    max Wy  \
# 0         -0.019553     -0.819419  0.133799  0.246318  0.063859  0.284864
# 1         -0.016760     -0.831981  0.092473 -0.046815  0.060318 -0.004249
# 2         -0.008380     -0.853965  0.159543  0.112683  0.051300  0.152444
# 3          0.106145     -0.806857 -0.042765 -0.152950 -0.102319 -0.133675
# 4          0.117318     -0.863910 -0.066185 -0.170172 -0.112482 -0.140753
# ...             ...           ...       ...       ...       ...       ...
# 10520     -0.579143     -0.991625  0.229035  0.139171  0.149395  0.205476
# 10521     -0.582868     -0.993195  0.218839  0.164867  0.136705  0.239152
# 10522     -0.590317     -0.993719  0.194299  0.134421  0.103579  0.185166
# 10523     -0.589385     -0.994766  0.205358  0.158256  0.113306  0.231840
# 10524     -0.577281     -0.995289  0.225765  0.111368  0.147909  0.152931
#
#         Day sin   Day cos  Year sin  Year cos
# 0      0.382683  0.923880 -0.948685  0.316223
# 1      0.608761  0.793353 -0.948458  0.316903
# 2      0.793353  0.608761 -0.948231  0.317583
# 3      0.923880  0.382683 -0.948003  0.318262
# 4      0.991445  0.130526 -0.947774  0.318942
# ...         ...       ...       ...       ...
# 10520 -0.965926  0.258819 -0.002079  0.999998
# 10521 -0.866025  0.500000 -0.001362  0.999999
# 10522 -0.707107  0.707107 -0.000645  1.000000
# 10523 -0.500000  0.866025  0.000072  1.000000
# 10524 -0.258819  0.965926  0.000788  1.000000
#
# [10525 rows x 16 columns]

# %%
# Calculate standardized values for all columns except the first
df_std = (df.iloc[:,1:] - train_mean) / train_std
df_std = df_std.melt(var_name='Column', value_name='Normalized')

# Plot violin plot
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
_ = ax.set_xticklabels(df.columns[1:], rotation=90)

# %%
column_names = train_df.columns.tolist()
print(column_names)
# Out:
# ['p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)', 'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'Wx', 'Wy', 'max Wx', 'max Wy', 'Day sin', 'Day cos', 'Year sin', 'Year cos']

# %%
def prepare_dataframe_for_lstm(df, n_steps):
   
    for i in range(1, n_steps+1):
        df[f'p (mbar)(t-{i})'] = df['p (mbar)'].shift(i)
    
    for i in range(1, n_steps+1):
        df[f'T (degC)(t-{i})'] = df['T (degC)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'rh (%)(t-{i})'] = df['rh (%)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tpot (K)(t-{i})'] = df['Tpot (K)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tdew (degC)(t-{i})'] = df['Tdew (degC)'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'VPmax (mbar)(t-{i})'] = df['VPmax (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPact (mbar)(t-{i})'] = df['VPact (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPdef (mbar)(t-{i})'] = df['VPdef (mbar)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'sh (g/kg)(t-{i})'] = df['sh (g/kg)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'H2OC (mmol/mol)(t-{i})'] = df['H2OC (mmol/mol)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'rho (g/m**3)(t-{i})'] = df['rho (g/m**3)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wx(t-{i})'] = df['Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wy(t-{i})'] = df['Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wx(t-{i})'] = df['max Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wy(t-{i})'] = df['max Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
   
    # Return the shifted dataframe
    return df

# %%
prepare_dataframe_for_lstm(train_df, n_steps=lookback)
prepare_dataframe_for_lstm(val_df, n_steps=lookback)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0      0.087719  0.118349  0.117362     0.404948  0.451659     -0.449141
# 1      0.087297  0.109633  0.108600     0.407454  0.483143     -0.457230
# 2      0.098288  0.095413  0.093383     0.413718  0.540863     -0.470172
# 3      0.100402  0.184404  0.182845     0.498277  0.464778     -0.384429
# 4      0.100824  0.144954  0.142725     0.506420  0.601207     -0.423660
# ...         ...       ...       ...          ...       ...           ...
# 10520  0.884168 -0.440826 -0.515794    -0.154400  0.942280     -0.825278
# 10521  0.887550 -0.446789 -0.521789    -0.158785  0.952774     -0.827705
# 10522  0.904883 -0.455046 -0.531473    -0.169433  0.955398     -0.831345
# 10523  0.914606 -0.455963 -0.533318    -0.167554  0.963269     -0.831749
# 10524  0.922638 -0.444954 -0.523173    -0.151268  0.968516     -0.826896
#
#        VPact (mbar)  VPdef (mbar)        Wx        Wy  ...  Year sin(t-7)  \
# 0         -0.019553     -0.819419  0.133799  0.246318  ...            NaN
# 1         -0.016760     -0.831981  0.092473 -0.046815  ...            NaN
# 2         -0.008380     -0.853965  0.159543  0.112683  ...            NaN
# 3          0.106145     -0.806857 -0.042765 -0.152950  ...            NaN
# 4          0.117318     -0.863910 -0.066185 -0.170172  ...            NaN
# ...             ...           ...       ...       ...  ...            ...
# 10520     -0.579143     -0.991625  0.229035  0.139171  ...   8.192870e-12
# 10521     -0.582868     -0.993195  0.218839  0.164867  ...  -2.588190e-01
# 10522     -0.590317     -0.993719  0.194299  0.134421  ...  -5.000000e-01
# 10523     -0.589385     -0.994766  0.205358  0.158256  ...  -7.071068e-01
# 10524     -0.577281     -0.995289  0.225765  0.111368  ...  -8.660254e-01
#
#        Year sin(t-8)  Year cos(t-1)  Year cos(t-2)  Year cos(t-3)  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN   9.238795e-01            NaN            NaN
# 2                NaN   7.933533e-01   9.238795e-01            NaN
# 3                NaN   6.087614e-01   7.933533e-01   9.238795e-01
# 4                NaN   3.826834e-01   6.087614e-01   7.933533e-01
# ...              ...            ...            ...            ...
# 10520   2.588190e-01  -1.075618e-11  -2.588190e-01  -5.000000e-01
# 10521   8.192870e-12   2.588190e-01  -1.075618e-11  -2.588190e-01
# 10522  -2.588190e-01   5.000000e-01   2.588190e-01  -1.075618e-11
# 10523  -5.000000e-01   7.071068e-01   5.000000e-01   2.588190e-01
# 10524  -7.071068e-01   8.660254e-01   7.071068e-01   5.000000e-01
#
#        Year cos(t-4)  Year cos(t-5)  Year cos(t-6)  Year cos(t-7)  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4       9.238795e-01            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 10520  -7.071068e-01  -8.660254e-01      -0.965926      -1.000000
# 10521  -5.000000e-01  -7.071068e-01      -0.866025      -0.965926
# 10522  -2.588190e-01  -5.000000e-01      -0.707107      -0.866025
# 10523  -1.075618e-11  -2.588190e-01      -0.500000      -0.707107
# 10524   2.588190e-01  -1.075618e-11      -0.258819      -0.500000
#
#        Year cos(t-8)
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 10520      -0.965926
# 10521      -1.000000
# 10522      -0.965926
# 10523      -0.866025
# 10524      -0.707107
#
# [10525 rows x 144 columns]

# %% [markdown]
# That worked, but the problem is that columns are ordered from $t-1$ to $t-k$, which is the opposite direction we want. We want to feed the furthest timepoints first and end with the most recent timepoint. Moreover, as it stands, columns are ordered by feature, not by timepoint, so we need to fix these two things:

# %%
# Define a list of timepoints to group by
timepoints = [f't-{i}' for i in range(lookback, 0, -1)]

# In comments below are all the options tried. The reader may ignore these

# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year','Tpot (K)', 'Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)

# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year','Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)
    
# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)
    
# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)  
    
# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)


# Group the shifted columns by timepoint
all_shifted_cols = []
for timepoint in timepoints:
    columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 
                                                 'Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos' ]] #'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
    all_shifted_cols.extend(columns)
    
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Year']]
#     all_shifted_cols.extend(columns)


# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year','Tpot (K)', 'Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year','Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols


# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year']
# all_cols = target_cols + feature_cols + all_shifted_cols

# Concatenate the target columns and the grouped columns
target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy']
feature_cols = ['Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos'] # 'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
all_cols = target_cols + feature_cols + all_shifted_cols

# %%
# Let us take a look at the final variable 'all_cols'
all_cols
# Out:
# ['p (mbar)',
#  'T (degC)',
#  'rh (%)',
#  'Wx',
#  'Wy',
#  'Tpot (K)',
#  'Tdew (degC)',
#  'VPmax (mbar)',
#  'VPact (mbar)',
#  'VPdef (mbar)',
#  'max Wx',
#  'max Wy',
#  'Day sin',
#  'Day cos',
#  'Year sin',
#  'Year cos',
#  'p (mbar)(t-8)',
#  'T (degC)(t-8)',
#  'rh (%)(t-8)',
#  'Wx(t-8)',
#  'Wy(t-8)',
#  'Tpot (K)(t-8)',
#  'Tdew (degC)(t-8)',
#  'VPmax (mbar)(t-8)',
#  'VPact (mbar)(t-8)',
#  'VPdef (mbar)(t-8)',
#  'max Wx(t-8)',
#  'max Wy(t-8)',
#  'Day sin(t-8)',
#  'Day cos(t-8)',
#  'Year sin(t-8)',
#  'Year cos(t-8)',
#  'p (mbar)(t-7)',
#  'T (degC)(t-7)',
#  'rh (%)(t-7)',
#  'Wx(t-7)',
#  'Wy(t-7)',
#  'Tpot (K)(t-7)',
#  'Tdew (degC)(t-7)',
#  'VPmax (mbar)(t-7)',
#  'VPact (mbar)(t-7)',
#  'VPdef (mbar)(t-7)',
#  'max Wx(t-7)',
#  'max Wy(t-7)',
#  'Day sin(t-7)',
#  'Day cos(t-7)',
#  'Year sin(t-7)',
#  'Year cos(t-7)',
#  'p (mbar)(t-6)',
#  'T (degC)(t-6)',
#  'rh (%)(t-6)',
#  'Wx(t-6)',
#  'Wy(t-6)',
#  'Tpot (K)(t-6)',
#  'Tdew (degC)(t-6)',
#  'VPmax (mbar)(t-6)',
#  'VPact (mbar)(t-6)',
#  'VPdef (mbar)(t-6)',
#  'max Wx(t-6)',
#  'max Wy(t-6)',
#  'Day sin(t-6)',
#  'Day cos(t-6)',
#  'Year sin(t-6)',
#  'Year cos(t-6)',
#  'p (mbar)(t-5)',
#  'T (degC)(t-5)',
#  'rh (%)(t-5)',
#  'Wx(t-5)',
#  'Wy(t-5)',
#  'Tpot (K)(t-5)',
#  'Tdew (degC)(t-5)',
#  'VPmax (mbar)(t-5)',
#  'VPact (mbar)(t-5)',
#  'VPdef (mbar)(t-5)',
#  'max Wx(t-5)',
#  'max Wy(t-5)',
#  'Day sin(t-5)',
#  'Day cos(t-5)',
#  'Year sin(t-5)',
#  'Year cos(t-5)',
#  'p (mbar)(t-4)',
#  'T (degC)(t-4)',
#  'rh (%)(t-4)',
#  'Wx(t-4)',
#  'Wy(t-4)',
#  'Tpot (K)(t-4)',
#  'Tdew (degC)(t-4)',
#  'VPmax (mbar)(t-4)',
#  'VPact (mbar)(t-4)',
#  'VPdef (mbar)(t-4)',
#  'max Wx(t-4)',
#  'max Wy(t-4)',
#  'Day sin(t-4)',
#  'Day cos(t-4)',
#  'Year sin(t-4)',
#  'Year cos(t-4)',
#  'p (mbar)(t-3)',
#  'T (degC)(t-3)',
#  'rh (%)(t-3)',
#  'Wx(t-3)',
#  'Wy(t-3)',
#  'Tpot (K)(t-3)',
#  'Tdew (degC)(t-3)',
#  'VPmax (mbar)(t-3)',
#  'VPact (mbar)(t-3)',
#  'VPdef (mbar)(t-3)',
#  'max Wx(t-3)',
#  'max Wy(t-3)',
#  'Day sin(t-3)',
#  'Day cos(t-3)',
#  'Year sin(t-3)',
#  'Year cos(t-3)',
#  'p (mbar)(t-2)',
#  'T (degC)(t-2)',
#  'rh (%)(t-2)',
#  'Wx(t-2)',
#  'Wy(t-2)',
#  'Tpot (K)(t-2)',
#  'Tdew (degC)(t-2)',
#  'VPmax (mbar)(t-2)',
#  'VPact (mbar)(t-2)',
#  'VPdef (mbar)(t-2)',
#  'max Wx(t-2)',
#  'max Wy(t-2)',
#  'Day sin(t-2)',
#  'Day cos(t-2)',
#  'Year sin(t-2)',
#  'Year cos(t-2)',
#  'p (mbar)(t-1)',
#  'T (degC)(t-1)',
#  'rh (%)(t-1)',
#  'Wx(t-1)',
#  'Wy(t-1)',
#  'Tpot (K)(t-1)',
#  'Tdew (degC)(t-1)',
#  'VPmax (mbar)(t-1)',
#  'VPact (mbar)(t-1)',
#  'VPdef (mbar)(t-1)',
#  'max Wx(t-1)',
#  'max Wy(t-1)',
#  'Day sin(t-1)',
#  'Day cos(t-1)',
#  'Year sin(t-1)',
#  'Year cos(t-1)']

# %% [markdown]
# Feature columns are now grouped by tiempoint and the direction of time has been flipped. Good progress, but now we must delete the custom features at timepoint $t$, as we are not allowed to use current timepoints.

# %%
# First we udpate the df
train_df = train_df[all_cols]
val_df = val_df[all_cols]

# %%
train_df
# Out:
#        p (mbar)  T (degC)    rh (%)        Wx        Wy  Tpot (K)  \
# 0      0.670866 -0.496319  0.869949  0.135604  0.027999 -0.506454
# 1      0.673284 -0.524739  0.842081  0.131399  0.028183 -0.534986
# 2      0.677718 -0.522342  0.849048  0.138605  0.038750 -0.533288
# 3      0.680742 -0.530560  0.828147  0.151447  0.022948 -0.541780
# 4      0.690215 -0.550419  0.818857  0.118894  0.053294 -0.562840
# ...         ...       ...       ...       ...       ...       ...
# 42091  0.478182  0.229584  0.468184 -0.144928 -0.228866  0.241168
# 42092  0.486849  0.234720  0.447283 -0.023027  0.018046  0.244905
# 42093  0.485035  0.242253  0.465862 -0.190039 -0.065514  0.252717
# 42094  0.479391  0.251840  0.484440 -0.092795  0.019939  0.263247
# 42095  0.482616  0.275809  0.475151  0.110061  0.127908  0.286685
#
#        Tdew (degC)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  ...  \
# 0        -0.330547     -0.917727     -0.830175     -0.990905  ...
# 1        -0.371918     -0.925048     -0.847668     -0.989947  ...
# 2        -0.367321     -0.924699     -0.845481     -0.990426  ...
# 3        -0.382365     -0.926791     -0.851312     -0.988990  ...
# 4        -0.408692     -0.931323     -0.861516     -0.988990  ...
# ...            ...           ...           ...           ...  ...
# 42091     0.422482     -0.505665     -0.207726     -0.833892  ...
# 42092     0.421229     -0.500436     -0.209913     -0.825754  ...
# 42093     0.436272     -0.492766     -0.188047     -0.829105  ...
# 42094     0.454242     -0.483005     -0.163265     -0.831977  ...
# 42095     0.479315     -0.457208     -0.126093     -0.820967  ...
#
#        Tdew (degC)(t-1)  VPmax (mbar)(t-1)  VPact (mbar)(t-1)  \
# 0                   NaN                NaN                NaN
# 1             -0.330547          -0.917727          -0.830175
# 2             -0.371918          -0.925048          -0.847668
# 3             -0.367321          -0.924699          -0.845481
# 4             -0.382365          -0.926791          -0.851312
# ...                 ...                ...                ...
# 42091          0.400334          -0.524839          -0.237609
# 42092          0.422482          -0.505665          -0.207726
# 42093          0.421229          -0.500436          -0.209913
# 42094          0.436272          -0.492766          -0.188047
# 42095          0.454242          -0.483005          -0.163265
#
#        VPdef (mbar)(t-1)  max Wx(t-1)  max Wy(t-1)  Day sin(t-1)  \
# 0                    NaN          NaN          NaN           NaN
# 1              -0.990905     0.205966     0.010418      0.258819
# 2              -0.989947     0.205632     0.012190      0.500000
# 3              -0.990426     0.205981     0.029474      0.707107
# 4              -0.988990     0.232877    -0.002642      0.866025
# ...                  ...          ...          ...           ...
# 42091          -0.840594     0.050740    -0.127093     -0.923880
# 42092          -0.833892     0.013750    -0.158367     -0.793353
# 42093          -0.825754     0.047673     0.004623     -0.608761
# 42094          -0.829105    -0.026594    -0.048943     -0.382683
# 42095          -0.831977     0.016979     0.008718     -0.130526
#
#        Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0               NaN            NaN            NaN
# 1          0.965926       0.258819       0.965926
# 2          0.866025       0.500000       0.866025
# 3          0.707107       0.707107       0.707107
# 4          0.500000       0.866025       0.500000
# ...             ...            ...            ...
# 42091      0.382683      -0.923880       0.382683
# 42092      0.608761      -0.793353       0.608761
# 42093      0.793353      -0.608761       0.793353
# 42094      0.923880      -0.382683       0.923880
# 42095      0.991445      -0.130526       0.991445
#
# [42096 rows x 144 columns]

# %%
val_df
# Out:
#        p (mbar)  T (degC)    rh (%)        Wx        Wy  Tpot (K)  \
# 0      0.087719  0.118349  0.451659  0.133799  0.246318  0.117362
# 1      0.087297  0.109633  0.483143  0.092473 -0.046815  0.108600
# 2      0.098288  0.095413  0.540863  0.159543  0.112683  0.093383
# 3      0.100402  0.184404  0.464778 -0.042765 -0.152950  0.182845
# 4      0.100824  0.144954  0.601207 -0.066185 -0.170172  0.142725
# ...         ...       ...       ...       ...       ...       ...
# 10520  0.884168 -0.440826  0.942280  0.229035  0.139171 -0.515794
# 10521  0.887550 -0.446789  0.952774  0.218839  0.164867 -0.521789
# 10522  0.904883 -0.455046  0.955398  0.194299  0.134421 -0.531473
# 10523  0.914606 -0.455963  0.963269  0.205358  0.158256 -0.533318
# 10524  0.922638 -0.444954  0.968516  0.225765  0.111368 -0.523173
#
#        Tdew (degC)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  ...  \
# 0         0.404948     -0.449141     -0.019553     -0.819419  ...
# 1         0.407454     -0.457230     -0.016760     -0.831981  ...
# 2         0.413718     -0.470172     -0.008380     -0.853965  ...
# 3         0.498277     -0.384429      0.106145     -0.806857  ...
# 4         0.506420     -0.423660      0.117318     -0.863910  ...
# ...            ...           ...           ...           ...  ...
# 10520    -0.154400     -0.825278     -0.579143     -0.991625  ...
# 10521    -0.158785     -0.827705     -0.582868     -0.993195  ...
# 10522    -0.169433     -0.831345     -0.590317     -0.993719  ...
# 10523    -0.167554     -0.831749     -0.589385     -0.994766  ...
# 10524    -0.151268     -0.826896     -0.577281     -0.995289  ...
#
#        Tdew (degC)(t-1)  VPmax (mbar)(t-1)  VPact (mbar)(t-1)  \
# 0                   NaN                NaN                NaN
# 1              0.404948          -0.449141          -0.019553
# 2              0.407454          -0.457230          -0.016760
# 3              0.413718          -0.470172          -0.008380
# 4              0.498277          -0.384429           0.106145
# ...                 ...                ...                ...
# 10520         -0.141873          -0.821234          -0.569832
# 10521         -0.154400          -0.825278          -0.579143
# 10522         -0.158785          -0.827705          -0.582868
# 10523         -0.169433          -0.831345          -0.590317
# 10524         -0.167554          -0.831749          -0.589385
#
#        VPdef (mbar)(t-1)  max Wx(t-1)  max Wy(t-1)  Day sin(t-1)  \
# 0                    NaN          NaN          NaN           NaN
# 1              -0.819419     0.063859     0.284864      0.382683
# 2              -0.831981     0.060318    -0.004249      0.608761
# 3              -0.853965     0.051300     0.152444      0.793353
# 4              -0.806857    -0.102319    -0.133675      0.923880
# ...                  ...          ...          ...           ...
# 10520          -0.992149     0.093468     0.170503     -1.000000
# 10521          -0.991625     0.149395     0.205476     -0.965926
# 10522          -0.993195     0.136705     0.239152     -0.866025
# 10523          -0.993719     0.103579     0.185166     -0.707107
# 10524          -0.994766     0.113306     0.231840     -0.500000
#
#        Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0               NaN            NaN            NaN
# 1      9.238795e-01       0.382683   9.238795e-01
# 2      7.933533e-01       0.608761   7.933533e-01
# 3      6.087614e-01       0.793353   6.087614e-01
# 4      3.826834e-01       0.923880   3.826834e-01
# ...             ...            ...            ...
# 10520 -1.075618e-11      -1.000000  -1.075618e-11
# 10521  2.588190e-01      -0.965926   2.588190e-01
# 10522  5.000000e-01      -0.866025   5.000000e-01
# 10523  7.071068e-01      -0.707107   7.071068e-01
# 10524  8.660254e-01      -0.500000   8.660254e-01
#
# [10525 rows x 144 columns]

# %%
print(train_df.columns[:60])
# Out:
# Index(['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 'Tpot (K)', 'Tdew (degC)',
#        'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'max Wx', 'max Wy',
#        'Day sin', 'Day cos', 'Year sin', 'Year cos', 'p (mbar)(t-8)',
#        'T (degC)(t-8)', 'rh (%)(t-8)', 'Wx(t-8)', 'Wy(t-8)', 'Tpot (K)(t-8)',
#        'Tdew (degC)(t-8)', 'VPmax (mbar)(t-8)', 'VPact (mbar)(t-8)',
#        'VPdef (mbar)(t-8)', 'max Wx(t-8)', 'max Wy(t-8)', 'Day sin(t-8)',
#        'Day cos(t-8)', 'Year sin(t-8)', 'Year cos(t-8)', 'p (mbar)(t-7)',
#        'T (degC)(t-7)', 'rh (%)(t-7)', 'Wx(t-7)', 'Wy(t-7)', 'Tpot (K)(t-7)',
#        'Tdew (degC)(t-7)', 'VPmax (mbar)(t-7)', 'VPact (mbar)(t-7)',
#        'VPdef (mbar)(t-7)', 'max Wx(t-7)', 'max Wy(t-7)', 'Day sin(t-7)',
#        'Day cos(t-7)', 'Year sin(t-7)', 'Year cos(t-7)', 'p (mbar)(t-6)',
#        'T (degC)(t-6)', 'rh (%)(t-6)', 'Wx(t-6)', 'Wy(t-6)', 'Tpot (K)(t-6)',
#        'Tdew (degC)(t-6)', 'VPmax (mbar)(t-6)', 'VPact (mbar)(t-6)',
#        'VPdef (mbar)(t-6)', 'max Wx(t-6)', 'max Wy(t-6)'],
#       dtype='object')

# %%
print(val_df.columns[:60])
# Out:
# Index(['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 'Tpot (K)', 'Tdew (degC)',
#        'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'max Wx', 'max Wy',
#        'Day sin', 'Day cos', 'Year sin', 'Year cos', 'p (mbar)(t-8)',
#        'T (degC)(t-8)', 'rh (%)(t-8)', 'Wx(t-8)', 'Wy(t-8)', 'Tpot (K)(t-8)',
#        'Tdew (degC)(t-8)', 'VPmax (mbar)(t-8)', 'VPact (mbar)(t-8)',
#        'VPdef (mbar)(t-8)', 'max Wx(t-8)', 'max Wy(t-8)', 'Day sin(t-8)',
#        'Day cos(t-8)', 'Year sin(t-8)', 'Year cos(t-8)', 'p (mbar)(t-7)',
#        'T (degC)(t-7)', 'rh (%)(t-7)', 'Wx(t-7)', 'Wy(t-7)', 'Tpot (K)(t-7)',
#        'Tdew (degC)(t-7)', 'VPmax (mbar)(t-7)', 'VPact (mbar)(t-7)',
#        'VPdef (mbar)(t-7)', 'max Wx(t-7)', 'max Wy(t-7)', 'Day sin(t-7)',
#        'Day cos(t-7)', 'Year sin(t-7)', 'Year cos(t-7)', 'p (mbar)(t-6)',
#        'T (degC)(t-6)', 'rh (%)(t-6)', 'Wx(t-6)', 'Wy(t-6)', 'Tpot (K)(t-6)',
#        'Tdew (degC)(t-6)', 'VPmax (mbar)(t-6)', 'VPact (mbar)(t-6)',
#        'VPdef (mbar)(t-6)', 'max Wx(t-6)', 'max Wy(t-6)'],
#       dtype='object')

# %%
#shifted_df = shifted_df.drop(shifted_df.columns[4:11], axis=1)
# shifted_df = shifted_df.drop(shifted_df.columns[4:10], axis=1)
#shifted_df = shifted_df.drop(shifted_df.columns[4:9], axis=1)
# shifted_df = shifted_df.drop(shifted_df.columns[4:8], axis=1)
# shifted_df = shifted_df.drop(shifted_df.columns[4:7], axis=1)

shifted_df = train_df.drop(train_df.columns[5:16], axis=1) # We delete the custom features at timpoint t
shifted_df_val = val_df.drop(val_df.columns[5:16], axis=1) # We delete the custom features at timpoint t
# shifted_df = shifted_df.drop(shifted_df.columns[4:5], axis=1) # We delete the custom features at timpoint t

# %%
shifted_df
# Out:
#        p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 0      0.670866 -0.496319  0.869949  0.135604  0.027999            NaN
# 1      0.673284 -0.524739  0.842081  0.131399  0.028183            NaN
# 2      0.677718 -0.522342  0.849048  0.138605  0.038750            NaN
# 3      0.680742 -0.530560  0.828147  0.151447  0.022948            NaN
# 4      0.690215 -0.550419  0.818857  0.118894  0.053294            NaN
# ...         ...       ...       ...       ...       ...            ...
# 42091  0.478182  0.229584  0.468184 -0.144928 -0.228866       0.502771
# 42092  0.486849  0.234720  0.447283 -0.023027  0.018046       0.485035
# 42093  0.485035  0.242253  0.465862 -0.190039 -0.065514       0.478384
# 42094  0.479391  0.251840  0.484440 -0.092795  0.019939       0.472740
# 42095  0.482616  0.275809  0.475151  0.110061  0.127908       0.470120
#
#        T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 0                NaN          NaN       NaN       NaN  ...               NaN
# 1                NaN          NaN       NaN       NaN  ...         -0.330547
# 2                NaN          NaN       NaN       NaN  ...         -0.371918
# 3                NaN          NaN       NaN       NaN  ...         -0.367321
# 4                NaN          NaN       NaN       NaN  ...         -0.382365
# ...              ...          ...       ...       ...  ...               ...
# 42091       0.282315     0.093590 -0.136243  0.099397  ...          0.400334
# 42092       0.329567    -0.046911 -0.265887 -0.017728  ...          0.422482
# 42093       0.336073    -0.084301 -0.207650 -0.092098  ...          0.421229
# 42094       0.359014    -0.073386 -0.222945  0.028105  ...          0.436272
# 42095       0.322034     0.071760 -0.088332  0.055206  ...          0.454242
#
#        VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 0                    NaN                NaN                NaN          NaN
# 1              -0.917727          -0.830175          -0.990905     0.205966
# 2              -0.925048          -0.847668          -0.989947     0.205632
# 3              -0.924699          -0.845481          -0.990426     0.205981
# 4              -0.926791          -0.851312          -0.988990     0.232877
# ...                  ...                ...                ...          ...
# 42091          -0.524839          -0.237609          -0.840594     0.050740
# 42092          -0.505665          -0.207726          -0.833892     0.013750
# 42093          -0.500436          -0.209913          -0.825754     0.047673
# 42094          -0.492766          -0.188047          -0.829105    -0.026594
# 42095          -0.483005          -0.163265          -0.831977     0.016979
#
#        max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0              NaN           NaN           NaN            NaN            NaN
# 1         0.010418      0.258819      0.965926       0.258819       0.965926
# 2         0.012190      0.500000      0.866025       0.500000       0.866025
# 3         0.029474      0.707107      0.707107       0.707107       0.707107
# 4        -0.002642      0.866025      0.500000       0.866025       0.500000
# ...            ...           ...           ...            ...            ...
# 42091    -0.127093     -0.923880      0.382683      -0.923880       0.382683
# 42092    -0.158367     -0.793353      0.608761      -0.793353       0.608761
# 42093     0.004623     -0.608761      0.793353      -0.608761       0.793353
# 42094    -0.048943     -0.382683      0.923880      -0.382683       0.923880
# 42095     0.008718     -0.130526      0.991445      -0.130526       0.991445
#
# [42096 rows x 133 columns]

# %%
shifted_df_val
# Out:
#        p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 0      0.087719  0.118349  0.451659  0.133799  0.246318            NaN
# 1      0.087297  0.109633  0.483143  0.092473 -0.046815            NaN
# 2      0.098288  0.095413  0.540863  0.159543  0.112683            NaN
# 3      0.100402  0.184404  0.464778 -0.042765 -0.152950            NaN
# 4      0.100824  0.144954  0.601207 -0.066185 -0.170172            NaN
# ...         ...       ...       ...       ...       ...            ...
# 10520  0.884168 -0.440826  0.942280  0.229035  0.139171       0.843162
# 10521  0.887550 -0.446789  0.952774  0.218839  0.164867       0.837244
# 10522  0.904883 -0.455046  0.955398  0.194299  0.134421       0.830057
# 10523  0.914606 -0.455963  0.963269  0.205358  0.158256       0.822025
# 10524  0.922638 -0.444954  0.968516  0.225765  0.111368       0.831325
#
#        T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 0                NaN          NaN       NaN       NaN  ...               NaN
# 1                NaN          NaN       NaN       NaN  ...          0.404948
# 2                NaN          NaN       NaN       NaN  ...          0.407454
# 3                NaN          NaN       NaN       NaN  ...          0.413718
# 4                NaN          NaN       NaN       NaN  ...          0.498277
# ...              ...          ...       ...       ...  ...               ...
# 10520      -0.424312     0.700905  0.241338  0.230861  ...         -0.141873
# 10521      -0.409174     0.698282  0.171763  0.025417  ...         -0.154400
# 10522      -0.419725     0.797980  0.178548  0.063260  ...         -0.158785
# 10523      -0.437615     0.887184  0.231995  0.202294  ...         -0.169433
# 10524      -0.444495     0.921291  0.193281  0.171565  ...         -0.167554
#
#        VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 0                    NaN                NaN                NaN          NaN
# 1              -0.449141          -0.019553          -0.819419     0.063859
# 2              -0.457230          -0.016760          -0.831981     0.060318
# 3              -0.470172          -0.008380          -0.853965     0.051300
# 4              -0.384429           0.106145          -0.806857    -0.102319
# ...                  ...                ...                ...          ...
# 10520          -0.821234          -0.569832          -0.992149     0.093468
# 10521          -0.825278          -0.579143          -0.991625     0.149395
# 10522          -0.827705          -0.582868          -0.993195     0.136705
# 10523          -0.831345          -0.590317          -0.993719     0.103579
# 10524          -0.831749          -0.589385          -0.994766     0.113306
#
#        max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0              NaN           NaN           NaN            NaN            NaN
# 1         0.284864      0.382683  9.238795e-01       0.382683   9.238795e-01
# 2        -0.004249      0.608761  7.933533e-01       0.608761   7.933533e-01
# 3         0.152444      0.793353  6.087614e-01       0.793353   6.087614e-01
# 4        -0.133675      0.923880  3.826834e-01       0.923880   3.826834e-01
# ...            ...           ...           ...            ...            ...
# 10520     0.170503     -1.000000 -1.075618e-11      -1.000000  -1.075618e-11
# 10521     0.205476     -0.965926  2.588190e-01      -0.965926   2.588190e-01
# 10522     0.239152     -0.866025  5.000000e-01      -0.866025   5.000000e-01
# 10523     0.185166     -0.707107  7.071068e-01      -0.707107   7.071068e-01
# 10524     0.231840     -0.500000  8.660254e-01      -0.500000   8.660254e-01
#
# [10525 rows x 133 columns]

# %%
shifted_df = shifted_df.dropna()
shifted_df_val = shifted_df_val.dropna()

# %%
shifted_df
# Out:
#        p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 8      0.735161 -0.482965  0.795634  0.124358  0.017717       0.670866
# 9      0.746851 -0.461736  0.804923  0.213567 -0.133479       0.673284
# 10     0.758944 -0.474405  0.784022  0.155198 -0.204854       0.677718
# 11     0.747455 -0.455915  0.758477 -0.031117  0.016131       0.680742
# 12     0.742014 -0.422359  0.735253  0.098723  0.024719       0.690215
# ...         ...       ...       ...       ...       ...            ...
# 42091  0.478182  0.229584  0.468184 -0.144928 -0.228866       0.502771
# 42092  0.486849  0.234720  0.447283 -0.023027  0.018046       0.485035
# 42093  0.485035  0.242253  0.465862 -0.190039 -0.065514       0.478384
# 42094  0.479391  0.251840  0.484440 -0.092795  0.019939       0.472740
# 42095  0.482616  0.275809  0.475151  0.110061  0.127908       0.470120
#
#        T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 8          -0.496319     0.869949  0.135604  0.027999  ...         -0.341830
# 9          -0.524739     0.842081  0.131399  0.028183  ...         -0.333055
# 10         -0.522342     0.849048  0.138605  0.038750  ...         -0.305056
# 11         -0.530560     0.828147  0.151447  0.022948  ...         -0.325533
# 12         -0.550419     0.818857  0.118894  0.053294  ...         -0.309653
# ...              ...          ...       ...       ...  ...               ...
# 42091       0.282315     0.093590 -0.136243  0.099397  ...          0.400334
# 42092       0.329567    -0.046911 -0.265887 -0.017728  ...          0.422482
# 42093       0.336073    -0.084301 -0.207650 -0.092098  ...          0.421229
# 42094       0.359014    -0.073386 -0.222945  0.028105  ...          0.436272
# 42095       0.322034     0.071760 -0.088332  0.055206  ...          0.454242
#
#        VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 8              -0.918424          -0.835277          -0.988511     0.179160
# 9              -0.914241          -0.830904          -0.985639     0.207949
# 10             -0.908314          -0.818513          -0.985639     0.317992
# 11             -0.911801          -0.827988          -0.984203     0.243424
# 12             -0.906920          -0.820700          -0.981809     0.078716
# ...                  ...                ...                ...          ...
# 42091          -0.524839          -0.237609          -0.840594     0.050740
# 42092          -0.505665          -0.207726          -0.833892     0.013750
# 42093          -0.500436          -0.209913          -0.825754     0.047673
# 42094          -0.492766          -0.188047          -0.829105    -0.026594
# 42095          -0.483005          -0.163265          -0.831977     0.016979
#
#        max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 8        -0.027867  8.660254e-01     -0.500000   8.660254e-01      -0.500000
# 9         0.003597  7.071068e-01     -0.707107   7.071068e-01      -0.707107
# 10       -0.169885  5.000000e-01     -0.866025   5.000000e-01      -0.866025
# 11       -0.211706  2.588190e-01     -0.965926   2.588190e-01      -0.965926
# 12        0.006082  6.903299e-12     -1.000000   6.903299e-12      -1.000000
# ...            ...           ...           ...            ...            ...
# 42091    -0.127093 -9.238795e-01      0.382683  -9.238795e-01       0.382683
# 42092    -0.158367 -7.933533e-01      0.608761  -7.933533e-01       0.608761
# 42093     0.004623 -6.087614e-01      0.793353  -6.087614e-01       0.793353
# 42094    -0.048943 -3.826834e-01      0.923880  -3.826834e-01       0.923880
# 42095     0.008718 -1.305262e-01      0.991445  -1.305262e-01       0.991445
#
# [42088 rows x 133 columns]

# %%
shifted_df_val
# Out:
#        p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 8      0.149440  0.222477  0.477896 -0.091436 -0.191852       0.087719
# 9      0.156627  0.250917  0.386068 -0.354008 -0.163510       0.087297
# 10     0.149863  0.262844  0.365079 -0.187159 -0.019420       0.098288
# 11     0.125343  0.228440  0.451659 -0.014054  0.202624       0.100402
# 12     0.132107  0.231651  0.456907  0.032462  0.089032       0.100824
# ...         ...       ...       ...       ...       ...            ...
# 10520  0.884168 -0.440826  0.942280  0.229035  0.139171       0.843162
# 10521  0.887550 -0.446789  0.952774  0.218839  0.164867       0.837244
# 10522  0.904883 -0.455046  0.955398  0.194299  0.134421       0.830057
# 10523  0.914606 -0.455963  0.963269  0.205358  0.158256       0.822025
# 10524  0.922638 -0.444954  0.968516  0.225765  0.111368       0.831325
#
#        T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 8           0.118349     0.451659  0.133799  0.246318  ...          0.473223
# 9           0.109633     0.483143  0.092473 -0.046815  ...          0.555277
# 10          0.095413     0.540863  0.159543  0.112683  ...          0.549640
# 11          0.184404     0.464778 -0.042765 -0.152950  ...          0.555277
# 12          0.144954     0.601207 -0.066185 -0.170172  ...          0.550893
# ...              ...          ...       ...       ...  ...               ...
# 10520      -0.424312     0.700905  0.241338  0.230861  ...         -0.141873
# 10521      -0.409174     0.698282  0.171763  0.025417  ...         -0.154400
# 10522      -0.419725     0.797980  0.178548  0.063260  ...         -0.158785
# 10523      -0.437615     0.887184  0.231995  0.202294  ...         -0.169433
# 10524      -0.444495     0.921291  0.193281  0.171565  ...         -0.167554
#
#        VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 8              -0.477452           0.070764          -0.907354    -0.015788
# 9              -0.344388           0.188082          -0.801099    -0.237115
# 10             -0.313650           0.180633          -0.757132    -0.307691
# 11             -0.300303           0.189013          -0.744569    -0.235096
# 12             -0.337917           0.182495          -0.789584    -0.088829
# ...                  ...                ...                ...          ...
# 10520          -0.821234          -0.569832          -0.992149     0.093468
# 10521          -0.825278          -0.579143          -0.991625     0.149395
# 10522          -0.827705          -0.582868          -0.993195     0.136705
# 10523          -0.831345          -0.590317          -0.993719     0.103579
# 10524          -0.831749          -0.589385          -0.994766     0.113306
#
#        max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 8         0.261613      0.793353 -6.087614e-01       0.793353  -6.087614e-01
# 9        -0.241596      0.608761 -7.933533e-01       0.608761  -7.933533e-01
# 10       -0.101872      0.382683 -9.238795e-01       0.382683  -9.238795e-01
# 11        0.004270      0.130526 -9.914449e-01       0.130526  -9.914449e-01
# 12        0.233896     -0.130526 -9.914449e-01      -0.130526  -9.914449e-01
# ...            ...           ...           ...            ...            ...
# 10520     0.170503     -1.000000 -1.075618e-11      -1.000000  -1.075618e-11
# 10521     0.205476     -0.965926  2.588190e-01      -0.965926   2.588190e-01
# 10522     0.239152     -0.866025  5.000000e-01      -0.866025   5.000000e-01
# 10523     0.185166     -0.707107  7.071068e-01      -0.707107   7.071068e-01
# 10524     0.231840     -0.500000  8.660254e-01      -0.500000   8.660254e-01
#
# [10517 rows x 133 columns]

# %% [markdown]
# That looks good. The first four columns contain our targets at timepoint $t$. Then, the other columns contain the $t-k$ ... $t-1$ values for each target variable. We're not done yet, though. Now we can turn this data into a Numpy array:

# %%
# We convert to numpy and print
shifted_df_as_np = shifted_df.to_numpy()
shifted_df_val_as_np = shifted_df_val.to_numpy()
print(shifted_df_as_np)
# Out:
# [[ 0.73516074 -0.48296525  0.795634   ... -0.5         0.8660254
#   -0.5       ]
#  [ 0.74685075 -0.461736    0.80492336 ... -0.70710678  0.70710678
#   -0.70710678]
#  [ 0.75894387 -0.47440507  0.78402229 ... -0.8660254   0.5
#   -0.8660254 ]
#  ...
#  [ 0.48503477  0.24225304  0.46586159 ...  0.79335334 -0.60876143
#    0.79335334]
#  [ 0.47939131  0.25184044  0.48444032 ...  0.92387953 -0.38268343
#    0.92387953]
#  [ 0.48261614  0.27580894  0.47515095 ...  0.99144486 -0.13052619
#    0.99144486]]

# %%
print(shifted_df_val_as_np)
# Out:
# [[ 0.14943986  0.22247706  0.47789584 ... -0.60876143  0.79335334
#   -0.60876143]
#  [ 0.15662651  0.25091743  0.38606848 ... -0.79335334  0.60876143
#   -0.79335334]
#  [ 0.14986261  0.26284404  0.36507937 ... -0.92387953  0.38268343
#   -0.92387953]
#  ...
#  [ 0.90488269 -0.45504587  0.95539814 ...  0.5        -0.8660254
#    0.5       ]
#  [ 0.91460579 -0.4559633   0.96326905 ...  0.70710678 -0.70710678
#    0.70710678]
#  [ 0.92263792 -0.44495413  0.96851633 ...  0.8660254  -0.5
#    0.8660254 ]]

# %%
# Let's take a look at the shape
print(shifted_df_as_np.shape)
print(shifted_df_val_as_np.shape)
# Out:
# (42088, 133)
# (10517, 133)

# %% [markdown]
# We have quite a few rows and 28 columns. That is, 4 targets in the first 4 columns plus $4*k$ columns which equals 24 in this case because we set $k$ to be equal to 6. Now we need to divide this into our `X` and `y` variables. For `X` we will take all columns but the first 4 and for `y` we will take just the first 4:

# %%
# We define X and y as mentioned
X_train = shifted_df_as_np[:, 5:]
y_train = shifted_df_as_np[:, :5]

X_test = shifted_df_val_as_np[:, 5:]
y_test = shifted_df_val_as_np[:, :5]
# Print the shapes to inspect them
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (42088, 128) (42088, 5)
# (10517, 128) (10517, 5)

# %% [markdown]
# The dimension match perfectly for Xs and their respective ys. Now we can reshape the data in the following way:

# %%
# We essentially want number_of_samples, lookback_size(k), and number of features for the Xs
X_train = X_train.reshape(-1, lookback, 16)
X_test = X_test.reshape(-1, lookback, 16)
#X_test = X_test.reshape(-1, lookback, 7)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (42088, 8, 16) (10517, 8, 16)
# (42088, 5) (10517, 5)

# %%
# Pytorch only deals with tensors, so we need to convert these last np arrays into torch floats:
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

print(X_train.shape, y_train.shape) #, y_train.shape, y_test.shape) # Inspect the shape once again
print(X_test.shape, y_test.shape) #, y_train.shape, y_test.shape) # Inspect the shape once again
# Out:
# torch.Size([42088, 8, 16]) torch.Size([42088, 5])
# torch.Size([10517, 8, 16]) torch.Size([10517, 5])

# %% [markdown]
# Everything looks good now. The next steps are easy since we've already done a lot of pre-processing legwork. Essentially, we just need to pass our Xs and ys into a Dataset class and then wrap the Dataset class into a DataLoader object that will batch our data nicely:

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset): # Nothing fancy here, just making sure we can access length and individual items
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]
    
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
from torch.utils.data import DataLoader

batch_size = batch_size # We will try batch_size values of 64 and 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) 
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([64, 8, 16]) torch.Size([64, 5])

# %% [markdown]
# Great, the first dimension of both X and y now correspond to batch length, not number of n_rows * n_columns. This means that the batching has worked well. Let's verify the same for the validation dataloader (here defined as test_loader):

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([64, 8, 16]) torch.Size([64, 5])

# %% [markdown]
# All good. At long last, we can now define our model class. This next part is a bit finicky in standard PyTorch, compared to Lightning or even TensorFlow, as we need to initialize the hidden state `h0` cell state `c0`. That said, since our model is not too complex, we can live with it:

# %%
class GRU(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        
        # Store the input parameters as instance variables
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        # Initialize a GRU layer with the given input size, hidden size, and number of stacked layers. Set batch_first to True.
        self.gru = nn.GRU(input_size, hidden_size, num_stacked_layers, 
                            batch_first=True)
               
        # Initialize a linear layer to map the hidden state output from the GRU to a scalar output. The output of this linear layer will be the 4 predicted values.
        self.fc1 = nn.Linear(hidden_size, 5)
    
    def forward(self, x):
        h_n = torch.zeros(self.num_stacked_layers, x.size(0), self.hidden_size)
        # Pass the input through the GRU layer
        h_n = h_n.to(device)
        output, h_n = self.gru(x, h_n)

        # Pass the GRU output through the linear layer
        output = self.fc1(output[:, -1, :])
        
        return output

# Instantiate a new GRU model with input size 4, hidden size 4, and 3 stacked GRU layers
model = GRU(16, 30, 3)

# Move the model to the device specified by the 'device' variable
model.to(device)

# Print the model
print(model)
# Out:
# GRU(
#   (gru): GRU(16, 30, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=30, out_features=5, bias=True)
# )

# %% [markdown]
# Next we will define a standard training loop as a function called `train_and_validate` which will take number of epochs as input:

# %%
def train_and_validate(num_epochs):
    
    ##############
    # TRAINING LOOP #
    #############
      
    # We initialize lists to store training and validation losses and R2s for each epoch   
    model.train(True)
    
    for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}')
        
        # Train the model for one epoch
        running_loss = 0.0  
        running_total = 0.0 
        running_correct = 0.0 
        
        for batch_index, batch in enumerate(train_loader):
            x_batch, y_batch = batch[0].to(device), batch[1].to(device)

            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item() 
            running_total += y_batch.size(0) 

            optimizer.zero_grad()
            loss.backward(retain_graph=False) # We will set this to False for now
            optimizer.step()

            y_pred = output.detach().cpu().numpy()
            y_true = y_batch.detach().cpu().numpy()
            r2 = r2_score(y_true, y_pred)
            running_correct += r2*y_batch.size(0)

            if batch_index % 1000 == 99:  
                avg_loss_across_batches = running_loss / 100
                avg_r2_across_batches = running_correct / running_total
                print('Batch {0}, MAE Loss: {1:.3f}, R2: {2:.3f}'.format(batch_index+1,
                                                                    avg_loss_across_batches,
                                                                    avg_r2_across_batches))
                running_loss = 0.0 
                running_correct = 0.0 
                running_total = 0.0 

        epoch_loss = running_loss / len(train_loader) 
        epoch_r2 = running_correct / running_total
        
        train_losses.append(epoch_loss)
        train_r2s.append(epoch_r2)
        
        print('Epoch Train MAE Loss: {0:.3f}, Epoch Train R2: {1:.3f}'.format(epoch_loss, epoch_r2))  
        print()
        
        ###############
        # VALIDATION LOOP #
        ###############
        
        # Validate the model for one epoch
        model.train(False)

        running_loss = 0.0 
        running_total = 0.0 
        running_correct = 0.0 
        
        for batch_index, batch in enumerate(test_loader):
            x_batch, y_batch = batch[0].to(device), batch[1].to(device)

            with torch.no_grad():
                output = model(x_batch)
                loss = loss_function(output, y_batch)
                running_loss += loss.item()
                running_total += y_batch.size(0)

                y_pred = output.detach().cpu().numpy()
                y_true = y_batch.detach().cpu().numpy()
                r2 = r2_score(y_true, y_pred)
                running_correct += r2*y_batch.size(0)

        avg_loss_across_batches = running_loss / len(test_loader)
        avg_r2_across_batches = running_correct / running_total
        
        val_losses.append(avg_loss_across_batches)
        val_r2s.append(avg_r2_across_batches)
               
        print('Val MAE Loss: {0:.3f}'.format(avg_loss_across_batches))
        print('Val R2 Score: {0:.3f}'.format(avg_r2_across_batches))
        print('***************************************************')
        print()
        
        model.train(True)

# %%
### We're ready to train ! ###
learning_rate = lr
loss_function = nn.L1Loss() 
num_epochs = 50
weight_decay = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) #weight_decay=weight_decay)

train_losses = []
val_losses = []
train_r2s = []
val_r2s = []

train_and_validate(num_epochs = num_epochs)
# Out:
# Epoch: 1
# Batch 100, MAE Loss: 0.130, R2: 0.350
# Epoch Train MAE Loss: 0.046, Epoch Train R2: 0.856
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.825
# ***************************************************
#
# Epoch: 2
# Batch 100, MAE Loss: 0.049, R2: 0.871
# Epoch Train MAE Loss: 0.041, Epoch Train R2: 0.869
#
# Val MAE Loss: 0.078
# Val R2 Score: 0.825
# ***************************************************
#
# Epoch: 3
# Batch 100, MAE Loss: 0.048, R2: 0.873
# Epoch Train MAE Loss: 0.040, Epoch Train R2: 0.871
#
# Val MAE Loss: 0.075
# Val R2 Score: 0.839
# ***************************************************
#
# Epoch: 4
# Batch 100, MAE Loss: 0.047, R2: 0.872
# Epoch Train MAE Loss: 0.040, Epoch Train R2: 0.872
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.826
# ***************************************************
#
# Epoch: 5
# Batch 100, MAE Loss: 0.048, R2: 0.871
# Epoch Train MAE Loss: 0.040, Epoch Train R2: 0.874
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.837
# ***************************************************
#
# Epoch: 6
# Batch 100, MAE Loss: 0.046, R2: 0.879
# Epoch Train MAE Loss: 0.040, Epoch Train R2: 0.873
#
# Val MAE Loss: 0.075
# Val R2 Score: 0.842
# ***************************************************
#
# Epoch: 7
# Batch 100, MAE Loss: 0.047, R2: 0.870
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.876
#
# Val MAE Loss: 0.076
# Val R2 Score: 0.838
# ***************************************************
#
# Epoch: 8
# Batch 100, MAE Loss: 0.047, R2: 0.875
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.875
#
# Val MAE Loss: 0.078
# Val R2 Score: 0.833
# ***************************************************
#
# Epoch: 9
# Batch 100, MAE Loss: 0.046, R2: 0.881
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.875
#
# Val MAE Loss: 0.077
# Val R2 Score: 0.841
# ***************************************************
#
# Epoch: 10
# Batch 100, MAE Loss: 0.046, R2: 0.871
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.877
#
# Val MAE Loss: 0.077
# Val R2 Score: 0.833
# ***************************************************
#
# Epoch: 11
# Batch 100, MAE Loss: 0.046, R2: 0.875
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.876
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.836
# ***************************************************
#
# Epoch: 12
# Batch 100, MAE Loss: 0.046, R2: 0.875
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.878
#
# Val MAE Loss: 0.077
# Val R2 Score: 0.835
# ***************************************************
#
# Epoch: 13
# Batch 100, MAE Loss: 0.046, R2: 0.877
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.877
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.837
# ***************************************************
#
# Epoch: 14
# Batch 100, MAE Loss: 0.045, R2: 0.876
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.877
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.837
# ***************************************************
#
# Epoch: 15
# Batch 100, MAE Loss: 0.045, R2: 0.879
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.878
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.836
# ***************************************************
#
# Epoch: 16
# Batch 100, MAE Loss: 0.045, R2: 0.878
# Epoch Train MAE Loss: 0.039, Epoch Train R2: 0.878
#
# Val MAE Loss: 0.075
# Val R2 Score: 0.839
# ***************************************************
#
# Epoch: 17
# Batch 100, MAE Loss: 0.046, R2: 0.876
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.878
#
# Val MAE Loss: 0.078
# Val R2 Score: 0.839
# ***************************************************
#
# Epoch: 18
# Batch 100, MAE Loss: 0.045, R2: 0.880
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.878
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.837
# ***************************************************
#
# Epoch: 19
# Batch 100, MAE Loss: 0.045, R2: 0.879
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.879
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.836
# ***************************************************
#
# Epoch: 20
# Batch 100, MAE Loss: 0.046, R2: 0.878
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.879
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.837
# ***************************************************
#
# Epoch: 21
# Batch 100, MAE Loss: 0.045, R2: 0.879
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.879
#
# Val MAE Loss: 0.077
# Val R2 Score: 0.835
# ***************************************************
#
# Epoch: 22
# Batch 100, MAE Loss: 0.045, R2: 0.883
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.878
#
# Val MAE Loss: 0.077
# Val R2 Score: 0.838
# ***************************************************
#
# Epoch: 23
# Batch 100, MAE Loss: 0.046, R2: 0.874
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.880
#
# Val MAE Loss: 0.078
# Val R2 Score: 0.837
# ***************************************************
#
# Epoch: 24
# Batch 100, MAE Loss: 0.045, R2: 0.884
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.879
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.837
# ***************************************************
#
# Epoch: 25
# Batch 100, MAE Loss: 0.045, R2: 0.879
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.880
#
# Val MAE Loss: 0.078
# Val R2 Score: 0.830
# ***************************************************
#
# Epoch: 26
# Batch 100, MAE Loss: 0.045, R2: 0.882
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.879
#
# Val MAE Loss: 0.082
# Val R2 Score: 0.825
# ***************************************************
#
# Epoch: 27
# Batch 100, MAE Loss: 0.044, R2: 0.889
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.879
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.836
# ***************************************************
#
# Epoch: 28
# Batch 100, MAE Loss: 0.045, R2: 0.881
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.833
# ***************************************************
#
# Epoch: 29
# Batch 100, MAE Loss: 0.045, R2: 0.881
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.880
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.835
# ***************************************************
#
# Epoch: 30
# Batch 100, MAE Loss: 0.045, R2: 0.880
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.826
# ***************************************************
#
# Epoch: 31
# Batch 100, MAE Loss: 0.044, R2: 0.880
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.834
# ***************************************************
#
# Epoch: 32
# Batch 100, MAE Loss: 0.045, R2: 0.880
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.828
# ***************************************************
#
# Epoch: 33
# Batch 100, MAE Loss: 0.044, R2: 0.885
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.834
# ***************************************************
#
# Epoch: 34
# Batch 100, MAE Loss: 0.045, R2: 0.879
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.882
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.828
# ***************************************************
#
# Epoch: 35
# Batch 100, MAE Loss: 0.043, R2: 0.885
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.832
# ***************************************************
#
# Epoch: 36
# Batch 100, MAE Loss: 0.044, R2: 0.883
# Epoch Train MAE Loss: 0.038, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.830
# ***************************************************
#
# Epoch: 37
# Batch 100, MAE Loss: 0.044, R2: 0.882
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.882
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.829
# ***************************************************
#
# Epoch: 38
# Batch 100, MAE Loss: 0.045, R2: 0.884
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.881
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.831
# ***************************************************
#
# Epoch: 39
# Batch 100, MAE Loss: 0.045, R2: 0.879
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.883
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.830
# ***************************************************
#
# Epoch: 40
# Batch 100, MAE Loss: 0.044, R2: 0.882
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.882
#
# Val MAE Loss: 0.080
# Val R2 Score: 0.829
# ***************************************************
#
# Epoch: 41
# Batch 100, MAE Loss: 0.043, R2: 0.885
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.882
#
# Val MAE Loss: 0.082
# Val R2 Score: 0.827
# ***************************************************
#
# Epoch: 42
# Batch 100, MAE Loss: 0.044, R2: 0.885
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.882
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.833
# ***************************************************
#
# Epoch: 43
# Batch 100, MAE Loss: 0.044, R2: 0.879
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.883
# Val MAE Loss: 0.080
# Val R2 Score: 0.834
# ***************************************************
#
# Epoch: 44
# Batch 100, MAE Loss: 0.043, R2: 0.883
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.882
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.825
# ***************************************************
#
# Epoch: 45
# Batch 100, MAE Loss: 0.044, R2: 0.886
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.882
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.825
# ***************************************************
#
# Epoch: 46
# Batch 100, MAE Loss: 0.044, R2: 0.881
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.883
#
# Val MAE Loss: 0.081
# Val R2 Score: 0.827
# ***************************************************
#
# Epoch: 47
# Batch 100, MAE Loss: 0.043, R2: 0.886
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.883
#
# Val MAE Loss: 0.082
# Val R2 Score: 0.829
# ***************************************************
#
# Epoch: 48
# Batch 100, MAE Loss: 0.043, R2: 0.886
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.883
#
# Val MAE Loss: 0.079
# Val R2 Score: 0.828
# ***************************************************
#
# Epoch: 49
# Batch 100, MAE Loss: 0.044, R2: 0.885
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.883
#
# Val MAE Loss: 0.083
# Val R2 Score: 0.821
# ***************************************************
#
# Epoch: 50
# Batch 100, MAE Loss: 0.044, R2: 0.878
# Epoch Train MAE Loss: 0.037, Epoch Train R2: 0.885
#
# Val MAE Loss: 0.082
# Val R2 Score: 0.826
# ***************************************************

# %%
# We can now plot and save the results

# plot the training and validation loss
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Loss value at every epoch')
plt.xlabel('Epoch (1-50)')
plt.ylabel('Average MAE')

# save the plot to a local directory
dir_path = dir_path
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
plt.savefig(os.path.join(dir_path, 'loss.png'))

# plot the training and validation R2 scores
plt.figure()
plt.plot(train_r2s, label='Training R2')
plt.plot(val_r2s, label='Validation R2')
plt.legend()
plt.title('R2 Score at every epoch')
plt.xlabel('Epoch (1-50)')
plt.ylabel('Average Coefficient of determination (R2) value')

# save the plot to a local directory
plt.savefig(os.path.join(dir_path, 'r2.png'))

# %%
# Find highest training and validation R2 values
highest_train_r2 = max(train_r2s)
highest_val_r2 = max(val_r2s)

# Find lowest training and validation losses
lowest_train_loss = min(train_losses)
lowest_val_loss = min(val_losses)

# %%
# Set directory path and filename for output file
output_dir = dir_path
output_filename = "results.txt"

# Create output directory if it doesn't already exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Open output file for writing
with open(os.path.join(output_dir, output_filename), 'w') as f:
    
    f.write("k was size: " + str(lookback) + "\n")
    f.write("batch was size: " + str(batch_size) + "\n")
    f.write("lr was size: " + str(lr) + "\n")
    
    # Write highest train R2 to file
    f.write("The highest train R2 was: " + str(highest_train_r2) + "\n")
    
    # Write highest val R2 to file
    f.write("The highest val R2 was: " + str(highest_val_r2) + "\n")
    
    # Write lowest train loss to file
    f.write("The lowest train loss was: " + str(lowest_train_loss) + "\n")
    
    # Write lowest val loss to file
    f.write("The lowest val loss was: " + str(lowest_val_loss) + "\n")
    
# Print confirmation message
print("Results saved to " + os.path.join(output_dir, output_filename))
# Out:
# Results saved to C:\Users\usuario\RecogniChess\HW4\Snapshots\GRU\BEST\results.txt

# %% [markdown]
# ## Model Evaluation

# %%
# We import the training data
df2 = pd.read_csv(r"C:\Users\usuario\RecogniChess\HW4\weather_test.csv", header=0, parse_dates=[0])
print(df2.shape)
# Out:
# (14019, 15)

# %%
df2.dropna(inplace=True)
print(df2.shape)
# Out:
# (14019, 15)

# %%
# First, we will turn the first column into a Pandas datetime object
df2['Date Time'] = pd.to_datetime(df2['Date Time'])

# %%
wv = df2['wv (m/s)']
bad_wv = wv == -9999.0
wv[bad_wv] = 0.0

max_wv = df2['max. wv (m/s)']
bad_max_wv = max_wv == -9999.0
max_wv[bad_max_wv] = 0.0

# The above inplace edits are reflected in the DataFrame.
df2['wv (m/s)'].min()

# Let's investigate deeper
df2.describe().transpose()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\3997851901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wv[bad_wv] = 0.0
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\3997851901.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_wv[bad_max_wv] = 0.0
#                    count         mean        std      min       25%      50%  \
# p (mbar)         14019.0   990.732392   8.220120   956.96   985.910   990.96
# T (degC)         14019.0    11.301290   8.092519   -13.67     5.080    11.07
# Tpot (K)         14019.0   285.225804   8.224984   259.15   279.100   284.95
# Tdew (degC)      14019.0     6.576604   6.045940   -15.30     2.030     6.80
# rh (%)           14019.0    75.216103  16.357764    23.64    64.250    78.30
# VPmax (mbar)     14019.0    15.199599   8.514445     2.12     8.775    13.20
# VPact (mbar)     14019.0    10.481350   4.182481     1.85     7.080     9.89
# VPdef (mbar)     14019.0     4.718212   5.661257     0.01     1.090     2.60
# sh (g/kg)        14019.0     6.614139   2.657874     1.15     4.450     6.23
# H2OC (mmol/mol)  14019.0    10.584220   4.235651     1.84     7.130     9.98
# rho (g/m**3)     14019.0  1209.490327  38.656354  1103.79  1181.300  1209.16
# wv (m/s)         14019.0     2.053288   1.544936     0.00     0.930     1.64
# max. wv (m/s)    14019.0     3.435356   2.364410     0.00     1.680     2.80
# wd (deg)         14019.0   177.828951  84.758167     0.11   131.550   201.00
#
#                       75%      max
# p (mbar)          995.960  1015.29
# T (degC)           17.040    37.28
# Tpot (K)          291.030   311.21
# Tdew (degC)        11.350    19.78
# rh (%)             88.800    99.90
# VPmax (mbar)       19.460    63.77
# VPact (mbar)       13.450    23.10
# VPdef (mbar)        6.070    46.01
# sh (g/kg)           8.490    14.76
# H2OC (mmol/mol)    13.570    23.51
# rho (g/m**3)     1235.705  1348.15
# wv (m/s)            2.730    12.05
# max. wv (m/s)       4.600    18.67
# wd (deg)          234.400   359.90

# %%
# Let's investigate deeper
df2.describe().transpose()
# Out:
#                    count         mean        std      min       25%      50%  \
# p (mbar)         14019.0   990.732392   8.220120   956.96   985.910   990.96
# T (degC)         14019.0    11.301290   8.092519   -13.67     5.080    11.07
# Tpot (K)         14019.0   285.225804   8.224984   259.15   279.100   284.95
# Tdew (degC)      14019.0     6.576604   6.045940   -15.30     2.030     6.80
# rh (%)           14019.0    75.216103  16.357764    23.64    64.250    78.30
# VPmax (mbar)     14019.0    15.199599   8.514445     2.12     8.775    13.20
# VPact (mbar)     14019.0    10.481350   4.182481     1.85     7.080     9.89
# VPdef (mbar)     14019.0     4.718212   5.661257     0.01     1.090     2.60
# sh (g/kg)        14019.0     6.614139   2.657874     1.15     4.450     6.23
# H2OC (mmol/mol)  14019.0    10.584220   4.235651     1.84     7.130     9.98
# rho (g/m**3)     14019.0  1209.490327  38.656354  1103.79  1181.300  1209.16
# wv (m/s)         14019.0     2.053288   1.544936     0.00     0.930     1.64
# max. wv (m/s)    14019.0     3.435356   2.364410     0.00     1.680     2.80
# wd (deg)         14019.0   177.828951  84.758167     0.11   131.550   201.00
#
#                       75%      max
# p (mbar)          995.960  1015.29
# T (degC)           17.040    37.28
# Tpot (K)          291.030   311.21
# Tdew (degC)        11.350    19.78
# rh (%)             88.800    99.90
# VPmax (mbar)       19.460    63.77
# VPact (mbar)       13.450    23.10
# VPdef (mbar)        6.070    46.01
# sh (g/kg)           8.490    14.76
# H2OC (mmol/mol)    13.570    23.51
# rho (g/m**3)     1235.705  1348.15
# wv (m/s)            2.730    12.05
# max. wv (m/s)       4.600    18.67
# wd (deg)          234.400   359.90

# %%
# We need to preprocess the variables that are expressed in radians

wv = df2.pop('wv (m/s)')
max_wv = df2.pop('max. wv (m/s)')

# Convert to radians.
wd_rad = df2.pop('wd (deg)')*np.pi / 180

# Calculate the wind x and y components.
df2['Wx'] = wv*np.cos(wd_rad)
df2['Wy'] = wv*np.sin(wd_rad)

# Calculate the max wind x and y components.
df2['max Wx'] = max_wv*np.cos(wd_rad)
df2['max Wy'] = max_wv*np.sin(wd_rad)

# %%
timestamp_s = df2['Date Time'].map(pd.Timestamp.timestamp)

# %%
day = 24*60*60
year = (365.2425)*day

df2['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
df2['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
df2['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
df2['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %%
df2 = df2[df2['Date Time'].dt.year != 2015] # Remove all rows whose year is 2015
df2.reset_index(drop=True, inplace=True) # Reset the index of the resulting dataframe

# %%
plt.plot(np.array(df2['Year sin'])[:365])
plt.plot(np.array(df2['Year cos'])[:365])
plt.xlabel('Time [d]')
plt.title('Time of year signal')
# Out:
# Text(0.5, 1.0, 'Time of year signal')

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rh (%)', 'Wx', 'Wy']
plot_features = df2[plot_cols]
plot_features.index = df2['Date Time']
_ = plot_features.plot(subplots=True)

plot_features = df2[plot_cols][:500]
plot_features.index = pd.DatetimeIndex(df2['Date Time'][:500])
_ = plot_features.plot(subplots=True)

# %%
numeric_cols = df2.select_dtypes(include=[np.number]).columns
test_mean = df2[numeric_cols].mean(numeric_only=True)
test_std = df2[numeric_cols].std(numeric_only=True)

df2[numeric_cols] = (df2[numeric_cols] - test_mean) / test_std

# %%
# Now we MinMax scale every column except the first column
scaler = MinMaxScaler(feature_range=(-1, 1)) # This is the scaler we will use to scale every column to values from 0 to 1
df2 = pd.DataFrame(scaler.fit_transform(df2.iloc[:, 1:]), columns=df2.columns[1:]) # Take all columns except the first

# %%
def prepare_dataframe_for_lstm(df, n_steps):
   
    for i in range(1, n_steps+1):
        df[f'p (mbar)(t-{i})'] = df['p (mbar)'].shift(i)
    
    for i in range(1, n_steps+1):
        df[f'T (degC)(t-{i})'] = df['T (degC)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'rh (%)(t-{i})'] = df['rh (%)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tpot (K)(t-{i})'] = df['Tpot (K)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tdew (degC)(t-{i})'] = df['Tdew (degC)'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'VPmax (mbar)(t-{i})'] = df['VPmax (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPact (mbar)(t-{i})'] = df['VPact (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPdef (mbar)(t-{i})'] = df['VPdef (mbar)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'sh (g/kg)(t-{i})'] = df['sh (g/kg)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'H2OC (mmol/mol)(t-{i})'] = df['H2OC (mmol/mol)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'rho (g/m**3)(t-{i})'] = df['rho (g/m**3)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wx(t-{i})'] = df['Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wy(t-{i})'] = df['Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wx(t-{i})'] = df['max Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wy(t-{i})'] = df['max Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
   
    # Return the shifted dataframe
    return df

# %%
prepare_dataframe_for_lstm(df2, n_steps=lookback)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
#       p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0     0.444197 -0.430952 -0.431170    -0.151826  0.921322     -0.847363
# 1     0.443511 -0.432618 -0.432788    -0.156393  0.913454     -0.847747
# 2     0.441454 -0.455114 -0.454215    -0.183219  0.926567     -0.856951
# 3     0.457912 -0.506769 -0.505963    -0.254566  0.923944     -0.876510
# 4     0.463741 -0.498438 -0.498282    -0.238584  0.939680     -0.873442
# ...        ...       ...       ...          ...       ...           ...
# 8705  0.550489 -0.471360 -0.480089    -0.432648  0.268293     -0.863087
# 8706  0.523744 -0.488856 -0.494239    -0.517123  0.118542     -0.869990
# 8707  0.516544 -0.545095 -0.548413    -0.520548  0.291896     -0.889933
# 8708  0.498028 -0.550927 -0.552456    -0.534817  0.276161     -0.892234
# 8709  0.479513 -0.594251 -0.592480    -0.588470  0.284028     -0.906424
#
#       VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  ...  \
# 0        -0.616981     -0.991234  -0.622305        -0.619048  ...
# 1        -0.619811     -0.990261  -0.625279        -0.622782  ...
# 2        -0.638679     -0.992208  -0.644610        -0.640523  ...
# 3        -0.685849     -0.992695  -0.690706        -0.688142  ...
# 4        -0.675472     -0.994156  -0.680297        -0.677871  ...
# ...            ...           ...        ...              ...  ...
# 8705     -0.788679     -0.923058  -0.793309        -0.790850  ...
# 8706     -0.830189     -0.909910  -0.833457        -0.830999  ...
# 8707     -0.831132     -0.934746  -0.834944        -0.832866  ...
# 8708     -0.837736     -0.933772  -0.840892        -0.838469  ...
# 8709     -0.862264     -0.939615  -0.864684        -0.862745  ...
#
#       Year sin(t-7)  Year sin(t-8)  Year cos(t-1)  Year cos(t-2)  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN       1.000000            NaN
# 2               NaN            NaN       0.965926       1.000000
# 3               NaN            NaN       0.866025       0.965926
# 4               NaN            NaN       0.707107       0.866025
# ...             ...            ...            ...            ...
# 8705      -0.043619       0.216440       0.043619      -0.216440
# 8706      -0.300706      -0.043619       0.300706       0.043619
# 8707      -0.537300      -0.300706       0.537300       0.300706
# 8708      -0.737277      -0.537300       0.737277       0.537300
# 8709      -0.887011      -0.737277       0.887011       0.737277
#
#       Year cos(t-3)  Year cos(t-4)  Year cos(t-5)  Year cos(t-6)  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3          1.000000            NaN            NaN            NaN
# 4          0.965926       1.000000            NaN            NaN
# ...             ...            ...            ...            ...
# 8705      -0.461749      -0.675590      -0.843391      -0.953717
# 8706      -0.216440      -0.461749      -0.675590      -0.843391
# 8707       0.043619      -0.216440      -0.461749      -0.675590
# 8708       0.300706       0.043619      -0.216440      -0.461749
# 8709       0.537300       0.300706       0.043619      -0.216440
#
#       Year cos(t-7)  Year cos(t-8)
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 8705      -0.999048      -0.976296
# 8706      -0.953717      -0.999048
# 8707      -0.843391      -0.953717
# 8708      -0.675590      -0.843391
# 8709      -0.461749      -0.675590
#
# [8710 rows x 147 columns]

# %%
# Define a list of timepoints to group by
timepoints = [f't-{i}' for i in range(lookback, 0, -1)]

# Group the shifted columns by timepoint
all_shifted_cols = []
for timepoint in timepoints:
    columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 
                                                 'Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos' ]] #'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
    all_shifted_cols.extend(columns)
    
# Concatenate the target columns and the grouped columns
target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy']
feature_cols = ['Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos'] # 'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
all_cols = target_cols + feature_cols + all_shifted_cols

# %%
# First we udpate the df
df2 = df2[all_cols]

# %%
shifted_df2 = df2.drop(df2.columns[5:16], axis=1) # We delete the custom features at timpoint t

# %%
shifted_df2 = shifted_df2.dropna()

# %%
# We convert to numpy and print
shifted_df2_as_np = shifted_df2.to_numpy()
print(shifted_df2_as_np)
# Out:
# [[ 0.46511229 -0.47094355  0.95279308 ... -0.25881905  0.96592583
#   -0.25881905]
#  [ 0.47779873 -0.49052281  0.95541568 ... -0.5         0.8660254
#   -0.5       ]
#  [ 0.48397051 -0.4534472   0.95803829 ... -0.70710678  0.70710678
#   -0.70710678]
#  ...
#  [ 0.5165438  -0.54509477  0.29189614 ...  0.53729961 -0.84339145
#    0.53729961]
#  [ 0.49802846 -0.55092689  0.2761605  ...  0.73727734 -0.67559021
#    0.73727734]
#  [ 0.47951312 -0.5942512   0.28402832 ...  0.88701083 -0.46174861
#    0.88701083]]

# %%
X_eval = shifted_df2_as_np[:, 5:]
y_eval = shifted_df2_as_np[:, :5]
print(X_eval.shape, y_eval.shape)
# Out:
# (8702, 128) (8702, 5)

# %%
X_eval = X_eval.reshape(-1, lookback, 16)

print(X_eval.shape)
print(y_eval.shape)
# Out:
# (8702, 8, 16)
# (8702, 5)

# %%
# Pytorch only deals with tensors, so we need to convert these last np arrays into torch floats:
X_eval = torch.tensor(X_train).float()
y_eval = torch.tensor(y_train).float()

print(X_eval.shape, y_eval.shape) #, y_train.shape, y_test.shape) # Inspect the shape once again
# Out:
# torch.Size([42088, 8, 16]) torch.Size([42088, 5])
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\1125268126.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_eval = torch.tensor(X_train).float()
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2928\1125268126.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_eval = torch.tensor(y_train).float()

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset): # Nothing fancy here, just making sure we can access length and individual items
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]
    
eval_dataset = TimeSeriesDataset(X_eval, y_eval)

# %%
from torch.utils.data import DataLoader

batch_size = batch_size # We will try batch_size values of 64 and 32

eval_loader = DataLoader(eval_dataset, batch_size=batch_size, shuffle=True)

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(eval_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([64, 8, 16]) torch.Size([64, 5])

# %%
def evaluate_model(model, dataloader, loss_function, num_epochs):
    model.eval()
    with torch.no_grad():
        for epoch in range(num_epochs):
            running_loss = 0.0
            running_correct = 0.0
            running_total = 0.0

            for batch_index, batch in enumerate(dataloader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                output = model(x_batch)
                loss = loss_function(output, y_batch)
                running_loss += loss.item()
                running_total += y_batch.size(0)

                y_pred = output.detach().cpu().numpy()
                y_true = y_batch.detach().cpu().numpy()
                r2 = r2_score(y_true, y_pred)
                running_correct += r2*y_batch.size(0)

            avg_loss_across_batches = running_loss / len(dataloader)
            avg_r2_across_batches = running_correct / running_total

            test_losses.append(avg_loss_across_batches)
            test_r2s.append(avg_r2_across_batches)

            print('Epoch {0}, Test MAE Loss: {1:.3f}'.format(epoch+1, avg_loss_across_batches))
            print('Epoch {0}, Test R2 Score: {1:.3f}'.format(epoch+1, avg_r2_across_batches))
            print('***************************************************')

    return test_losses, test_r2s

# %%
### We're ready to evaluate ! ###

loss_function = nn.L1Loss() 
num_epochs = 50

test_losses = []
test_r2s = []

evaluate_model(model=model, dataloader = eval_loader, loss_function = loss_function, num_epochs = num_epochs)
# Out:
# Epoch 1, Test MAE Loss: 0.044
# Epoch 1, Test R2 Score: 0.883
# ***************************************************
# Epoch 2, Test MAE Loss: 0.044
# Epoch 2, Test R2 Score: 0.884
# ***************************************************
# Epoch 3, Test MAE Loss: 0.044
# Epoch 3, Test R2 Score: 0.884
# ***************************************************
# Epoch 4, Test MAE Loss: 0.044
# Epoch 4, Test R2 Score: 0.883
# ***************************************************
# Epoch 5, Test MAE Loss: 0.044
# Epoch 5, Test R2 Score: 0.884
# ***************************************************
# Epoch 6, Test MAE Loss: 0.044
# Epoch 6, Test R2 Score: 0.883
# ***************************************************
# Epoch 7, Test MAE Loss: 0.044
# Epoch 7, Test R2 Score: 0.883
# ***************************************************
# Epoch 8, Test MAE Loss: 0.044
# Epoch 8, Test R2 Score: 0.884
# ***************************************************
# Epoch 9, Test MAE Loss: 0.044
# Epoch 9, Test R2 Score: 0.883
# ***************************************************
# Epoch 10, Test MAE Loss: 0.044
# Epoch 10, Test R2 Score: 0.884
# ***************************************************
# Epoch 11, Test MAE Loss: 0.044
# Epoch 11, Test R2 Score: 0.883
# ***************************************************
# Epoch 12, Test MAE Loss: 0.044
# Epoch 12, Test R2 Score: 0.883
# ***************************************************
# Epoch 13, Test MAE Loss: 0.044
# Epoch 13, Test R2 Score: 0.883
# ***************************************************
# Epoch 14, Test MAE Loss: 0.044
# Epoch 14, Test R2 Score: 0.884
# ***************************************************
# Epoch 15, Test MAE Loss: 0.044
# Epoch 15, Test R2 Score: 0.883
# ***************************************************
# Epoch 16, Test MAE Loss: 0.044
# Epoch 16, Test R2 Score: 0.883
# ***************************************************
# Epoch 17, Test MAE Loss: 0.044
# Epoch 17, Test R2 Score: 0.883
# ***************************************************
# Epoch 18, Test MAE Loss: 0.044
# Epoch 18, Test R2 Score: 0.883
# ***************************************************
# Epoch 19, Test MAE Loss: 0.044
# Epoch 19, Test R2 Score: 0.883
# ***************************************************
# Epoch 20, Test MAE Loss: 0.044
# Epoch 20, Test R2 Score: 0.883
# ***************************************************
# Epoch 21, Test MAE Loss: 0.044
# Epoch 21, Test R2 Score: 0.883
# ***************************************************
# Epoch 22, Test MAE Loss: 0.044
# Epoch 22, Test R2 Score: 0.883
# ***************************************************
# Epoch 23, Test MAE Loss: 0.044
# Epoch 23, Test R2 Score: 0.883
# ***************************************************
# Epoch 24, Test MAE Loss: 0.044
# Epoch 24, Test R2 Score: 0.883
# ***************************************************
# Epoch 25, Test MAE Loss: 0.044
# Epoch 25, Test R2 Score: 0.883
# ***************************************************
# Epoch 26, Test MAE Loss: 0.044
# Epoch 26, Test R2 Score: 0.883
# ***************************************************
# Epoch 27, Test MAE Loss: 0.044
# Epoch 27, Test R2 Score: 0.883
# ***************************************************
# Epoch 28, Test MAE Loss: 0.044
# Epoch 28, Test R2 Score: 0.883
# ***************************************************
# Epoch 29, Test MAE Loss: 0.044
# Epoch 29, Test R2 Score: 0.883
# ***************************************************
# Epoch 30, Test MAE Loss: 0.044
# Epoch 30, Test R2 Score: 0.883
# ***************************************************
# Epoch 31, Test MAE Loss: 0.044
# Epoch 31, Test R2 Score: 0.883
# ***************************************************
# Epoch 32, Test MAE Loss: 0.044
# Epoch 32, Test R2 Score: 0.883
# ***************************************************
# Epoch 33, Test MAE Loss: 0.044
# Epoch 33, Test R2 Score: 0.883
# ***************************************************
# Epoch 34, Test MAE Loss: 0.044
# Epoch 34, Test R2 Score: 0.883
# ***************************************************
# Epoch 35, Test MAE Loss: 0.044
# Epoch 35, Test R2 Score: 0.883
# ***************************************************
# Epoch 36, Test MAE Loss: 0.044
# Epoch 36, Test R2 Score: 0.883
# ***************************************************
# Epoch 37, Test MAE Loss: 0.044
# Epoch 37, Test R2 Score: 0.883
# ***************************************************
# Epoch 38, Test MAE Loss: 0.044
# Epoch 38, Test R2 Score: 0.883
# ***************************************************
# Epoch 39, Test MAE Loss: 0.044
# Epoch 39, Test R2 Score: 0.883
# ***************************************************
# Epoch 40, Test MAE Loss: 0.044
# Epoch 40, Test R2 Score: 0.883
# ***************************************************
# Epoch 41, Test MAE Loss: 0.044
# Epoch 41, Test R2 Score: 0.883
# ***************************************************
# Epoch 42, Test MAE Loss: 0.044
# Epoch 42, Test R2 Score: 0.883
# ***************************************************
# Epoch 43, Test MAE Loss: 0.044
# Epoch 43, Test R2 Score: 0.883
# ***************************************************
# Epoch 44, Test MAE Loss: 0.044
# Epoch 44, Test R2 Score: 0.883
# ***************************************************
# Epoch 45, Test MAE Loss: 0.044
# Epoch 45, Test R2 Score: 0.883
# ***************************************************
# Epoch 46, Test MAE Loss: 0.044
# Epoch 46, Test R2 Score: 0.883
# ***************************************************
# Epoch 47, Test MAE Loss: 0.044
# Epoch 47, Test R2 Score: 0.883
# ***************************************************
# Epoch 48, Test MAE Loss: 0.044
# Epoch 48, Test R2 Score: 0.883
# ***************************************************
# Epoch 49, Test MAE Loss: 0.044
# Epoch 49, Test R2 Score: 0.883
# ***************************************************
# Epoch 50, Test MAE Loss: 0.044
# Epoch 50, Test R2 Score: 0.883
# ***************************************************
# ([0.0436906805573354,
#   0.04369084086371048,
#   0.0436902547419343,
#   0.043690850890289686,
#   0.04368757521082565,
#   0.0436923714711311,
#   0.04369066459180555,
#   0.04369432728816854,
#   0.04369544247759784,
#   0.04369165328837999,
#   0.04369221217817086,
#   0.04369392081823392,
#   0.043691253499057156,
#   0.043691324087080624,
#   0.04368995181015922,
#   0.043690811689818525,
#   0.043696498419059086,
#   0.04369473085373549,
#   0.04369508690203577,
#   0.043696423307468826,
#   0.04369267151552312,
#   0.04369475282049288,
#   0.04369392824616838,
#   0.04368870550240064,
#   0.04369219510298007,
#   0.04369119341318187,
#   0.04369028992271532,
#   0.04369470775467103,
#   0.043692017608183496,
#   0.04369430494774982,
#   0.04368891084628989,
#   0.04368941554952537,
#   0.043690350484159576,
#   0.043692158257707635,
#   0.043690666686573655,
#   0.04369191270559392,
#   0.04369084479847759,
#   0.04369191024848755,
#   0.043691045618800044,
#   0.043693199555607555,
#   0.04369319506600997,
#   0.0436988818858351,
#   0.04369648880577196,
#   0.04369795974627092,
#   0.04368867693995451,
#   0.043688293031238494,
#   0.0436916070959126,
#   0.043693123373987106,
#   0.04369293747747198,
#   0.04369142148813578],
#  [0.8831399433438414,
#   0.8836398545868223,
#   0.8835184934595678,
#   0.8832002735312235,
#   0.8835263089312967,
#   0.8831507218240452,
#   0.8833576400438271,
#   0.883514483050262,
#   0.8828182989615889,
#   0.8835940915578491,
#   0.8830742748259075,
#   0.8832587908716578,
#   0.8831603948336686,
#   0.883595938827512,
#   0.8831170197777855,
#   0.883126698446882,
#   0.8832442264552218,
#   0.8831899002244727,
#   0.8829287835314501,
#   0.883119656768416,
#   0.8830314982123949,
#   0.8830192131134013,
#   0.8832593192141225,
#   0.8829688160665724,
#   0.8832606177190399,
#   0.8831909184331568,
#   0.883102031333801,
#   0.8829378947566903,
#   0.8832781240226539,
#   0.8831743464110781,
#   0.8831698797167578,
#   0.8829636151238803,
#   0.8833328124581368,
#   0.883289215968605,
#   0.883178921223908,
#   0.8833011237355776,
#   0.8832843326973449,
#   0.8831930948114649,
#   0.883071385097126,
#   0.8832108835590435,
#   0.8830312663060695,
#   0.883284146437175,
#   0.8829590596265101,
#   0.88314160269286,
#   0.8833957244415191,
#   0.8829875013136764,
#   0.8829865810914238,
#   0.8830725268287157,
#   0.8831367313353133,
#   0.8831378467082935])
