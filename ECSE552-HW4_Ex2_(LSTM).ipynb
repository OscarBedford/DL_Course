# %% [markdown]
# # MODEL 2: LSTM solution

# %% [markdown]
# In this exercise, we are asked to build a `Seq2Vec` model using at least one nn.LSTM() layer. Using the values of a set of features at timepoints $t-k$ through $t-1$, we are asked to predict the following targets at timepoint $t$:
#
# - `p(mbar)`, atmospheric pressure
# - `T (degC)`, air temperature
# - `rh (%)`, relative humidity
# - `wv(m/s)`, wind velocity
#
# For simplicity, we will first initialize this model at  $k=4$. Then, once we get that model working, we will set  `k`  as a hyperparameter and iterate through `{4, 6, 8}`, along with two learning rate values `{0.01, 0.001}` and batch size `{32, 64}` .

# %%
# First we will import the necessary dependencies
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
import torchmetrics
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms
from torch.utils.data import SubsetRandomSampler
import pytorch_lightning as L
import torch.utils.data
import datetime

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

# %%
# We can check the current working directory
import os
print(os.getcwd())

# We determine whether CUDA is available 
if torch.cuda.is_available():
    device = torch.device("cuda")
    print (f"Using GPU: {torch.cuda.get_device_name(device)}")
else: 
    device = torch.device("cpu")
    print (f"Using CPU")

# We empty the cuda cache for good measure and make sure both the cache and the RAM are at zero
torch.cuda.empty_cache()
print(f"CUDA cache used: {torch.cuda.memory_reserved() / 1e6:.1f} MB")
print(f"CUDA RAM used: {torch.cuda.memory_allocated() / 1e6:.1f} MB")
# Out:
# C:\Users\usuario\RecogniChess
# Using GPU: NVIDIA GeForce GTX 960M
# CUDA cache used: 0.0 MB
# CUDA RAM used: 0.0 MB

# %%
############################# 
### HYPERPARAMETER TUNING CELL ###
#############################

dir_path = r'C:\Users\usuario\RecogniChess\HW4\Snapshots\LSTM2\BEST'

# Tweak the value of these HPs when re-running the model
lookback = 8
batch_size = 64
lr = 0.002

# %% [markdown]
# Before we do anything else, we will import the data and take a look at it:

# %%
# We import the training data
df = pd.read_csv(r"C:\Users\usuario\RecogniChess\HW4\weather_train.csv", header=0, parse_dates=[0])
print(df.shape)
# Out:
# (56072, 15)

# %%
df.dropna(inplace=True)
print(df.shape)
# Out:
# (56072, 15)

# %%
# First, we will turn the first column into a Pandas datetime object
df['Date Time'] = pd.to_datetime(df['Date Time'])

# %%
# Let's take a look
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.14          0.19       1.96             3.15
# 1          3.12          2.90          0.21       1.81             2.91
# 2          3.13          2.93          0.20       1.83             2.94
# 3          3.07          2.85          0.23       1.78             2.85
# 4          2.94          2.71          0.23       1.69             2.71
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.86      0.21           0.63     192.7
# 1       1312.25      0.25           0.63     190.3
# 2       1312.18      0.18           0.63     167.2
# 3       1313.61      0.10           0.38     240.0
# 4       1317.19      0.40           0.88     157.0

# %%
df = df.drop(columns=["sh (g/kg)", "H2OC (mmol/mol)", "rho (g/m**3)"])
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0          3.33          3.14          0.19      0.21           0.63     192.7
# 1          3.12          2.90          0.21      0.25           0.63     190.3
# 2          3.13          2.93          0.20      0.18           0.63     167.2
# 3          3.07          2.85          0.23      0.10           0.38     240.0
# 4          2.94          2.71          0.23      0.40           0.88     157.0

# %% [markdown]
# Data looks good, but we need to apply a couple of changes:
# - First, we need to separate out the first column, which doesn't hold feature values but rather keeps time
# - Second, we seriously need to minmax scale the other columns because they're on vastly different scales right now.

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rh (%)', 'wv (m/s)']
plot_features = df[plot_cols]
plot_features.index = df['Date Time']
_ = plot_features.plot(subplots=True)

plot_features = df[plot_cols][:500]
plot_features.index = pd.DatetimeIndex(df['Date Time'][:500])
_ = plot_features.plot(subplots=True)

# %% [markdown]
# Data looks good except fo values after 2015, where there is clearly an anomaly.

# %%
# Let's investigate deeper
df.describe().transpose()
# Out:
#                  count        mean        std     min       25%      50%  \
# p (mbar)       56072.0  988.832928   8.350194  913.60  983.8100  989.240
# T (degC)       56072.0    8.987746   8.440986  -22.76    2.8800    8.970
# Tpot (K)       56072.0  283.059875   8.518036  250.85  277.0000  283.100
# Tdew (degC)    56072.0    4.551409   6.830787  -24.80   -0.1200    4.745
# rh (%)         56072.0   76.208224  16.498261   13.88   65.4975   79.500
# VPmax (mbar)   56072.0   13.170791   7.479040    0.97    7.5200   11.470
# VPact (mbar)   56072.0    9.297106   4.150333    0.81    6.0500    8.575
# VPdef (mbar)   56072.0    3.873606   4.673326    0.00    0.8200    2.090
# wv (m/s)       56072.0    2.149853   1.542047    0.00    1.0100    1.790
# max. wv (m/s)  56072.0    3.558251   2.337514    0.00    1.8000    3.000
# wd (deg)       56072.0  174.029077  87.062724    0.00  123.4000  197.400
#
#                     75%      max
# p (mbar)       994.3100  1013.91
# T (degC)        15.0700    35.65
# Tpot (K)       289.1300   309.73
# Tdew (degC)      9.7325    23.06
# rh (%)          89.6000   100.00
# VPmax (mbar)    17.1600    58.34
# VPact (mbar)    12.0800    28.25
# VPdef (mbar)     5.1000    41.78
# wv (m/s)         2.8900    14.01
# max. wv (m/s)    4.7600    23.50
# wd (deg)       233.9000   360.00

# %%
# We need to preprocess the variables that are expressed in radians

wv = df.pop('wv (m/s)')
max_wv = df.pop('max. wv (m/s)')

# Convert to radians.
wd_rad = df.pop('wd (deg)')*np.pi / 180

# Calculate the wind x and y components.
df['Wx'] = wv*np.cos(wd_rad)
df['Wy'] = wv*np.sin(wd_rad)

# Calculate the max wind x and y components.
df['max Wx'] = max_wv*np.cos(wd_rad)
df['max Wy'] = max_wv*np.sin(wd_rad)

# %%
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0          3.33          3.14          0.19 -0.204862 -0.046168 -0.614587
# 1          3.12          2.90          0.21 -0.245971 -0.044701 -0.619848
# 2          3.13          2.93          0.20 -0.175527  0.039879 -0.614344
# 3          3.07          2.85          0.23 -0.050000 -0.086603 -0.190000
# 4          2.94          2.71          0.23 -0.368202  0.156292 -0.810044
#
#      max Wy
# 0 -0.138503
# 1 -0.112645
# 2  0.139576
# 3 -0.329090
# 4  0.343843

# %%
timestamp_s = df['Date Time'].map(pd.Timestamp.timestamp)

# %%
day = 24*60*60
year = (365.2425)*day

df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %%
plt.plot(np.array(df['Day sin'])[:25])
plt.plot(np.array(df['Day cos'])[:25])
plt.xlabel('Time [h]')
plt.title('Time of day signal')
# Out:
# Text(0.5, 1.0, 'Time of day signal')

# %%
plt.plot(np.array(df['Year sin'])[:365])
plt.plot(np.array(df['Year cos'])[:365])
plt.xlabel('Time [d]')
plt.title('Time of year signal')
# Out:
# Text(0.5, 1.0, 'Time of year signal')

# %%
df.tail()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 56067 2015-05-24 14:00:00    991.94     17.16    290.99         9.83   62.00
# 56068 2015-05-24 15:00:00    991.52     17.77    291.64         9.29   57.52
# 56069 2015-05-24 16:00:00    990.96     19.40    293.32         9.07   51.17
# 56070 2015-05-24 17:00:00    990.56     19.03    292.98         9.04   52.25
# 56071 2015-05-24 18:00:00    990.23     18.46    292.44         8.97   53.89
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 56067         19.60         12.15          7.45  2.520849  1.626445  3.865301
# 56068         20.37         11.72          8.66 -0.143727  0.868184 -0.372383
# 56069         22.56         11.55         11.02 -0.495154  0.373125 -1.086144
# 56070         22.05         11.52         10.53 -0.755076 -0.232292 -1.299879
# 56071         21.28         11.47          9.81  0.724710  0.840771  1.710577
#
#          max Wy   Day sin       Day cos  Year sin  Year cos
# 56067  2.493882 -0.500000 -8.660254e-01  0.621029 -0.783787
# 56068  2.249385 -0.707107 -7.071068e-01  0.620467 -0.784232
# 56069  0.818468 -0.866025 -5.000000e-01  0.619905 -0.784677
# 56070 -0.399895 -0.965926 -2.588190e-01  0.619343 -0.785121
# 56071  1.984522 -1.000000 -2.947092e-12  0.618780 -0.785565

# %%
df = df[df['Date Time'].dt.year != 2015] # Remove all rows whose year is 2015
df.reset_index(drop=True, inplace=True) # Reset the index of the resulting dataframe

# %%
# Then, set Date Time as the index variable
df.tail() # We take a look
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 52616 2014-12-31 19:00:00   1006.20      2.27    274.94         1.96    97.8
# 52617 2014-12-31 20:00:00   1006.28      2.14    274.81         1.89    98.2
# 52618 2014-12-31 21:00:00   1006.69      1.96    274.60         1.72    98.3
# 52619 2014-12-31 22:00:00   1006.92      1.94    274.56         1.75    98.6
# 52620 2014-12-31 23:00:00   1007.11      2.18    274.78         2.01    98.8
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 52616          7.19          7.04          0.16 -0.242173  0.414430 -0.645795
# 52617          7.13          7.00          0.13 -0.332780  0.593007 -0.822163
# 52618          7.04          6.92          0.12 -0.550837  0.381417 -1.282545
# 52619          7.03          6.93          0.10 -0.452571  0.547064 -1.147363
# 52620          7.15          7.06          0.09 -0.271231  0.221210 -0.666452
#
#          max Wy   Day sin   Day cos  Year sin  Year cos
# 52616  1.105146 -0.965926  0.258819 -0.002079  0.999998
# 52617  1.465076 -0.866025  0.500000 -0.001362  0.999999
# 52618  0.888076 -0.707107  0.707107 -0.000645  1.000000
# 52619  1.386924 -0.500000  0.866025  0.000072  1.000000
# 52620  0.543545 -0.258819  0.965926  0.000788  1.000000

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rh (%)', 'Wx', 'Wy']
plot_features = df[plot_cols]
plot_features.index = df['Date Time']
_ = plot_features.plot(subplots=True)

plot_features = df[plot_cols][:500]
plot_features.index = pd.DatetimeIndex(df['Date Time'][:500])
_ = plot_features.plot(subplots=True)

# %% [markdown]
# The trimming worked, so we are now ready to create columns containing the prior timepoints:

# %%
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
train_df = df[0:int(n*0.8)]
val_df = df[int(n*0.8):]

num_features = df.shape[1]

# %%
train_df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 1 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 3 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 4 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0          3.33          3.14          0.19 -0.204862 -0.046168 -0.614587
# 1          3.12          2.90          0.21 -0.245971 -0.044701 -0.619848
# 2          3.13          2.93          0.20 -0.175527  0.039879 -0.614344
# 3          3.07          2.85          0.23 -0.050000 -0.086603 -0.190000
# 4          2.94          2.71          0.23 -0.368202  0.156292 -0.810044
#
#      max Wy   Day sin   Day cos  Year sin  Year cos
# 0 -0.138503  0.258819  0.965926  0.010049  0.999950
# 1 -0.112645  0.500000  0.866025  0.010766  0.999942
# 2  0.139576  0.707107  0.707107  0.011483  0.999934
# 3 -0.329090  0.866025  0.500000  0.012199  0.999926
# 4  0.343843  0.965926  0.258819  0.012916  0.999917

# %%
val_df.head()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 42096 2013-10-20 01:30:00    987.36     14.46    288.67        10.89    79.1
# 42097 2013-10-20 02:30:00    987.35     14.27    288.48        10.93    80.3
# 42098 2013-10-20 03:30:00    987.61     13.96    288.15        11.03    82.5
# 42099 2013-10-20 04:30:00    987.66     15.90    290.09        12.38    79.6
# 42100 2013-10-20 05:30:00    987.67     15.04    289.22        12.51    84.8
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 42096         16.49         13.05          3.45 -1.088430  1.159060 -1.834586
# 42097         16.29         13.08          3.21 -1.455654 -0.878107 -1.883788
# 42098         15.97         13.17          2.79 -0.859674  0.230349 -2.009126
# 42099         18.09         14.40          3.69 -2.657367 -1.615704 -4.144125
# 42100         17.12         14.52          2.60 -2.865470 -1.735390 -4.285375
#
#          max Wy   Day sin   Day cos  Year sin  Year cos
# 42096  1.953636  0.382683  0.923880 -0.948685  0.316223
# 42097 -1.136373  0.608761  0.793353 -0.948458  0.316903
# 42098  0.538344  0.793353  0.608761 -0.948231  0.317583
# 42099 -2.519668  0.923880  0.382683 -0.948003  0.318262
# 42100 -2.595315  0.991445  0.130526 -0.947774  0.318942

# %%
numeric_cols = train_df.select_dtypes(include=[np.number]).columns
train_mean = train_df[numeric_cols].mean(numeric_only=True)
train_std = train_df[numeric_cols].std(numeric_only=True)

train_df[numeric_cols] = (train_df[numeric_cols] - train_mean) / train_std
val_df[numeric_cols] = (val_df[numeric_cols] - train_mean) / train_std
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\1788790050.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[numeric_cols] = (train_df[numeric_cols] - train_mean) / train_std
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\1788790050.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df[numeric_cols] = (val_df[numeric_cols] - train_mean) / train_std

# %%
train_df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  \
# 0 2009-01-01 01:00:00  0.933933 -1.930717 -1.989975    -1.855824  1.116628
# 1 2009-01-01 02:00:00  0.948382 -2.024689 -2.084404    -1.994185  1.044124
# 2 2009-01-01 03:00:00  0.974873 -2.016763 -2.078783    -1.978812  1.062250
# 3 2009-01-01 04:00:00  0.992935 -2.043936 -2.106887    -2.029125  1.007872
# 4 2009-01-01 05:00:00  1.049529 -2.109603 -2.176584    -2.117173  0.983704
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0     -1.289666     -1.459553     -0.788278  0.181904  0.222705  0.099683
# 1     -1.316755     -1.516124     -0.784135  0.161361  0.223641  0.097991
# 2     -1.315465     -1.509053     -0.786206  0.196563  0.277578  0.099761
# 3     -1.323204     -1.527910     -0.779993  0.259291  0.196920  0.236239
# 4     -1.339974     -1.560910     -0.779993  0.100280  0.351816  0.036820
#
#      max Wy   Day sin   Day cos  Year sin  Year cos
# 0  0.219956  0.366030  1.365974 -0.006048  1.449683
# 1  0.229785  0.707109  1.224696 -0.005038  1.449672
# 2  0.325662  1.000000  0.999954 -0.004028  1.449661
# 3  0.147509  1.224743  0.707066 -0.003018  1.449649
# 4  0.403309  1.366022  0.365990 -0.002007  1.449636

# %%
val_df.head()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 42096 2013-10-20 01:30:00 -0.166644  0.617844  0.628177     0.893231
# 42097 2013-10-20 02:30:00 -0.167848  0.596332  0.606818     0.898821
# 42098 2013-10-20 03:30:00 -0.136541  0.561235  0.569721     0.912797
# 42099 2013-10-20 04:30:00 -0.130520  0.780880  0.787807     1.101472
# 42100 2013-10-20 05:30:00 -0.129316  0.683511  0.690005     1.119640
#
#          rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy  \
# 42096  0.192197      0.407899      0.876383     -0.113041 -0.259630  0.991289
# 42097  0.264702      0.382100      0.883455     -0.162752 -0.443138 -0.307829
# 42098  0.397626      0.340822      0.904669     -0.249745 -0.145317  0.399042
# 42099  0.222407      0.614289      1.194598     -0.063330 -1.043654 -0.778200
# 42100  0.536593      0.489165      1.222884     -0.289100 -1.147646 -0.854525
#
#          max Wx    max Wy   Day sin   Day cos  Year sin  Year cos
# 42096 -0.292694  1.015235  0.541199  1.306512 -1.357294  0.478819
# 42097 -0.308518 -0.159361  0.860919  1.121923 -1.356975  0.479785
# 42098 -0.348830  0.477244  1.121970  0.860875 -1.356654  0.480750
# 42099 -1.035489 -0.685189  1.306560  0.541158 -1.356333  0.481715
# 42100 -1.080918 -0.713945  1.402111  0.184559 -1.356011  0.482679

# %%
# Now we MinMax scale every column except the first column
scaler = MinMaxScaler(feature_range=(-1, 1)) # This is the scaler we will use to scale every column to values from 0 to 1
train_df = pd.DataFrame(scaler.fit_transform(train_df.iloc[:, 1:]), columns=train_df.columns[1:]) # Take all columns except the first


# Now we MinMax scale every column except the first column
scaler = MinMaxScaler(feature_range=(-1, 1)) # This is the scaler we will use to scale every column to values from 0 to 1
val_df = pd.DataFrame(scaler.fit_transform(val_df.iloc[:, 1:]), columns=val_df.columns[1:]) # Take all columns except the first

# %%
train_df.head()
# Out:
#    p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0  0.670866 -0.496319 -0.506454    -0.330547  0.869949     -0.917727
# 1  0.673284 -0.524739 -0.534986    -0.371918  0.842081     -0.925048
# 2  0.677718 -0.522342 -0.533288    -0.367321  0.849048     -0.924699
# 3  0.680742 -0.530560 -0.541780    -0.382365  0.828147     -0.926791
# 4  0.690215 -0.550419 -0.562840    -0.408692  0.818857     -0.931323
#
#    VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx    max Wy  \
# 0     -0.830175     -0.990905  0.135604  0.027999  0.205966  0.010418
# 1     -0.847668     -0.989947  0.131399  0.028183  0.205632  0.012190
# 2     -0.845481     -0.990426  0.138605  0.038750  0.205981  0.029474
# 3     -0.851312     -0.988990  0.151447  0.022948  0.232877 -0.002642
# 4     -0.861516     -0.988990  0.118894  0.053294  0.193577  0.043472
#
#     Day sin   Day cos  Year sin  Year cos
# 0  0.258819  0.965926  0.010049  0.999950
# 1  0.500000  0.866025  0.010766  0.999942
# 2  0.707107  0.707107  0.011483  0.999934
# 3  0.866025  0.500000  0.012199  0.999926
# 4  0.965926  0.258819  0.012916  0.999917

# %%
val_df.head()
# Out:
#    p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0  0.087719  0.118349  0.117362     0.404948  0.451659     -0.449141
# 1  0.087297  0.109633  0.108600     0.407454  0.483143     -0.457230
# 2  0.098288  0.095413  0.093383     0.413718  0.540863     -0.470172
# 3  0.100402  0.184404  0.182845     0.498277  0.464778     -0.384429
# 4  0.100824  0.144954  0.142725     0.506420  0.601207     -0.423660
#
#    VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx    max Wy  \
# 0     -0.019553     -0.819419  0.133799  0.246318  0.063859  0.284864
# 1     -0.016760     -0.831981  0.092473 -0.046815  0.060318 -0.004249
# 2     -0.008380     -0.853965  0.159543  0.112683  0.051300  0.152444
# 3      0.106145     -0.806857 -0.042765 -0.152950 -0.102319 -0.133675
# 4      0.117318     -0.863910 -0.066185 -0.170172 -0.112482 -0.140753
#
#     Day sin   Day cos  Year sin  Year cos
# 0  0.382683  0.923880 -0.948685  0.316223
# 1  0.608761  0.793353 -0.948458  0.316903
# 2  0.793353  0.608761 -0.948231  0.317583
# 3  0.923880  0.382683 -0.948003  0.318262
# 4  0.991445  0.130526 -0.947774  0.318942

# %%
# Calculate standardized values for all columns except the first
df_std = (df.iloc[:,1:] - train_mean) / train_std
df_std = df_std.melt(var_name='Column', value_name='Normalized')

# Plot violin plot
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
_ = ax.set_xticklabels(df.columns[1:], rotation=90)

# %%
column_names = train_df.columns.tolist()
print(column_names)
# Out:
# ['p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)', 'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'Wx', 'Wy', 'max Wx', 'max Wy', 'Day sin', 'Day cos', 'Year sin', 'Year cos']

# %%
def prepare_dataframe_for_lstm(df, n_steps):
   
    for i in range(1, n_steps+1):
        df[f'p (mbar)(t-{i})'] = df['p (mbar)'].shift(i)
    
    for i in range(1, n_steps+1):
        df[f'T (degC)(t-{i})'] = df['T (degC)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'rh (%)(t-{i})'] = df['rh (%)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tpot (K)(t-{i})'] = df['Tpot (K)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tdew (degC)(t-{i})'] = df['Tdew (degC)'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'VPmax (mbar)(t-{i})'] = df['VPmax (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPact (mbar)(t-{i})'] = df['VPact (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPdef (mbar)(t-{i})'] = df['VPdef (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wx(t-{i})'] = df['Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wy(t-{i})'] = df['Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wx(t-{i})'] = df['max Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wy(t-{i})'] = df['max Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
   
    # Return the shifted dataframe
    return df

# %%
prepare_dataframe_for_lstm(train_df, n_steps=lookback)
prepare_dataframe_for_lstm(val_df, n_steps=lookback)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\423097190.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0      0.087719  0.118349  0.117362     0.404948  0.451659     -0.449141
# 1      0.087297  0.109633  0.108600     0.407454  0.483143     -0.457230
# 2      0.098288  0.095413  0.093383     0.413718  0.540863     -0.470172
# 3      0.100402  0.184404  0.182845     0.498277  0.464778     -0.384429
# 4      0.100824  0.144954  0.142725     0.506420  0.601207     -0.423660
# ...         ...       ...       ...          ...       ...           ...
# 10520  0.884168 -0.440826 -0.515794    -0.154400  0.942280     -0.825278
# 10521  0.887550 -0.446789 -0.521789    -0.158785  0.952774     -0.827705
# 10522  0.904883 -0.455046 -0.531473    -0.169433  0.955398     -0.831345
# 10523  0.914606 -0.455963 -0.533318    -0.167554  0.963269     -0.831749
# 10524  0.922638 -0.444954 -0.523173    -0.151268  0.968516     -0.826896
#
#        VPact (mbar)  VPdef (mbar)        Wx        Wy  ...  Year sin(t-7)  \
# 0         -0.019553     -0.819419  0.133799  0.246318  ...            NaN
# 1         -0.016760     -0.831981  0.092473 -0.046815  ...            NaN
# 2         -0.008380     -0.853965  0.159543  0.112683  ...            NaN
# 3          0.106145     -0.806857 -0.042765 -0.152950  ...            NaN
# 4          0.117318     -0.863910 -0.066185 -0.170172  ...            NaN
# ...             ...           ...       ...       ...  ...            ...
# 10520     -0.579143     -0.991625  0.229035  0.139171  ...   8.192870e-12
# 10521     -0.582868     -0.993195  0.218839  0.164867  ...  -2.588190e-01
# 10522     -0.590317     -0.993719  0.194299  0.134421  ...  -5.000000e-01
# 10523     -0.589385     -0.994766  0.205358  0.158256  ...  -7.071068e-01
# 10524     -0.577281     -0.995289  0.225765  0.111368  ...  -8.660254e-01
#
#        Year sin(t-8)  Year cos(t-1)  Year cos(t-2)  Year cos(t-3)  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN   9.238795e-01            NaN            NaN
# 2                NaN   7.933533e-01   9.238795e-01            NaN
# 3                NaN   6.087614e-01   7.933533e-01   9.238795e-01
# 4                NaN   3.826834e-01   6.087614e-01   7.933533e-01
# ...              ...            ...            ...            ...
# 10520   2.588190e-01  -1.075618e-11  -2.588190e-01  -5.000000e-01
# 10521   8.192870e-12   2.588190e-01  -1.075618e-11  -2.588190e-01
# 10522  -2.588190e-01   5.000000e-01   2.588190e-01  -1.075618e-11
# 10523  -5.000000e-01   7.071068e-01   5.000000e-01   2.588190e-01
# 10524  -7.071068e-01   8.660254e-01   7.071068e-01   5.000000e-01
#
#        Year cos(t-4)  Year cos(t-5)  Year cos(t-6)  Year cos(t-7)  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4       9.238795e-01            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 10520  -7.071068e-01  -8.660254e-01      -0.965926      -1.000000
# 10521  -5.000000e-01  -7.071068e-01      -0.866025      -0.965926
# 10522  -2.588190e-01  -5.000000e-01      -0.707107      -0.866025
# 10523  -1.075618e-11  -2.588190e-01      -0.500000      -0.707107
# 10524   2.588190e-01  -1.075618e-11      -0.258819      -0.500000
#
#        Year cos(t-8)
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 10520      -0.965926
# 10521      -1.000000
# 10522      -0.965926
# 10523      -0.866025
# 10524      -0.707107
#
# [10525 rows x 144 columns]

# %% [markdown]
# That worked, but the problem is that columns are ordered from $t-1$ to $t-k$, which is the opposite direction we want. We want to feed the furthest timepoints first and end with the most recent timepoint. Moreover, as it stands, columns are ordered by feature, not by timepoint, so we need to fix these two things:

# %%
# Define a list of timepoints to group by
timepoints = [f't-{i}' for i in range(lookback, 0, -1)]

# Group the shifted columns by timepoint
all_shifted_cols = []
for timepoint in timepoints:
    columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 
                                                 'Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos' ]] #'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
    all_shifted_cols.extend(columns)
    
# Concatenate the target columns and the grouped columns
target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy']
feature_cols = ['Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos'] # 'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
all_cols = target_cols + feature_cols + all_shifted_cols

# %%
# Let us take a look at the final variable 'all_cols'
all_cols
# Out:
# ['p (mbar)',
#  'T (degC)',
#  'rh (%)',
#  'Wx',
#  'Wy',
#  'Tpot (K)',
#  'Tdew (degC)',
#  'VPmax (mbar)',
#  'VPact (mbar)',
#  'VPdef (mbar)',
#  'max Wx',
#  'max Wy',
#  'Day sin',
#  'Day cos',
#  'Year sin',
#  'Year cos',
#  'p (mbar)(t-8)',
#  'T (degC)(t-8)',
#  'rh (%)(t-8)',
#  'Wx(t-8)',
#  'Wy(t-8)',
#  'Tpot (K)(t-8)',
#  'Tdew (degC)(t-8)',
#  'VPmax (mbar)(t-8)',
#  'VPact (mbar)(t-8)',
#  'VPdef (mbar)(t-8)',
#  'max Wx(t-8)',
#  'max Wy(t-8)',
#  'Day sin(t-8)',
#  'Day cos(t-8)',
#  'Year sin(t-8)',
#  'Year cos(t-8)',
#  'p (mbar)(t-7)',
#  'T (degC)(t-7)',
#  'rh (%)(t-7)',
#  'Wx(t-7)',
#  'Wy(t-7)',
#  'Tpot (K)(t-7)',
#  'Tdew (degC)(t-7)',
#  'VPmax (mbar)(t-7)',
#  'VPact (mbar)(t-7)',
#  'VPdef (mbar)(t-7)',
#  'max Wx(t-7)',
#  'max Wy(t-7)',
#  'Day sin(t-7)',
#  'Day cos(t-7)',
#  'Year sin(t-7)',
#  'Year cos(t-7)',
#  'p (mbar)(t-6)',
#  'T (degC)(t-6)',
#  'rh (%)(t-6)',
#  'Wx(t-6)',
#  'Wy(t-6)',
#  'Tpot (K)(t-6)',
#  'Tdew (degC)(t-6)',
#  'VPmax (mbar)(t-6)',
#  'VPact (mbar)(t-6)',
#  'VPdef (mbar)(t-6)',
#  'max Wx(t-6)',
#  'max Wy(t-6)',
#  'Day sin(t-6)',
#  'Day cos(t-6)',
#  'Year sin(t-6)',
#  'Year cos(t-6)',
#  'p (mbar)(t-5)',
#  'T (degC)(t-5)',
#  'rh (%)(t-5)',
#  'Wx(t-5)',
#  'Wy(t-5)',
#  'Tpot (K)(t-5)',
#  'Tdew (degC)(t-5)',
#  'VPmax (mbar)(t-5)',
#  'VPact (mbar)(t-5)',
#  'VPdef (mbar)(t-5)',
#  'max Wx(t-5)',
#  'max Wy(t-5)',
#  'Day sin(t-5)',
#  'Day cos(t-5)',
#  'Year sin(t-5)',
#  'Year cos(t-5)',
#  'p (mbar)(t-4)',
#  'T (degC)(t-4)',
#  'rh (%)(t-4)',
#  'Wx(t-4)',
#  'Wy(t-4)',
#  'Tpot (K)(t-4)',
#  'Tdew (degC)(t-4)',
#  'VPmax (mbar)(t-4)',
#  'VPact (mbar)(t-4)',
#  'VPdef (mbar)(t-4)',
#  'max Wx(t-4)',
#  'max Wy(t-4)',
#  'Day sin(t-4)',
#  'Day cos(t-4)',
#  'Year sin(t-4)',
#  'Year cos(t-4)',
#  'p (mbar)(t-3)',
#  'T (degC)(t-3)',
#  'rh (%)(t-3)',
#  'Wx(t-3)',
#  'Wy(t-3)',
#  'Tpot (K)(t-3)',
#  'Tdew (degC)(t-3)',
#  'VPmax (mbar)(t-3)',
#  'VPact (mbar)(t-3)',
#  'VPdef (mbar)(t-3)',
#  'max Wx(t-3)',
#  'max Wy(t-3)',
#  'Day sin(t-3)',
#  'Day cos(t-3)',
#  'Year sin(t-3)',
#  'Year cos(t-3)',
#  'p (mbar)(t-2)',
#  'T (degC)(t-2)',
#  'rh (%)(t-2)',
#  'Wx(t-2)',
#  'Wy(t-2)',
#  'Tpot (K)(t-2)',
#  'Tdew (degC)(t-2)',
#  'VPmax (mbar)(t-2)',
#  'VPact (mbar)(t-2)',
#  'VPdef (mbar)(t-2)',
#  'max Wx(t-2)',
#  'max Wy(t-2)',
#  'Day sin(t-2)',
#  'Day cos(t-2)',
#  'Year sin(t-2)',
#  'Year cos(t-2)',
#  'p (mbar)(t-1)',
#  'T (degC)(t-1)',
#  'rh (%)(t-1)',
#  'Wx(t-1)',
#  'Wy(t-1)',
#  'Tpot (K)(t-1)',
#  'Tdew (degC)(t-1)',
#  'VPmax (mbar)(t-1)',
#  'VPact (mbar)(t-1)',
#  'VPdef (mbar)(t-1)',
#  'max Wx(t-1)',
#  'max Wy(t-1)',
#  'Day sin(t-1)',
#  'Day cos(t-1)',
#  'Year sin(t-1)',
#  'Year cos(t-1)']

# %% [markdown]
# Feature columns are now grouped by tiempoint and the direction of time has been flipped. Good progress, but now we must delete the custom features at timepoint $t$, as we are not allowed to use current timepoints.

# %%
# First we udpate the df
train_df = train_df[all_cols]
val_df = val_df[all_cols]

# %%
train_df.head()
# Out:
#    p (mbar)  T (degC)    rh (%)        Wx        Wy  Tpot (K)  Tdew (degC)  \
# 0  0.670866 -0.496319  0.869949  0.135604  0.027999 -0.506454    -0.330547
# 1  0.673284 -0.524739  0.842081  0.131399  0.028183 -0.534986    -0.371918
# 2  0.677718 -0.522342  0.849048  0.138605  0.038750 -0.533288    -0.367321
# 3  0.680742 -0.530560  0.828147  0.151447  0.022948 -0.541780    -0.382365
# 4  0.690215 -0.550419  0.818857  0.118894  0.053294 -0.562840    -0.408692
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  ...  Tdew (degC)(t-1)  \
# 0     -0.917727     -0.830175     -0.990905  ...               NaN
# 1     -0.925048     -0.847668     -0.989947  ...         -0.330547
# 2     -0.924699     -0.845481     -0.990426  ...         -0.371918
# 3     -0.926791     -0.851312     -0.988990  ...         -0.367321
# 4     -0.931323     -0.861516     -0.988990  ...         -0.382365
#
#    VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 0                NaN                NaN                NaN          NaN
# 1          -0.917727          -0.830175          -0.990905     0.205966
# 2          -0.925048          -0.847668          -0.989947     0.205632
# 3          -0.924699          -0.845481          -0.990426     0.205981
# 4          -0.926791          -0.851312          -0.988990     0.232877
#
#    max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0          NaN           NaN           NaN            NaN            NaN
# 1     0.010418      0.258819      0.965926       0.258819       0.965926
# 2     0.012190      0.500000      0.866025       0.500000       0.866025
# 3     0.029474      0.707107      0.707107       0.707107       0.707107
# 4    -0.002642      0.866025      0.500000       0.866025       0.500000
#
# [5 rows x 144 columns]

# %%
val_df.head()
# Out:
#    p (mbar)  T (degC)    rh (%)        Wx        Wy  Tpot (K)  Tdew (degC)  \
# 0  0.087719  0.118349  0.451659  0.133799  0.246318  0.117362     0.404948
# 1  0.087297  0.109633  0.483143  0.092473 -0.046815  0.108600     0.407454
# 2  0.098288  0.095413  0.540863  0.159543  0.112683  0.093383     0.413718
# 3  0.100402  0.184404  0.464778 -0.042765 -0.152950  0.182845     0.498277
# 4  0.100824  0.144954  0.601207 -0.066185 -0.170172  0.142725     0.506420
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  ...  Tdew (degC)(t-1)  \
# 0     -0.449141     -0.019553     -0.819419  ...               NaN
# 1     -0.457230     -0.016760     -0.831981  ...          0.404948
# 2     -0.470172     -0.008380     -0.853965  ...          0.407454
# 3     -0.384429      0.106145     -0.806857  ...          0.413718
# 4     -0.423660      0.117318     -0.863910  ...          0.498277
#
#    VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 0                NaN                NaN                NaN          NaN
# 1          -0.449141          -0.019553          -0.819419     0.063859
# 2          -0.457230          -0.016760          -0.831981     0.060318
# 3          -0.470172          -0.008380          -0.853965     0.051300
# 4          -0.384429           0.106145          -0.806857    -0.102319
#
#    max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0          NaN           NaN           NaN            NaN            NaN
# 1     0.284864      0.382683      0.923880       0.382683       0.923880
# 2    -0.004249      0.608761      0.793353       0.608761       0.793353
# 3     0.152444      0.793353      0.608761       0.793353       0.608761
# 4    -0.133675      0.923880      0.382683       0.923880       0.382683
#
# [5 rows x 144 columns]

# %%
print(train_df.columns[:60])
# Out:
# Index(['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 'Tpot (K)', 'Tdew (degC)',
#        'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'max Wx', 'max Wy',
#        'Day sin', 'Day cos', 'Year sin', 'Year cos', 'p (mbar)(t-8)',
#        'T (degC)(t-8)', 'rh (%)(t-8)', 'Wx(t-8)', 'Wy(t-8)', 'Tpot (K)(t-8)',
#        'Tdew (degC)(t-8)', 'VPmax (mbar)(t-8)', 'VPact (mbar)(t-8)',
#        'VPdef (mbar)(t-8)', 'max Wx(t-8)', 'max Wy(t-8)', 'Day sin(t-8)',
#        'Day cos(t-8)', 'Year sin(t-8)', 'Year cos(t-8)', 'p (mbar)(t-7)',
#        'T (degC)(t-7)', 'rh (%)(t-7)', 'Wx(t-7)', 'Wy(t-7)', 'Tpot (K)(t-7)',
#        'Tdew (degC)(t-7)', 'VPmax (mbar)(t-7)', 'VPact (mbar)(t-7)',
#        'VPdef (mbar)(t-7)', 'max Wx(t-7)', 'max Wy(t-7)', 'Day sin(t-7)',
#        'Day cos(t-7)', 'Year sin(t-7)', 'Year cos(t-7)', 'p (mbar)(t-6)',
#        'T (degC)(t-6)', 'rh (%)(t-6)', 'Wx(t-6)', 'Wy(t-6)', 'Tpot (K)(t-6)',
#        'Tdew (degC)(t-6)', 'VPmax (mbar)(t-6)', 'VPact (mbar)(t-6)',
#        'VPdef (mbar)(t-6)', 'max Wx(t-6)', 'max Wy(t-6)'],
#       dtype='object')

# %%
print(val_df.columns[:60])
# Out:
# Index(['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 'Tpot (K)', 'Tdew (degC)',
#        'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'max Wx', 'max Wy',
#        'Day sin', 'Day cos', 'Year sin', 'Year cos', 'p (mbar)(t-8)',
#        'T (degC)(t-8)', 'rh (%)(t-8)', 'Wx(t-8)', 'Wy(t-8)', 'Tpot (K)(t-8)',
#        'Tdew (degC)(t-8)', 'VPmax (mbar)(t-8)', 'VPact (mbar)(t-8)',
#        'VPdef (mbar)(t-8)', 'max Wx(t-8)', 'max Wy(t-8)', 'Day sin(t-8)',
#        'Day cos(t-8)', 'Year sin(t-8)', 'Year cos(t-8)', 'p (mbar)(t-7)',
#        'T (degC)(t-7)', 'rh (%)(t-7)', 'Wx(t-7)', 'Wy(t-7)', 'Tpot (K)(t-7)',
#        'Tdew (degC)(t-7)', 'VPmax (mbar)(t-7)', 'VPact (mbar)(t-7)',
#        'VPdef (mbar)(t-7)', 'max Wx(t-7)', 'max Wy(t-7)', 'Day sin(t-7)',
#        'Day cos(t-7)', 'Year sin(t-7)', 'Year cos(t-7)', 'p (mbar)(t-6)',
#        'T (degC)(t-6)', 'rh (%)(t-6)', 'Wx(t-6)', 'Wy(t-6)', 'Tpot (K)(t-6)',
#        'Tdew (degC)(t-6)', 'VPmax (mbar)(t-6)', 'VPact (mbar)(t-6)',
#        'VPdef (mbar)(t-6)', 'max Wx(t-6)', 'max Wy(t-6)'],
#       dtype='object')

# %%
shifted_df = train_df.drop(train_df.columns[5:16], axis=1) # We delete the custom features at timpoint t
shifted_df_val = val_df.drop(val_df.columns[5:16], axis=1) # We delete the custom features at timpoint t

# %%
shifted_df.head()
shifted_df_val.head()
# Out:
#    p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 0  0.087719  0.118349  0.451659  0.133799  0.246318            NaN
# 1  0.087297  0.109633  0.483143  0.092473 -0.046815            NaN
# 2  0.098288  0.095413  0.540863  0.159543  0.112683            NaN
# 3  0.100402  0.184404  0.464778 -0.042765 -0.152950            NaN
# 4  0.100824  0.144954  0.601207 -0.066185 -0.170172            NaN
#
#    T (degC)(t-8)  rh (%)(t-8)  Wx(t-8)  Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 0            NaN          NaN      NaN      NaN  ...               NaN
# 1            NaN          NaN      NaN      NaN  ...          0.404948
# 2            NaN          NaN      NaN      NaN  ...          0.407454
# 3            NaN          NaN      NaN      NaN  ...          0.413718
# 4            NaN          NaN      NaN      NaN  ...          0.498277
#
#    VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 0                NaN                NaN                NaN          NaN
# 1          -0.449141          -0.019553          -0.819419     0.063859
# 2          -0.457230          -0.016760          -0.831981     0.060318
# 3          -0.470172          -0.008380          -0.853965     0.051300
# 4          -0.384429           0.106145          -0.806857    -0.102319
#
#    max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0          NaN           NaN           NaN            NaN            NaN
# 1     0.284864      0.382683      0.923880       0.382683       0.923880
# 2    -0.004249      0.608761      0.793353       0.608761       0.793353
# 3     0.152444      0.793353      0.608761       0.793353       0.608761
# 4    -0.133675      0.923880      0.382683       0.923880       0.382683
#
# [5 rows x 133 columns]

# %%
shifted_df = shifted_df.dropna()
shifted_df_val = shifted_df_val.dropna()

# %%
shifted_df.head()
# Out:
#     p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 8   0.735161 -0.482965  0.795634  0.124358  0.017717       0.670866
# 9   0.746851 -0.461736  0.804923  0.213567 -0.133479       0.673284
# 10  0.758944 -0.474405  0.784022  0.155198 -0.204854       0.677718
# 11  0.747455 -0.455915  0.758477 -0.031117  0.016131       0.680742
# 12  0.742014 -0.422359  0.735253  0.098723  0.024719       0.690215
#
#     T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 8       -0.496319     0.869949  0.135604  0.027999  ...         -0.341830
# 9       -0.524739     0.842081  0.131399  0.028183  ...         -0.333055
# 10      -0.522342     0.849048  0.138605  0.038750  ...         -0.305056
# 11      -0.530560     0.828147  0.151447  0.022948  ...         -0.325533
# 12      -0.550419     0.818857  0.118894  0.053294  ...         -0.309653
#
#     VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 8           -0.918424          -0.835277          -0.988511     0.179160
# 9           -0.914241          -0.830904          -0.985639     0.207949
# 10          -0.908314          -0.818513          -0.985639     0.317992
# 11          -0.911801          -0.827988          -0.984203     0.243424
# 12          -0.906920          -0.820700          -0.981809     0.078716
#
#     max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 8     -0.027867  8.660254e-01     -0.500000   8.660254e-01      -0.500000
# 9      0.003597  7.071068e-01     -0.707107   7.071068e-01      -0.707107
# 10    -0.169885  5.000000e-01     -0.866025   5.000000e-01      -0.866025
# 11    -0.211706  2.588190e-01     -0.965926   2.588190e-01      -0.965926
# 12     0.006082  6.903299e-12     -1.000000   6.903299e-12      -1.000000
#
# [5 rows x 133 columns]

# %%
shifted_df_val.head()
# Out:
#     p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 8   0.149440  0.222477  0.477896 -0.091436 -0.191852       0.087719
# 9   0.156627  0.250917  0.386068 -0.354008 -0.163510       0.087297
# 10  0.149863  0.262844  0.365079 -0.187159 -0.019420       0.098288
# 11  0.125343  0.228440  0.451659 -0.014054  0.202624       0.100402
# 12  0.132107  0.231651  0.456907  0.032462  0.089032       0.100824
#
#     T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 8        0.118349     0.451659  0.133799  0.246318  ...          0.473223
# 9        0.109633     0.483143  0.092473 -0.046815  ...          0.555277
# 10       0.095413     0.540863  0.159543  0.112683  ...          0.549640
# 11       0.184404     0.464778 -0.042765 -0.152950  ...          0.555277
# 12       0.144954     0.601207 -0.066185 -0.170172  ...          0.550893
#
#     VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 8           -0.477452           0.070764          -0.907354    -0.015788
# 9           -0.344388           0.188082          -0.801099    -0.237115
# 10          -0.313650           0.180633          -0.757132    -0.307691
# 11          -0.300303           0.189013          -0.744569    -0.235096
# 12          -0.337917           0.182495          -0.789584    -0.088829
#
#     max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 8      0.261613      0.793353     -0.608761       0.793353      -0.608761
# 9     -0.241596      0.608761     -0.793353       0.608761      -0.793353
# 10    -0.101872      0.382683     -0.923880       0.382683      -0.923880
# 11     0.004270      0.130526     -0.991445       0.130526      -0.991445
# 12     0.233896     -0.130526     -0.991445      -0.130526      -0.991445
#
# [5 rows x 133 columns]

# %% [markdown]
# That looks good. The first four columns contain our targets at timepoint $t$. Then, the other columns contain the $t-k$ ... $t-1$ values for each target variable. We're not done yet, though. Now we can turn this data into a Numpy array:

# %%
# We convert to numpy and print
shifted_df_as_np = shifted_df.to_numpy()
shifted_df_val_as_np = shifted_df_val.to_numpy()
print(shifted_df_as_np)
print(shifted_df_val_as_np)
# Out:
# [[ 0.73516074 -0.48296525  0.795634   ... -0.5         0.8660254
#   -0.5       ]
#  [ 0.74685075 -0.461736    0.80492336 ... -0.70710678  0.70710678
#   -0.70710678]
#  [ 0.75894387 -0.47440507  0.78402229 ... -0.8660254   0.5
#   -0.8660254 ]
#  ...
#  [ 0.48503477  0.24225304  0.46586159 ...  0.79335334 -0.60876143
#    0.79335334]
#  [ 0.47939131  0.25184044  0.48444032 ...  0.92387953 -0.38268343
#    0.92387953]
#  [ 0.48261614  0.27580894  0.47515095 ...  0.99144486 -0.13052619
#    0.99144486]]
# [[ 0.14943986  0.22247706  0.47789584 ... -0.60876143  0.79335334
#   -0.60876143]
#  [ 0.15662651  0.25091743  0.38606848 ... -0.79335334  0.60876143
#   -0.79335334]
#  [ 0.14986261  0.26284404  0.36507937 ... -0.92387953  0.38268343
#   -0.92387953]
#  ...
#  [ 0.90488269 -0.45504587  0.95539814 ...  0.5        -0.8660254
#    0.5       ]
#  [ 0.91460579 -0.4559633   0.96326905 ...  0.70710678 -0.70710678
#    0.70710678]
#  [ 0.92263792 -0.44495413  0.96851633 ...  0.8660254  -0.5
#    0.8660254 ]]

# %%
# Let's take a look at the shape
print(shifted_df_as_np.shape)
print(shifted_df_val_as_np.shape)
# Out:
# (42088, 133)
# (10517, 133)

# %% [markdown]
# We have quite a few rows and 28 columns. That is, 4 targets in the first 4 columns plus $4*k$ columns which equals 24 in this case because we set $k$ to be equal to 6. Now we need to divide this into our `X` and `y` variables. For `X` we will take all columns but the first 4 and for `y` we will take just the first 4:

# %%
# We define X and y as mentioned
X_train = shifted_df_as_np[:, 5:]
y_train = shifted_df_as_np[:, :5]

X_test = shifted_df_val_as_np[:, 5:]
y_test = shifted_df_val_as_np[:, :5]
# Print the shapes to inspect them
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (42088, 128) (42088, 5)
# (10517, 128) (10517, 5)

# %% [markdown]
# The dimension match perfectly for Xs and their respective ys. Now we can reshape the data in the following way:

# %%
# We essentially want number_of_samples, lookback_size(k), and number of features for the Xs
X_train = X_train.reshape(-1, lookback, 16)
X_test = X_test.reshape(-1, lookback, 16)
#X_test = X_test.reshape(-1, lookback, 7)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (42088, 8, 16) (10517, 8, 16)
# (42088, 5) (10517, 5)

# %%
# Pytorch only deals with tensors, so we need to convert these last np arrays into torch floats:
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

print(X_train.shape, y_train.shape) #, y_train.shape, y_test.shape) # Inspect the shape once again
# Out:
# torch.Size([42088, 8, 16]) torch.Size([42088, 5])

# %% [markdown]
# Everything looks good now. The next steps are easy since we've already done a lot of pre-processing legwork. Essentially, we just need to pass our Xs and ys into a Dataset class and then wrap the Dataset class into a DataLoader object that will batch our data nicely:

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset): # Nothing fancy here, just making sure we can access length and individual items
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]
    
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
from torch.utils.data import DataLoader

batch_size = batch_size # We will try batch_size values of 64 and 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) 
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([64, 8, 16]) torch.Size([64, 5])

# %% [markdown]
# Great, the first dimension of both X and y now correspond to batch length, not number of n_rows * n_columns. This means that the batching has worked well. Let's verify the same for the validation dataloader (here defined as test_loader):

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([64, 8, 16]) torch.Size([64, 5])

# %% [markdown]
# All good. At long last, we can now define our model class. This next part is a bit finicky in standard PyTorch, compared to Lightning or even TensorFlow, as we need to initialize the hidden state `h0` cell state `c0`. That said, since our model is not too complex, we can live with it:

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        
        # Store the input parameters as instance variables
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        # Initialize an LSTM layer with the given input size, hidden size, and number of stacked layers. Set batch_first to True.
        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers, 
                            batch_first=True)
               
        # Initialize a linear layer to map the hidden state output from the LSTM to a scalar output. The output of this linear layer will be the 4 predicted values.
        self.fc1 = nn.Linear(hidden_size, 5)
    
    def forward(self, x):
        h_n = torch.zeros(self.num_stacked_layers, x.size(0), self.hidden_size)
        c_n = torch.zeros(self.num_stacked_layers, x.size(0), self.hidden_size)
        h_n = h_n.to(device)
        c_n = c_n.to(device)
        # Pass the input through the LSTM layer
        output, (h_n, c_n) = self.lstm(x)

        # Pass the LSTM output through the linear layer
        output = (self.fc1(output[:, -1, :]))
        
        return output

# Instantiate a new LSTM model with input size 16, hidden size 30, and 3 stacked LSTM layers (really these should be called LSTM cells, but I don't get to name things).
model = LSTM(16, 30, 3)

# Move the model to the device specified by the 'device' variable
model.to(device)

# Print the model
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(16, 30, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=30, out_features=5, bias=True)
# )

# %% [markdown]
# Next we will define a standard training loop as a function called `train_and_validate` which will take number of epochs as input:

# %%
from sklearn.metrics import r2_score, mean_absolute_error

def train_and_validate(num_epochs):
    for epoch in range(num_epochs):
        # Training
        train_loss = 0.0
        train_r2 = 0.0
        train_mae_epoch = np.zeros((5,))
        train_r2_epoch = np.zeros((5,))
        model.train()
        for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            y_pred = model(X_batch)
            loss = loss_function(y_pred, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_r2 += r2_score(y_batch.cpu().detach().numpy(), y_pred.cpu().detach().numpy())
            train_mae_epoch += mean_absolute_error(y_batch.cpu().detach().numpy(), y_pred.cpu().detach().numpy(), multioutput='raw_values')
            train_r2_epoch += r2_score(y_batch.cpu().detach().numpy(), y_pred.cpu().detach().numpy(), multioutput='raw_values')

        # Validation
        val_loss = 0.0
        val_r2 = 0.0
        val_mae_epoch = np.zeros((5,))
        val_r2_epoch = np.zeros((5,))
        model.eval()
        with torch.no_grad():
            for batch_idx, (X_batch, y_batch) in enumerate(test_loader):
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                y_pred = model(X_batch)
                loss = loss_function(y_pred, y_batch)
                val_loss += loss.item()
                val_r2 += r2_score(y_batch.cpu().detach().numpy(), y_pred.cpu().detach().numpy())
                val_mae_epoch += mean_absolute_error(y_batch.cpu().detach().numpy(), y_pred.cpu().detach().numpy(), multioutput='raw_values')
                val_r2_epoch += r2_score(y_batch.cpu().detach().numpy(), y_pred.cpu().detach().numpy(), multioutput='raw_values')

        # Average metrics
        train_loss /= len(train_loader)
        val_loss /= len(test_loader)
        train_r2 /= len(train_loader)
        val_r2 /= len(test_loader)
        train_mae_epoch /= len(train_loader)
        val_mae_epoch /= len(test_loader)
        train_r2_epoch /= len(train_loader)
        val_r2_epoch /= len(test_loader)
        
        # Store metrics
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_r2s.append(train_r2)
        val_r2s.append(val_r2)
        train_mae_ind.append(train_mae_epoch)
        val_mae_ind.append(val_mae_epoch)
        train_r2_ind.append(train_r2_epoch)
        val_r2_ind.append(val_r2_epoch)
        
        # Print progress
        print(f"Epoch: {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train R2: {train_r2:.4f}, Val R2: {val_r2:.4f}")
        print(f"Train individual target MAEs: {train_mae_epoch}")
        print(f"Val individual target MAEs: {val_mae_epoch}")
        print(f"Train individual target R2s: {train_r2_epoch}") 
        print(f"Val individual target R2s: {val_r2_epoch}")
        print('***************************************************')        
        
        model.train(True)

# %%
### We're ready to train ! ###
learning_rate = lr
loss_function = nn.L1Loss() 
num_epochs = 50
weight_decay = 1e-5
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

train_losses = []
val_losses = []
train_r2s = []
val_r2s = []

train_mae_ind = []
val_mae_ind = []
train_r2_ind = []
val_r2_ind = []

train_and_validate(num_epochs = num_epochs)
# Out:
# Epoch: 1/50, Train Loss: 0.0866, Val Loss: 0.0985, Train R2: 0.6429, Val R2: 0.7332
# Train individual target MAEs: [0.07399818 0.047753   0.11342563 0.09465394 0.10298357]
# Val individual target MAEs: [0.11856158 0.05941766 0.07817594 0.13627985 0.09982487]
# Train individual target R2s: [0.49406244 0.92049732 0.77512598 0.54327271 0.48141187]
# Val individual target R2s: [0.74272868 0.95127525 0.92487514 0.44755789 0.59974919]
# ***************************************************
# Epoch: 2/50, Train Loss: 0.0512, Val Loss: 0.0870, Train R2: 0.8638, Val R2: 0.8104
# Train individual target MAEs: [0.02030881 0.02179884 0.05983052 0.07255226 0.08152466]
# Val individual target MAEs: [0.08803197 0.05924416 0.0980801  0.09590775 0.09374338]
# Train individual target R2s: [0.9726753  0.989844   0.94481631 0.74116441 0.67059948]
# Val individual target R2s: [0.87754195 0.95478939 0.90003941 0.67893944 0.64084239]
# ***************************************************
# Epoch: 3/50, Train Loss: 0.0489, Val Loss: 0.0824, Train R2: 0.8705, Val R2: 0.8144
# Train individual target MAEs: [0.01508362 0.01955234 0.05883075 0.07122237 0.07997559]
# Val individual target MAEs: [0.07781145 0.044077   0.09195183 0.10537787 0.09294474]
# Train individual target R2s: [0.98491041 0.99154057 0.9457151  0.74953814 0.68058046]
# Val individual target R2s: [0.91508666 0.97219939 0.91094151 0.63158926 0.64212122]
# ***************************************************
# Epoch: 4/50, Train Loss: 0.0477, Val Loss: 0.0844, Train R2: 0.8728, Val R2: 0.8184
# Train individual target MAEs: [0.01159403 0.01911076 0.05783201 0.07088011 0.0792404 ]
# Val individual target MAEs: [0.06799037 0.06391233 0.10007313 0.09877252 0.09148697]
# Train individual target R2s: [0.99076577 0.99184115 0.94608229 0.75103157 0.6845194 ]
# Val individual target R2s: [0.93530603 0.94997756 0.9000913  0.65854518 0.64820782]
# ***************************************************
# Epoch: 5/50, Train Loss: 0.0471, Val Loss: 0.0798, Train R2: 0.8731, Val R2: 0.8226
# Train individual target MAEs: [0.00973963 0.01828258 0.05747458 0.07075453 0.07934266]
# Val individual target MAEs: [0.05839474 0.043398   0.10294833 0.10357079 0.09074574]
# Train individual target R2s: [0.99298338 0.99228399 0.94698003 0.75100526 0.68225288]
# Val individual target R2s: [0.95063846 0.97446103 0.89759317 0.63300612 0.65748015]
# ***************************************************
# Epoch: 6/50, Train Loss: 0.0470, Val Loss: 0.0774, Train R2: 0.8739, Val R2: 0.8236
# Train individual target MAEs: [0.00960484 0.01807897 0.05772108 0.07047277 0.07917254]
# Val individual target MAEs: [0.05467962 0.04776012 0.08886571 0.10494283 0.09085135]
# Train individual target R2s: [0.99305322 0.99250137 0.94663683 0.75306009 0.68445367]
# Val individual target R2s: [0.95857413 0.96944268 0.91473816 0.62813434 0.64712809]
# ***************************************************
# Epoch: 7/50, Train Loss: 0.0467, Val Loss: 0.0809, Train R2: 0.8748, Val R2: 0.8221
# Train individual target MAEs: [0.00899514 0.0177698  0.05730478 0.07023713 0.07896045]
# Val individual target MAEs: [0.05970147 0.0415184  0.10871761 0.10401442 0.09074009]
# Train individual target R2s: [0.99393186 0.99258437 0.94746432 0.75281593 0.68702202]
# Val individual target R2s: [0.9539368  0.97499291 0.89145958 0.6394037  0.65092767]
# ***************************************************
# Epoch: 8/50, Train Loss: 0.0464, Val Loss: 0.0822, Train R2: 0.8747, Val R2: 0.8236
# Train individual target MAEs: [0.00799571 0.01778084 0.05732512 0.0700509  0.07891398]
# Val individual target MAEs: [0.05513372 0.05574456 0.10637646 0.10121791 0.09229069]
# Train individual target R2s: [0.99498543 0.99259406 0.94700588 0.75365451 0.68542004]
# Val individual target R2s: [0.95823433 0.96098975 0.89303647 0.66051449 0.64541969]
# ***************************************************
# Epoch: 9/50, Train Loss: 0.0465, Val Loss: 0.0814, Train R2: 0.8758, Val R2: 0.8218
# Train individual target MAEs: [0.00813682 0.01802995 0.05750377 0.07006401 0.07858662]
# Val individual target MAEs: [0.0574262  0.04196022 0.11334062 0.10247203 0.09166227]
# Train individual target R2s: [0.9948022  0.99255793 0.94730658 0.75500677 0.68937462]
# Val individual target R2s: [0.9567287  0.97538168 0.88534066 0.64701281 0.64460417]
# ***************************************************
# Epoch: 10/50, Train Loss: 0.0463, Val Loss: 0.0844, Train R2: 0.8754, Val R2: 0.8194
# Train individual target MAEs: [0.00798154 0.01797961 0.05704088 0.07002547 0.07859074]
# Val individual target MAEs: [0.05369055 0.04840341 0.13242615 0.09628165 0.09137218]
# Train individual target R2s: [0.99494166 0.99245595 0.94728019 0.75420126 0.68803458]
# Val individual target R2s: [0.9635381  0.96956983 0.85014962 0.66951107 0.64430785]
# ***************************************************
# Epoch: 11/50, Train Loss: 0.0461, Val Loss: 0.0875, Train R2: 0.8759, Val R2: 0.8104
# Train individual target MAEs: [0.00733847 0.01753384 0.05706423 0.06998142 0.07836023]
# Val individual target MAEs: [0.06496654 0.05851231 0.11494959 0.10741555 0.09167662]
# Train individual target R2s: [0.99544137 0.99276018 0.94779378 0.75461887 0.68871385]
# Val individual target R2s: [0.94879885 0.95678334 0.88204815 0.62529543 0.63889391]
# ***************************************************
# Epoch: 12/50, Train Loss: 0.0460, Val Loss: 0.0832, Train R2: 0.8758, Val R2: 0.8211
# Train individual target MAEs: [0.0071725  0.01776445 0.05693729 0.06971938 0.07835193]
# Val individual target MAEs: [0.06461336 0.04970333 0.10589649 0.10619097 0.08952897]
# Train individual target R2s: [0.99573827 0.99265511 0.94753813 0.75501058 0.68821274]
# Val individual target R2s: [0.94856172 0.96828537 0.8942517  0.63588814 0.6583488 ]
# ***************************************************
# Epoch: 13/50, Train Loss: 0.0459, Val Loss: 0.0837, Train R2: 0.8762, Val R2: 0.8242
# Train individual target MAEs: [0.00720948 0.0175137  0.05661344 0.0697761  0.07831727]
# Val individual target MAEs: [0.06543071 0.05956303 0.10672142 0.09540351 0.0913664 ]
# Train individual target R2s: [0.99559699 0.9927756  0.94767203 0.75651796 0.68853332]
# Val individual target R2s: [0.94974555 0.95460063 0.89277682 0.67449801 0.64921131]
# ***************************************************
# Epoch: 14/50, Train Loss: 0.0459, Val Loss: 0.0809, Train R2: 0.8768, Val R2: 0.8324
# Train individual target MAEs: [0.00713458 0.01772075 0.0567952  0.06962442 0.07801668]
# Val individual target MAEs: [0.06788318 0.04639936 0.11352914 0.08653285 0.09021208]
# Train individual target R2s: [0.99587098 0.99268203 0.94808155 0.75695684 0.69051701]
# Val individual target R2s: [0.94601238 0.97045413 0.88284021 0.71273752 0.64991319]
# ***************************************************
# Epoch: 15/50, Train Loss: 0.0458, Val Loss: 0.0872, Train R2: 0.8765, Val R2: 0.8182
# Train individual target MAEs: [0.00688138 0.01736139 0.05663047 0.06985059 0.07821692]
# Val individual target MAEs: [0.0696146  0.04957511 0.12686878 0.09751437 0.09253964]
# Train individual target R2s: [0.99600004 0.99282174 0.94781591 0.75625903 0.68979536]
# Val individual target R2s: [0.94311599 0.96659769 0.86484443 0.67019085 0.64601836]
# ***************************************************
# Epoch: 16/50, Train Loss: 0.0457, Val Loss: 0.0856, Train R2: 0.8771, Val R2: 0.8220
# Train individual target MAEs: [0.00685863 0.0175415  0.0563133  0.069743   0.07797395]
# Val individual target MAEs: [0.07060937 0.04718591 0.12872401 0.0921735  0.08928565]
# Train individual target R2s: [0.99594054 0.99271485 0.94786894 0.75729215 0.69163855]
# Val individual target R2s: [0.94071873 0.96862235 0.85992551 0.68762058 0.65299115]
# ***************************************************
# Epoch: 17/50, Train Loss: 0.0457, Val Loss: 0.0836, Train R2: 0.8765, Val R2: 0.8265
# Train individual target MAEs: [0.00684435 0.01753382 0.05670288 0.0696892  0.07784406]
# Val individual target MAEs: [0.07510117 0.05257238 0.10905283 0.09050077 0.09056473]
# Train individual target R2s: [0.99605381 0.99278156 0.94799063 0.75481409 0.69095732]
# Val individual target R2s: [0.93421532 0.96361469 0.88710914 0.70110351 0.64655928]
# ***************************************************
# Epoch: 18/50, Train Loss: 0.0455, Val Loss: 0.0827, Train R2: 0.8775, Val R2: 0.8289
# Train individual target MAEs: [0.00650207 0.01729473 0.05630542 0.06945746 0.07787459]
# Val individual target MAEs: [0.07220939 0.0499922  0.1087185  0.09272434 0.0900113 ]
# Train individual target R2s: [0.99628394 0.99294385 0.94854532 0.75845866 0.6911914 ]
# Val individual target R2s: [0.93897594 0.96626979 0.88939277 0.6979458  0.6520081 ]
# ***************************************************
# Epoch: 19/50, Train Loss: 0.0455, Val Loss: 0.0817, Train R2: 0.8777, Val R2: 0.8251
# Train individual target MAEs: [0.0067576  0.01728941 0.05638821 0.06925559 0.0777885 ]
# Val individual target MAEs: [0.06228519 0.05089451 0.10649205 0.09858406 0.09044529]
# Train individual target R2s: [0.99599412 0.99294118 0.94796648 0.75983446 0.69177874]
# Val individual target R2s: [0.95317519 0.96715117 0.89440335 0.65801019 0.65252997]
# ***************************************************
# Epoch: 20/50, Train Loss: 0.0455, Val Loss: 0.0817, Train R2: 0.8772, Val R2: 0.8195
# Train individual target MAEs: [0.00665128 0.01739484 0.05623399 0.06934369 0.07764471]
# Val individual target MAEs: [0.06923424 0.04582755 0.09842784 0.10512135 0.08975078]
# Train individual target R2s: [0.99622954 0.99283134 0.94823473 0.75718546 0.69175822]
# Val individual target R2s: [0.94417036 0.97237342 0.90395642 0.61840773 0.65871493]
# ***************************************************
# Epoch: 21/50, Train Loss: 0.0454, Val Loss: 0.0827, Train R2: 0.8775, Val R2: 0.8234
# Train individual target MAEs: [0.00632838 0.01727367 0.05607794 0.06952064 0.0776156 ]
# Val individual target MAEs: [0.07864707 0.04616324 0.10580887 0.09130925 0.09179852]
# Train individual target R2s: [0.99650681 0.9929253  0.94855665 0.75722965 0.69246776]
# Val individual target R2s: [0.93022282 0.97072513 0.89247461 0.68905766 0.63464163]
# ***************************************************
# Epoch: 22/50, Train Loss: 0.0454, Val Loss: 0.0834, Train R2: 0.8772, Val R2: 0.8279
# Train individual target MAEs: [0.0064223  0.01738465 0.05605019 0.06935603 0.07767552]
# Val individual target MAEs: [0.06718816 0.04281769 0.12119351 0.09586083 0.09017701]
# Train individual target R2s: [0.9963913  0.99289682 0.94857755 0.75674255 0.69129473]
# Val individual target R2s: [0.94493825 0.9749971  0.86950049 0.68686789 0.66325972]
# ***************************************************
# Epoch: 23/50, Train Loss: 0.0452, Val Loss: 0.0850, Train R2: 0.8782, Val R2: 0.8182
# Train individual target MAEs: [0.00626397 0.0170971  0.05604656 0.06926496 0.07746416]
# Val individual target MAEs: [0.07093128 0.04178539 0.12444361 0.0949632  0.09270334]
# Train individual target R2s: [0.99649497 0.99304926 0.94860257 0.75904249 0.69400447]
# Val individual target R2s: [0.94238182 0.97521444 0.86218309 0.67756128 0.63362986]
# ***************************************************
# Epoch: 24/50, Train Loss: 0.0453, Val Loss: 0.0823, Train R2: 0.8781, Val R2: 0.8236
# Train individual target MAEs: [0.00649426 0.01728454 0.05585488 0.06928539 0.07742758]
# Val individual target MAEs: [0.07198115 0.04637356 0.102482   0.10102645 0.0895193 ]
# Train individual target R2s: [0.99630654 0.99294008 0.94883131 0.75888597 0.69332888]
# Val individual target R2s: [0.94208418 0.97033807 0.8992623  0.6511979  0.65536448]
# ***************************************************
# Epoch: 25/50, Train Loss: 0.0451, Val Loss: 0.0820, Train R2: 0.8784, Val R2: 0.8339
# Train individual target MAEs: [0.00617109 0.01710801 0.05591293 0.06921676 0.07727641]
# Val individual target MAEs: [0.06878619 0.047982   0.11829036 0.08418906 0.09078864]
# Train individual target R2s: [0.99644302 0.99302026 0.94880167 0.75859512 0.69537629]
# Val individual target R2s: [0.94623861 0.96864294 0.87676217 0.72815444 0.64949178]
# ***************************************************
# Epoch: 26/50, Train Loss: 0.0452, Val Loss: 0.0803, Train R2: 0.8782, Val R2: 0.8329
# Train individual target MAEs: [0.00636675 0.01721633 0.05607334 0.06917097 0.07725016]
# Val individual target MAEs: [0.06705042 0.04441079 0.11092201 0.08725363 0.09175566]
# Train individual target R2s: [0.99656807 0.99297489 0.9485633  0.75879289 0.69406009]
# Val individual target R2s: [0.94750966 0.97230602 0.8867787  0.71736214 0.64042883]
# ***************************************************
# Epoch: 27/50, Train Loss: 0.0452, Val Loss: 0.0825, Train R2: 0.8782, Val R2: 0.8303
# Train individual target MAEs: [0.0061747  0.0172982  0.05584646 0.06925563 0.07740257]
# Val individual target MAEs: [0.07435241 0.04447678 0.11483462 0.08976497 0.08899869]
# Train individual target R2s: [0.99658918 0.99297409 0.94879141 0.75826533 0.69416887]
# Val individual target R2s: [0.93615476 0.97224686 0.88158666 0.70047668 0.66112734]
# ***************************************************
# Epoch: 28/50, Train Loss: 0.0451, Val Loss: 0.0799, Train R2: 0.8779, Val R2: 0.8316
# Train individual target MAEs: [0.00604842 0.01707457 0.05566781 0.06916187 0.07733448]
# Val individual target MAEs: [0.06503714 0.03886074 0.11364775 0.09084126 0.09112356]
# Train individual target R2s: [0.99671643 0.99311039 0.94884057 0.75705485 0.69359829]
# Val individual target R2s: [0.95139384 0.97803328 0.88136781 0.69953208 0.6478129 ]
# ***************************************************
# Epoch: 29/50, Train Loss: 0.0450, Val Loss: 0.0875, Train R2: 0.8786, Val R2: 0.8037
# Train individual target MAEs: [0.00596477 0.01708044 0.05587223 0.0690809  0.07718309]
# Val individual target MAEs: [0.06806439 0.04296488 0.12335812 0.11223417 0.0907537 ]
# Train individual target R2s: [0.99680468 0.99306916 0.94896397 0.75885849 0.69522599]
# Val individual target R2s: [0.94687612 0.9744958  0.86559007 0.58585194 0.64589724]
# ***************************************************
# Epoch: 30/50, Train Loss: 0.0450, Val Loss: 0.0837, Train R2: 0.8779, Val R2: 0.8172
# Train individual target MAEs: [0.00587143 0.01696159 0.05568597 0.06913283 0.07712002]
# Val individual target MAEs: [0.06610981 0.03908109 0.12016995 0.10121946 0.09191895]
# Train individual target R2s: [0.99676432 0.99311151 0.94896323 0.75726107 0.69342672]
# Val individual target R2s: [0.94981042 0.97694791 0.87434976 0.64856519 0.63640837]
# ***************************************************
# Epoch: 31/50, Train Loss: 0.0450, Val Loss: 0.0813, Train R2: 0.8786, Val R2: 0.8283
# Train individual target MAEs: [0.00596317 0.01700695 0.0557564  0.06901306 0.07704111]
# Val individual target MAEs: [0.06950727 0.04307218 0.10954387 0.09355643 0.09074309]
# Train individual target R2s: [0.99682243 0.99306854 0.94885606 0.76005668 0.69430151]
# Val individual target R2s: [0.94377276 0.97430903 0.8915392  0.68498823 0.64699616]
# ***************************************************
# Epoch: 32/50, Train Loss: 0.0450, Val Loss: 0.0812, Train R2: 0.8790, Val R2: 0.8229
# Train individual target MAEs: [0.00627322 0.01707918 0.05569434 0.06901336 0.07698747]
# Val individual target MAEs: [0.0658078  0.03435441 0.12018435 0.09443444 0.09142131]
# Train individual target R2s: [0.99652788 0.99305479 0.94948832 0.75991772 0.69592787]
# Val individual target R2s: [0.94824017 0.98202141 0.87255457 0.66305582 0.64843704]
# ***************************************************
# Epoch: 33/50, Train Loss: 0.0450, Val Loss: 0.0832, Train R2: 0.8788, Val R2: 0.8240
# Train individual target MAEs: [0.00611417 0.0168889  0.05570151 0.0690666  0.07707336]
# Val individual target MAEs: [0.07105088 0.04482385 0.11627337 0.09211781 0.09170953]
# Train individual target R2s: [0.99666487 0.99315136 0.94910356 0.75986191 0.69507596]
# Val individual target R2s: [0.94202693 0.9730682  0.87701472 0.69043852 0.63722061]
# ***************************************************
# Epoch: 34/50, Train Loss: 0.0449, Val Loss: 0.0823, Train R2: 0.8793, Val R2: 0.8300
# Train individual target MAEs: [0.00588434 0.01711077 0.05559193 0.06894195 0.07697722]
# Val individual target MAEs: [0.07123293 0.04804368 0.11544932 0.08788112 0.08900382]
# Train individual target R2s: [0.99691916 0.9930251  0.94927947 0.76042029 0.69674997]
# Val individual target R2s: [0.94066984 0.96965889 0.87685565 0.70437496 0.65855889]
# ***************************************************
# Epoch: 35/50, Train Loss: 0.0449, Val Loss: 0.0823, Train R2: 0.8798, Val R2: 0.8248
# Train individual target MAEs: [0.00591417 0.01678779 0.05553798 0.06895833 0.07711724]
# Val individual target MAEs: [0.06990361 0.03893422 0.11753603 0.09408946 0.09085949]
# Train individual target R2s: [0.99666894 0.99322278 0.94929327 0.7630098  0.69697796]
# Val individual target R2s: [0.94355668 0.97809041 0.87534744 0.67625895 0.65061818]
# ***************************************************
# Epoch: 36/50, Train Loss: 0.0448, Val Loss: 0.0837, Train R2: 0.8792, Val R2: 0.8256
# Train individual target MAEs: [0.00603929 0.01686298 0.05553476 0.06881536 0.07695348]
# Val individual target MAEs: [0.06638693 0.05379775 0.11674126 0.08959636 0.09197216]
# Train individual target R2s: [0.99672466 0.99320953 0.94900796 0.7603322  0.69662498]
# Val individual target R2s: [0.94806572 0.96227204 0.87816786 0.70339574 0.63618601]
# ***************************************************
# Epoch: 37/50, Train Loss: 0.0448, Val Loss: 0.0818, Train R2: 0.8787, Val R2: 0.8308
# Train individual target MAEs: [0.00580889 0.01678951 0.05535683 0.06888449 0.07701775]
# Val individual target MAEs: [0.07211915 0.03693674 0.12156013 0.08754956 0.09087944]
# Train individual target R2s: [0.99696188 0.99318121 0.94944876 0.75986395 0.69381301]
# Val individual target R2s: [0.93869639 0.97979595 0.87174479 0.7151821  0.64867354]
# ***************************************************
# Epoch: 38/50, Train Loss: 0.0448, Val Loss: 0.0824, Train R2: 0.8787, Val R2: 0.8269
# Train individual target MAEs: [0.00604749 0.01685543 0.05521636 0.06889875 0.07703258]
# Val individual target MAEs: [0.06610129 0.03841466 0.12527353 0.09223617 0.08972459]
# Train individual target R2s: [0.99683732 0.99316879 0.94933803 0.75866864 0.69565778]
# Val individual target R2s: [0.94863578 0.97863129 0.862722   0.69238253 0.65188744]
# ***************************************************
# Epoch: 39/50, Train Loss: 0.0448, Val Loss: 0.0802, Train R2: 0.8785, Val R2: 0.8325
# Train individual target MAEs: [0.00585749 0.0167074  0.05537969 0.06890272 0.07699436]
# Val individual target MAEs: [0.06233659 0.04403715 0.11496483 0.08980008 0.08963161]
# Train individual target R2s: [0.99680869 0.99325684 0.94950267 0.75870774 0.69400426]
# Val individual target R2s: [0.95422491 0.97367717 0.88245015 0.69607504 0.65598796]
# ***************************************************
# Epoch: 40/50, Train Loss: 0.0448, Val Loss: 0.0793, Train R2: 0.8795, Val R2: 0.8344
# Train individual target MAEs: [0.00592836 0.01706626 0.05539307 0.06884576 0.07685909]
# Val individual target MAEs: [0.06765249 0.04380282 0.10749147 0.08691151 0.09058703]
# Train individual target R2s: [0.99686142 0.99308575 0.94924816 0.7610365  0.6972744 ]
# Val individual target R2s: [0.94663438 0.97377666 0.89300213 0.71442869 0.64404047]
# ***************************************************
# Epoch: 41/50, Train Loss: 0.0448, Val Loss: 0.0838, Train R2: 0.8789, Val R2: 0.8254
# Train individual target MAEs: [0.00587865 0.0168759  0.05533453 0.06882714 0.0769038 ]
# Val individual target MAEs: [0.07586081 0.04454005 0.11355735 0.094777   0.09019637]
# Train individual target R2s: [0.9967543  0.99315793 0.94920558 0.7586741  0.6967619 ]
# Val individual target R2s: [0.93372449 0.97252271 0.88381872 0.67931019 0.65784174]
# ***************************************************
# Epoch: 42/50, Train Loss: 0.0448, Val Loss: 0.0810, Train R2: 0.8792, Val R2: 0.8311
# Train individual target MAEs: [0.00579009 0.0168229  0.05561928 0.06874519 0.07689453]
# Val individual target MAEs: [0.06584364 0.03832383 0.12442751 0.08675287 0.08975247]
# Train individual target R2s: [0.99695704 0.99321842 0.94940595 0.76037037 0.69622518]
# Val individual target R2s: [0.94780675 0.97828906 0.86564283 0.71145942 0.65253905]
# ***************************************************
# Epoch: 43/50, Train Loss: 0.0447, Val Loss: 0.0804, Train R2: 0.8792, Val R2: 0.8311
# Train individual target MAEs: [0.00554227 0.01683221 0.05545236 0.06882908 0.07660568]
# Val individual target MAEs: [0.06289737 0.04495368 0.11438036 0.09050612 0.08905492]
# Train individual target R2s: [0.99711232 0.99322742 0.94943128 0.75916884 0.6968701 ]
# Val individual target R2s: [0.95190209 0.97245037 0.88124604 0.6887872  0.6610215 ]
# ***************************************************
# Epoch: 44/50, Train Loss: 0.0446, Val Loss: 0.0823, Train R2: 0.8796, Val R2: 0.8310
# Train individual target MAEs: [0.00575879 0.01680014 0.05504315 0.06877909 0.07673901]
# Val individual target MAEs: [0.07093523 0.04541461 0.11560865 0.0898665  0.08962153]
# Train individual target R2s: [0.99703724 0.99325164 0.94995018 0.76031756 0.697461  ]
# Val individual target R2s: [0.94052355 0.97179743 0.87887854 0.7055284  0.65826374]
# ***************************************************
# Epoch: 45/50, Train Loss: 0.0447, Val Loss: 0.0788, Train R2: 0.8795, Val R2: 0.8376
# Train individual target MAEs: [0.0056724  0.01680574 0.05524277 0.06879226 0.07683533]
# Val individual target MAEs: [0.06814545 0.0406112  0.10693036 0.08870693 0.08984436]
# Train individual target R2s: [0.99686449 0.99318615 0.94967427 0.7600132  0.69788588]
# Val individual target R2s: [0.94534551 0.97636793 0.89484749 0.71576104 0.65591291]
# ***************************************************
# Epoch: 46/50, Train Loss: 0.0447, Val Loss: 0.0793, Train R2: 0.8803, Val R2: 0.8331
# Train individual target MAEs: [0.00574456 0.01678623 0.05540356 0.06864861 0.07670618]
# Val individual target MAEs: [0.07247451 0.03868977 0.10682431 0.0870426  0.09122948]
# Train individual target R2s: [0.99688052 0.99325287 0.94993727 0.7626975  0.69854502]
# Val individual target R2s: [0.93923627 0.97837022 0.8942751  0.70808267 0.64556599]
# ***************************************************
# Epoch: 47/50, Train Loss: 0.0447, Val Loss: 0.0785, Train R2: 0.8797, Val R2: 0.8344
# Train individual target MAEs: [0.00574155 0.01674577 0.05525973 0.06875937 0.07675104]
# Val individual target MAEs: [0.06689169 0.04094786 0.10072532 0.0941578  0.08992335]
# Train individual target R2s: [0.99709532 0.9932534  0.95021383 0.76136324 0.69665421]
# Val individual target R2s: [0.94699827 0.97668354 0.9001322  0.68859697 0.6594283 ]
# ***************************************************
# Epoch: 48/50, Train Loss: 0.0446, Val Loss: 0.0807, Train R2: 0.8795, Val R2: 0.8260
# Train individual target MAEs: [0.00568821 0.016889   0.05499648 0.06877246 0.07674565]
# Val individual target MAEs: [0.06885914 0.03997911 0.11039745 0.09106991 0.09296655]
# Train individual target R2s: [0.99703415 0.99320371 0.94995712 0.76007663 0.69716553]
# Val individual target R2s: [0.94369351 0.97684399 0.88891926 0.68625499 0.63429924]
# ***************************************************
# Epoch: 49/50, Train Loss: 0.0447, Val Loss: 0.0813, Train R2: 0.8795, Val R2: 0.8261
# Train individual target MAEs: [0.00571358 0.01682203 0.05540117 0.06865825 0.07677971]
# Val individual target MAEs: [0.0676406  0.04604278 0.10712243 0.09617858 0.08950943]
# Train individual target R2s: [0.9970536  0.99323519 0.94954587 0.76122764 0.69664602]
# Val individual target R2s: [0.9448321  0.97201876 0.89169333 0.66844783 0.65344061]
# ***************************************************
# Epoch: 50/50, Train Loss: 0.0445, Val Loss: 0.0790, Train R2: 0.8796, Val R2: 0.8359
# Train individual target MAEs: [0.00559598 0.0165507  0.0549418  0.0687674  0.07665478]
# Val individual target MAEs: [0.0667927  0.04424765 0.10682578 0.0874059  0.08990611]
# Train individual target R2s: [0.99708637 0.99336946 0.94962531 0.76088695 0.69683838]
# Val individual target R2s: [0.94824636 0.97350707 0.89034721 0.7171797  0.65011278]
# ***************************************************

# %%
# We can now plot and save the results

labels = ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy']

# plot the training and validation loss
plt.figure()
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Loss value at every epoch')
plt.xlabel('Epoch (1-50)')
plt.ylabel('Average MAE')

# save the plot to a local directory
dir_path = dir_path
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
plt.savefig(os.path.join(dir_path, 'avg_loss.png'))

# plot the training loss curve for each target
plt.figure()
plt.plot(train_mae_ind, label='Training Loss')
plt.legend(labels = labels)
plt.title('Training loss value at every epoch for each individual target feature')
plt.xlabel('Epoch (1-50)')
plt.ylabel('MAE')

# save the plot to a local directory
plt.savefig(os.path.join(dir_path, 'ind_train_loss.png'))

# plot the validation loss curve for each target
plt.figure()
plt.plot(val_mae_ind, label='Validation Loss')
plt.legend(labels = labels)
plt.title('Validation loss value at every epoch for each individual target feature')
plt.xlabel('Epoch (1-50)')
plt.ylabel('MAE')

# save the plot to a local directory
plt.savefig(os.path.join(dir_path, 'ind_val_loss.png'))

# plot the training and validation R2 scores
plt.figure()
plt.plot(train_r2s, label='Training R2')
plt.plot(val_r2s, label='Validation R2')
plt.legend()
plt.title('R2 Score at every epoch')
plt.xlabel('Epoch (1-50)')
plt.ylabel('Average Coefficient of determination (R2) value')

# save the plot to a local directory
plt.savefig(os.path.join(dir_path, 'avg_r2.png'))

# plot the training loss curve for each target
plt.figure()
plt.plot(train_r2_ind, label='Training R2')
plt.legend(labels = labels)
plt.title('Training R2 at every epoch for each individual target feature')
plt.xlabel('Epoch (1-50)')
plt.ylabel('Coefficient of determination (R2) value')

# save the plot to a local directory
plt.savefig(os.path.join(dir_path, 'ind_train_r2.png'))

# plot the validation loss curve for each target
plt.figure()
plt.plot(val_r2_ind, label='Validation R2')
plt.legend(labels = labels)
plt.title('Validation R2 at every epoch for each individual target feature')
plt.xlabel('Epoch (1-50)')
plt.ylabel('Coefficient of determination (R2) value')

# save the plot to a local directory
plt.savefig(os.path.join(dir_path, 'ind_val_r2.png'))

# %%
# Find highest training and validation R2 values
highest_train_r2 = max(train_r2s)
highest_val_r2 = max(val_r2s)

# Find lowest training and validation losses
lowest_train_loss = min(train_losses)
lowest_val_loss = min(val_losses)

# %%
# Set directory path and filename for output file
output_dir = dir_path
output_filename = "results.txt"

# Create output directory if it doesn't already exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Open output file for writing
with open(os.path.join(output_dir, output_filename), 'w') as f:
    
    f.write("k was size: " + str(lookback) + "\n")
    f.write("batch was size: " + str(batch_size) + "\n")
    f.write("lr was size: " + str(lr) + "\n")
    
    # Write highest train R2 to file
    f.write("The highest train R2 was: " + str(highest_train_r2) + "\n")
    
    # Write highest val R2 to file
    f.write("The highest val R2 was: " + str(highest_val_r2) + "\n")
    
    # Write lowest train loss to file
    f.write("The lowest train loss was: " + str(lowest_train_loss) + "\n")
    
    # Write lowest val loss to file
    f.write("The lowest val loss was: " + str(lowest_val_loss) + "\n")
    
# Print confirmation message
print("Results saved to " + os.path.join(output_dir, output_filename))
# Out:
# Results saved to C:\Users\usuario\RecogniChess\HW4\Snapshots\LSTM2\BEST\results.txt

# %% [markdown]
# ## Model Evaluation

# %%
# We import the test data
df2 = pd.read_csv(r"C:\Users\usuario\RecogniChess\HW4\weather_test.csv", header=0, parse_dates=[0])
print(df2.shape)
# Out:
# (14019, 15)

# %% [markdown]
# We have the same number of columns, but way less samples

# %%
# Let's drop any and all rows with NAs
df2.dropna(inplace=True)
print(df2.shape)
# Out:
# (14019, 15)

# %%
# Let's take a look
df2.tail()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 14014 2016-12-31 19:10:00   1002.18     -0.98    272.01        -5.36   72.00
# 14015 2016-12-31 20:10:00   1001.40     -1.40    271.66        -6.84   66.29
# 14016 2016-12-31 21:10:00   1001.19     -2.75    270.32        -6.90   72.90
# 14017 2016-12-31 22:10:00   1000.65     -2.89    270.22        -7.15   72.30
# 14018 2016-12-31 23:10:00   1000.11     -3.93    269.23        -8.09   72.60
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 14014          5.69          4.09          1.59       2.54             4.08
# 14015          5.51          3.65          1.86       2.27             3.65
# 14016          4.99          3.64          1.35       2.26             3.63
# 14017          4.93          3.57          1.37       2.22             3.57
# 14018          4.56          3.31          1.25       2.06             3.31
#
#        rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 14014       1280.70      0.87           1.36     190.6
# 14015       1281.87      1.02           1.92     225.4
# 14016       1288.02      0.71           1.56     158.7
# 14017       1288.03      0.35           0.68     216.7
# 14018       1292.41      0.56           1.00     202.6

# %%
# First, we will turn the first column into a Pandas datetime object
df2['Date Time'] = pd.to_datetime(df2['Date Time'])

# %%
# Let's take a look
df2.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2015-05-24 19:00:00    990.00     17.93    291.93         9.23   56.73
# 1 2015-05-24 20:00:00    989.86     16.92    290.93         9.52   61.65
# 2 2015-05-24 21:00:00    990.11     15.82    289.80         9.71   66.97
# 3 2015-05-24 22:00:00    990.01     15.02    289.01         9.50   69.53
# 4 2015-05-24 23:00:00    989.89     14.14    288.14         9.42   73.20
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0         20.58         11.68          8.91       7.37            11.79
# 1         19.31         11.90          7.40       7.51            12.03
# 2         18.00         12.06          5.95       7.61            12.18
# 3         17.10         11.89          5.21       7.50            12.01
# 4         16.15         11.83          4.33       7.46            11.95
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1179.50      1.58           2.16     34.37
# 1       1183.33      0.23           0.60     20.89
# 2       1188.07      0.26           0.52    252.00
# 3       1191.32      1.22           1.88    218.50
# 4       1194.85      1.43           1.96    218.00

# %%
df2 = df2.drop(columns=["sh (g/kg)", "H2OC (mmol/mol)", "rho (g/m**3)"])
df2.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2015-05-24 19:00:00    990.00     17.93    291.93         9.23   56.73
# 1 2015-05-24 20:00:00    989.86     16.92    290.93         9.52   61.65
# 2 2015-05-24 21:00:00    990.11     15.82    289.80         9.71   66.97
# 3 2015-05-24 22:00:00    990.01     15.02    289.01         9.50   69.53
# 4 2015-05-24 23:00:00    989.89     14.14    288.14         9.42   73.20
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0         20.58         11.68          8.91      1.58           2.16     34.37
# 1         19.31         11.90          7.40      0.23           0.60     20.89
# 2         18.00         12.06          5.95      0.26           0.52    252.00
# 3         17.10         11.89          5.21      1.22           1.88    218.50
# 4         16.15         11.83          4.33      1.43           1.96    218.00

# %%
# We will plot the targets as with the training data

plot_cols = ['T (degC)', 'p (mbar)', 'rh (%)', 'wv (m/s)']
plot_features = df2[plot_cols]
plot_features.index = df2['Date Time']
_ = plot_features.plot(subplots=True)

plot_features = df2[plot_cols][:500]
plot_features.index = pd.DatetimeIndex(df2['Date Time'][:500])
_ = plot_features.plot(subplots=True)

# %% [markdown]
# Once again we see that the samples from 2015 look a bit strange. Also there is a strange anomaly in the wv (m/s), also in 2015. We will have to delete this whole year again

# %%
# Let's investigate deeper
df2.describe().transpose()
# Out:
#                  count        mean         std      min      25%     50%  \
# p (mbar)       14019.0  990.732392    8.220120   956.96  985.910  990.96
# T (degC)       14019.0   11.301290    8.092519   -13.67    5.080   11.07
# Tpot (K)       14019.0  285.225804    8.224984   259.15  279.100  284.95
# Tdew (degC)    14019.0    6.576604    6.045940   -15.30    2.030    6.80
# rh (%)         14019.0   75.216103   16.357764    23.64   64.250   78.30
# VPmax (mbar)   14019.0   15.199599    8.514445     2.12    8.775   13.20
# VPact (mbar)   14019.0   10.481350    4.182481     1.85    7.080    9.89
# VPdef (mbar)   14019.0    4.718212    5.661257     0.01    1.090    2.60
# wv (m/s)       14019.0   -0.086451  146.298911 -9999.00    0.930    1.64
# max. wv (m/s)  14019.0    0.582371  168.955876 -9999.00    1.680    2.80
# wd (deg)       14019.0  177.828951   84.758167     0.11  131.550  201.00
#
#                   75%      max
# p (mbar)       995.96  1015.29
# T (degC)        17.04    37.28
# Tpot (K)       291.03   311.21
# Tdew (degC)     11.35    19.78
# rh (%)          88.80    99.90
# VPmax (mbar)    19.46    63.77
# VPact (mbar)    13.45    23.10
# VPdef (mbar)     6.07    46.01
# wv (m/s)         2.73    12.05
# max. wv (m/s)    4.60    18.67
# wd (deg)       234.40   359.90

# %% [markdown]
# There are clearly two wrong values in the min column of the wv (m/s) and max. wv (m/s) variables. We will fix this:

# %%
# We replace the crazy values with a value of 0

wv = df2['wv (m/s)']
bad_wv = wv == -9999.0
wv[bad_wv] = 0.0

max_wv = df2['max. wv (m/s)']
bad_max_wv = max_wv == -9999.0
max_wv[bad_max_wv] = 0.0

# The above inplace edits are reflected in the DataFrame.
df2['wv (m/s)'].min()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2635357693.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wv[bad_wv] = 0.0
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2635357693.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_wv[bad_max_wv] = 0.0
# 0.0

# %%
# Let's investigate deeper
df2.describe().transpose()
# Out:
#                  count        mean        std     min      25%     50%  \
# p (mbar)       14019.0  990.732392   8.220120  956.96  985.910  990.96
# T (degC)       14019.0   11.301290   8.092519  -13.67    5.080   11.07
# Tpot (K)       14019.0  285.225804   8.224984  259.15  279.100  284.95
# Tdew (degC)    14019.0    6.576604   6.045940  -15.30    2.030    6.80
# rh (%)         14019.0   75.216103  16.357764   23.64   64.250   78.30
# VPmax (mbar)   14019.0   15.199599   8.514445    2.12    8.775   13.20
# VPact (mbar)   14019.0   10.481350   4.182481    1.85    7.080    9.89
# VPdef (mbar)   14019.0    4.718212   5.661257    0.01    1.090    2.60
# wv (m/s)       14019.0    2.053288   1.544936    0.00    0.930    1.64
# max. wv (m/s)  14019.0    3.435356   2.364410    0.00    1.680    2.80
# wd (deg)       14019.0  177.828951  84.758167    0.11  131.550  201.00
#
#                   75%      max
# p (mbar)       995.96  1015.29
# T (degC)        17.04    37.28
# Tpot (K)       291.03   311.21
# Tdew (degC)     11.35    19.78
# rh (%)          88.80    99.90
# VPmax (mbar)    19.46    63.77
# VPact (mbar)    13.45    23.10
# VPdef (mbar)     6.07    46.01
# wv (m/s)         2.73    12.05
# max. wv (m/s)    4.60    18.67
# wd (deg)       234.40   359.90

# %%
# We need to preprocess the wind variable that are expressed in radians as with the training set

wv = df2.pop('wv (m/s)')
max_wv = df2.pop('max. wv (m/s)')

# Convert to radians.
wd_rad = df2.pop('wd (deg)')*np.pi / 180

# Calculate the wind x and y components.
df2['Wx'] = wv*np.cos(wd_rad)
df2['Wy'] = wv*np.sin(wd_rad)

# Calculate the max wind x and y components.
df2['max Wx'] = max_wv*np.cos(wd_rad)
df2['max Wy'] = max_wv*np.sin(wd_rad)

# %%
df2.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2015-05-24 19:00:00    990.00     17.93    291.93         9.23   56.73
# 1 2015-05-24 20:00:00    989.86     16.92    290.93         9.52   61.65
# 2 2015-05-24 21:00:00    990.11     15.82    289.80         9.71   66.97
# 3 2015-05-24 22:00:00    990.01     15.02    289.01         9.50   69.53
# 4 2015-05-24 23:00:00    989.89     14.14    288.14         9.42   73.20
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0         20.58         11.68          8.91  1.304147  0.891965  1.782884
# 1         19.31         11.90          7.40  0.214881  0.082012  0.560560
# 2         18.00         12.06          5.95 -0.080344 -0.247275 -0.160689
# 3         17.10         11.89          5.21 -0.954782 -0.759468 -1.471303
# 4         16.15         11.83          4.33 -1.126855 -0.880396 -1.544501
#
#      max Wy
# 0  1.219395
# 1  0.213945
# 2 -0.494549
# 3 -1.170328
# 4 -1.206696

# %%
timestamp_s = df2['Date Time'].map(pd.Timestamp.timestamp)

# %%
day = 24*60*60
year = (365.2425)*day

df2['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
df2['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
df2['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
df2['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %%
plt.plot(np.array(df2['Day sin'])[:25])
plt.plot(np.array(df2['Day cos'])[:25])
plt.xlabel('Time [h]')
plt.title('Time of day signal')
# Out:
# Text(0.5, 1.0, 'Time of day signal')

# %%
plt.plot(np.array(df2['Year sin'])[:365])
plt.plot(np.array(df2['Year cos'])[:365])
plt.xlabel('Time [d]')
plt.title('Time of year signal')
# Out:
# Text(0.5, 1.0, 'Time of year signal')

# %% [markdown]
# That looks wrong. Once again, the year 2015 is working against us. We will remove it.

# %%
df2.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2015-05-24 19:00:00    990.00     17.93    291.93         9.23   56.73
# 1 2015-05-24 20:00:00    989.86     16.92    290.93         9.52   61.65
# 2 2015-05-24 21:00:00    990.11     15.82    289.80         9.71   66.97
# 3 2015-05-24 22:00:00    990.01     15.02    289.01         9.50   69.53
# 4 2015-05-24 23:00:00    989.89     14.14    288.14         9.42   73.20
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0         20.58         11.68          8.91  1.304147  0.891965  1.782884
# 1         19.31         11.90          7.40  0.214881  0.082012  0.560560
# 2         18.00         12.06          5.95 -0.080344 -0.247275 -0.160689
# 3         17.10         11.89          5.21 -0.954782 -0.759468 -1.471303
# 4         16.15         11.83          4.33 -1.126855 -0.880396 -1.544501
#
#      max Wy   Day sin   Day cos  Year sin  Year cos
# 0  1.219395 -0.965926  0.258819  0.618216 -0.786008
# 1  0.213945 -0.866025  0.500000  0.617653 -0.786451
# 2 -0.494549 -0.707107  0.707107  0.617089 -0.786893
# 3 -1.170328 -0.500000  0.866025  0.616525 -0.787336
# 4 -1.206696 -0.258819  0.965926  0.615960 -0.787777

# %%
df2 = df2[df2['Date Time'].dt.year != 2015] # Remove all rows whose year is 2015
df2.reset_index(drop=True, inplace=True) # Reset the index of the resulting dataframe

# %%
df2.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2016-01-01 00:00:00    999.08     -0.01    273.22        -0.44    96.9
# 1 2016-01-01 01:00:00    999.06     -0.05    273.18        -0.52    96.6
# 2 2016-01-01 02:00:00    999.00     -0.59    272.65        -0.99    97.1
# 3 2016-01-01 03:00:00    999.48     -1.83    271.37        -2.24    97.0
# 4 2016-01-01 04:00:00    999.65     -1.63    271.56        -1.96    97.6
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0          6.10          5.91          0.19 -1.132940 -0.249093 -1.992411
# 1          6.09          5.88          0.21 -0.345175  0.102246 -0.728703
# 2          5.85          5.68          0.17 -0.309603  0.163235 -0.530749
# 3          5.34          5.18          0.16 -0.373876 -0.067945 -0.629686
# 4          5.42          5.29          0.13 -0.257776  0.033937 -0.555209
#
#      max Wy       Day sin   Day cos  Year sin  Year cos
# 0 -0.438060 -1.407890e-12  1.000000 -0.002666  0.999996
# 1  0.215852  2.588190e-01  0.965926 -0.001950  0.999998
# 2  0.279832  5.000000e-01  0.866025 -0.001233  0.999999
# 3 -0.114433  7.071068e-01  0.707107 -0.000516  1.000000
# 4  0.073095  8.660254e-01  0.500000  0.000201  1.000000

# %%
plt.plot(np.array(df2['Year sin'])[:365])
plt.plot(np.array(df2['Year cos'])[:365])
plt.xlabel('Time [d]')
plt.title('Time of year signal')
# Out:
# Text(0.5, 1.0, 'Time of year signal')

# %% [markdown]
# That looks much better. We may now proceed.

# %%
plot_cols = ['T (degC)', 'p (mbar)', 'rh (%)', 'Wx', 'Wy']
plot_features = df2[plot_cols]
plot_features.index = df2['Date Time']
_ = plot_features.plot(subplots=True)

plot_features = df2[plot_cols][:500]
plot_features.index = pd.DatetimeIndex(df2['Date Time'][:500])
_ = plot_features.plot(subplots=True)

# %% [markdown]
# That looks much better. We may proceed.

# %%
numeric_cols = df2.select_dtypes(include=[np.number]).columns
test_mean = df2[numeric_cols].mean(numeric_only=True)
test_std = df2[numeric_cols].std(numeric_only=True)

df2[numeric_cols] = (df2[numeric_cols] - test_mean) / test_std

# %%
df2.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  \
# 0 2016-01-01 00:00:00  1.025883 -1.215010 -1.287757    -0.931108  1.310194
# 1 2016-01-01 01:00:00  1.023619 -1.219871 -1.292549    -0.943763  1.291557
# 2 2016-01-01 02:00:00  1.016829 -1.285489 -1.356046    -1.018109  1.322619
# 3 2016-01-01 03:00:00  1.071150 -1.436169 -1.509398    -1.215839  1.316406
# 4 2016-01-01 04:00:00  1.090388 -1.411866 -1.486635    -1.171547  1.353681
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx  \
# 0     -0.984703     -0.925270     -0.785769 -0.250515  0.092669 -0.309262
# 1     -0.985945     -0.932440     -0.781896  0.167604  0.320749  0.120280
# 2     -1.015752     -0.980240     -0.789642  0.186484  0.360343  0.187566
# 3     -1.079091     -1.099742     -0.791579  0.152370  0.210266  0.153937
# 4     -1.069155     -1.073452     -0.797389  0.213992  0.276405  0.179252
#
#      max Wy   Day sin   Day cos  Year sin  Year cos
# 0  0.100154  0.000041  1.413911 -0.014694  1.411105
# 1  0.352602  0.366006  1.365720 -0.013676  1.411107
# 2  0.377302  0.707031  1.224433 -0.012659  1.411109
# 3  0.225093  0.999877  0.999677 -0.011641  1.411110
# 4  0.297489  1.224585  0.706769 -0.010624  1.411110

# %%
# Now we MinMax scale every column except the first column
scaler = MinMaxScaler(feature_range=(-1, 1)) # This is the scaler we will use to scale every column to values from 0 to 1
df2 = pd.DataFrame(scaler.fit_transform(df2.iloc[:, 1:]), columns=df2.columns[1:]) # Take all columns except the first

# %%
df2.head()
# Out:
#    p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0  0.444197 -0.430952 -0.431170    -0.151826  0.921322     -0.847363
# 1  0.443511 -0.432618 -0.432788    -0.156393  0.913454     -0.847747
# 2  0.441454 -0.455114 -0.454215    -0.183219  0.926567     -0.856951
# 3  0.457912 -0.506769 -0.505963    -0.254566  0.923944     -0.876510
# 4  0.463741 -0.498438 -0.498282    -0.238584  0.939680     -0.873442
#
#    VPact (mbar)  VPdef (mbar)        Wx        Wy    max Wx    max Wy  \
# 0     -0.616981     -0.991234  0.096388 -0.060593  0.043580 -0.116223
# 1     -0.619811     -0.990261  0.191060 -0.007101  0.142289 -0.056098
# 2     -0.638679     -0.992208  0.195335  0.002185  0.157751 -0.050215
# 3     -0.685849     -0.992695  0.187611 -0.033013  0.150023 -0.086466
# 4     -0.675472     -0.994156  0.201564 -0.017501  0.155841 -0.069224
#
#         Day sin   Day cos  Year sin  Year cos
# 0 -1.407980e-12  1.000000 -0.002666  0.999996
# 1  2.588190e-01  0.965926 -0.001950  0.999998
# 2  5.000000e-01  0.866025 -0.001233  0.999999
# 3  7.071068e-01  0.707107 -0.000516  1.000000
# 4  8.660254e-01  0.500000  0.000201  1.000000

# %%
column_names = df2.columns.tolist()
print(column_names)
# Out:
# ['p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)', 'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'Wx', 'Wy', 'max Wx', 'max Wy', 'Day sin', 'Day cos', 'Year sin', 'Year cos']

# %%
def prepare_dataframe_for_lstm(df, n_steps):
   
    for i in range(1, n_steps+1):
        df[f'p (mbar)(t-{i})'] = df['p (mbar)'].shift(i)
    
    for i in range(1, n_steps+1):
        df[f'T (degC)(t-{i})'] = df['T (degC)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'rh (%)(t-{i})'] = df['rh (%)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tpot (K)(t-{i})'] = df['Tpot (K)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Tdew (degC)(t-{i})'] = df['Tdew (degC)'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'VPmax (mbar)(t-{i})'] = df['VPmax (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPact (mbar)(t-{i})'] = df['VPact (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'VPdef (mbar)(t-{i})'] = df['VPdef (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wx(t-{i})'] = df['Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Wy(t-{i})'] = df['Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wx(t-{i})'] = df['max Wx'].shift(i)

    for i in range(1, n_steps+1):
        df[f'max Wy(t-{i})'] = df['max Wy'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
   
    # Return the shifted dataframe
    return df

# %%
prepare_dataframe_for_lstm(df2, n_steps=lookback)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Day cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year sin(t-{i})'] = df['Day sin'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9152\2134815107.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Year cos(t-{i})'] = df['Day cos'].shift(i)
#       p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  VPmax (mbar)  \
# 0     0.444197 -0.430952 -0.431170    -0.151826  0.921322     -0.847363
# 1     0.443511 -0.432618 -0.432788    -0.156393  0.913454     -0.847747
# 2     0.441454 -0.455114 -0.454215    -0.183219  0.926567     -0.856951
# 3     0.457912 -0.506769 -0.505963    -0.254566  0.923944     -0.876510
# 4     0.463741 -0.498438 -0.498282    -0.238584  0.939680     -0.873442
# ...        ...       ...       ...          ...       ...           ...
# 8705  0.550489 -0.471360 -0.480089    -0.432648  0.268293     -0.863087
# 8706  0.523744 -0.488856 -0.494239    -0.517123  0.118542     -0.869990
# 8707  0.516544 -0.545095 -0.548413    -0.520548  0.291896     -0.889933
# 8708  0.498028 -0.550927 -0.552456    -0.534817  0.276161     -0.892234
# 8709  0.479513 -0.594251 -0.592480    -0.588470  0.284028     -0.906424
#
#       VPact (mbar)  VPdef (mbar)        Wx        Wy  ...  Year sin(t-7)  \
# 0        -0.616981     -0.991234  0.096388 -0.060593  ...            NaN
# 1        -0.619811     -0.990261  0.191060 -0.007101  ...            NaN
# 2        -0.638679     -0.992208  0.195335  0.002185  ...            NaN
# 3        -0.685849     -0.992695  0.187611 -0.033013  ...            NaN
# 4        -0.675472     -0.994156  0.201564 -0.017501  ...            NaN
# ...            ...           ...       ...       ...  ...            ...
# 8705     -0.788679     -0.923058  0.129772 -0.047034  ...      -0.043619
# 8706     -0.830189     -0.909910  0.146472 -0.133245  ...      -0.300706
# 8707     -0.831132     -0.934746  0.153045  0.016600  ...      -0.537300
# 8708     -0.837736     -0.933772  0.198818 -0.054515  ...      -0.737277
# 8709     -0.862264     -0.939615  0.170411 -0.055434  ...      -0.887011
#
#       Year sin(t-8)  Year cos(t-1)  Year cos(t-2)  Year cos(t-3)  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN       1.000000            NaN            NaN
# 2               NaN       0.965926       1.000000            NaN
# 3               NaN       0.866025       0.965926       1.000000
# 4               NaN       0.707107       0.866025       0.965926
# ...             ...            ...            ...            ...
# 8705       0.216440       0.043619      -0.216440      -0.461749
# 8706      -0.043619       0.300706       0.043619      -0.216440
# 8707      -0.300706       0.537300       0.300706       0.043619
# 8708      -0.537300       0.737277       0.537300       0.300706
# 8709      -0.737277       0.887011       0.737277       0.537300
#
#       Year cos(t-4)  Year cos(t-5)  Year cos(t-6)  Year cos(t-7)  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4          1.000000            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 8705      -0.675590      -0.843391      -0.953717      -0.999048
# 8706      -0.461749      -0.675590      -0.843391      -0.953717
# 8707      -0.216440      -0.461749      -0.675590      -0.843391
# 8708       0.043619      -0.216440      -0.461749      -0.675590
# 8709       0.300706       0.043619      -0.216440      -0.461749
#
#       Year cos(t-8)
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 8705      -0.976296
# 8706      -0.999048
# 8707      -0.953717
# 8708      -0.843391
# 8709      -0.675590
#
# [8710 rows x 144 columns]

# %%
# Define a list of timepoints to group by
timepoints = [f't-{i}' for i in range(lookback, 0, -1)]

# Group the shifted columns by timepoint
all_shifted_cols = []
for timepoint in timepoints:
    columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 
                                                 'Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos' ]] #'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
    all_shifted_cols.extend(columns)
    
# Concatenate the target columns and the grouped columns
target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy']
feature_cols = ['Tpot (K)', 'Tdew (degC)', 
                                                 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 
                                                 'max Wx', 'max Wy', 'Day sin', 
                                                 'Day cos', 'Year sin', 'Year cos'] # 'sh (g/kg)', 'H2OC (mmol/mol)', 'rho (g/m**3)'
all_cols = target_cols + feature_cols + all_shifted_cols

# %%
# Let us take a look at the final variable 'all_cols'
all_cols
# Out:
# ['p (mbar)',
#  'T (degC)',
#  'rh (%)',
#  'Wx',
#  'Wy',
#  'Tpot (K)',
#  'Tdew (degC)',
#  'VPmax (mbar)',
#  'VPact (mbar)',
#  'VPdef (mbar)',
#  'max Wx',
#  'max Wy',
#  'Day sin',
#  'Day cos',
#  'Year sin',
#  'Year cos',
#  'p (mbar)(t-8)',
#  'T (degC)(t-8)',
#  'rh (%)(t-8)',
#  'Wx(t-8)',
#  'Wy(t-8)',
#  'Tpot (K)(t-8)',
#  'Tdew (degC)(t-8)',
#  'VPmax (mbar)(t-8)',
#  'VPact (mbar)(t-8)',
#  'VPdef (mbar)(t-8)',
#  'max Wx(t-8)',
#  'max Wy(t-8)',
#  'Day sin(t-8)',
#  'Day cos(t-8)',
#  'Year sin(t-8)',
#  'Year cos(t-8)',
#  'p (mbar)(t-7)',
#  'T (degC)(t-7)',
#  'rh (%)(t-7)',
#  'Wx(t-7)',
#  'Wy(t-7)',
#  'Tpot (K)(t-7)',
#  'Tdew (degC)(t-7)',
#  'VPmax (mbar)(t-7)',
#  'VPact (mbar)(t-7)',
#  'VPdef (mbar)(t-7)',
#  'max Wx(t-7)',
#  'max Wy(t-7)',
#  'Day sin(t-7)',
#  'Day cos(t-7)',
#  'Year sin(t-7)',
#  'Year cos(t-7)',
#  'p (mbar)(t-6)',
#  'T (degC)(t-6)',
#  'rh (%)(t-6)',
#  'Wx(t-6)',
#  'Wy(t-6)',
#  'Tpot (K)(t-6)',
#  'Tdew (degC)(t-6)',
#  'VPmax (mbar)(t-6)',
#  'VPact (mbar)(t-6)',
#  'VPdef (mbar)(t-6)',
#  'max Wx(t-6)',
#  'max Wy(t-6)',
#  'Day sin(t-6)',
#  'Day cos(t-6)',
#  'Year sin(t-6)',
#  'Year cos(t-6)',
#  'p (mbar)(t-5)',
#  'T (degC)(t-5)',
#  'rh (%)(t-5)',
#  'Wx(t-5)',
#  'Wy(t-5)',
#  'Tpot (K)(t-5)',
#  'Tdew (degC)(t-5)',
#  'VPmax (mbar)(t-5)',
#  'VPact (mbar)(t-5)',
#  'VPdef (mbar)(t-5)',
#  'max Wx(t-5)',
#  'max Wy(t-5)',
#  'Day sin(t-5)',
#  'Day cos(t-5)',
#  'Year sin(t-5)',
#  'Year cos(t-5)',
#  'p (mbar)(t-4)',
#  'T (degC)(t-4)',
#  'rh (%)(t-4)',
#  'Wx(t-4)',
#  'Wy(t-4)',
#  'Tpot (K)(t-4)',
#  'Tdew (degC)(t-4)',
#  'VPmax (mbar)(t-4)',
#  'VPact (mbar)(t-4)',
#  'VPdef (mbar)(t-4)',
#  'max Wx(t-4)',
#  'max Wy(t-4)',
#  'Day sin(t-4)',
#  'Day cos(t-4)',
#  'Year sin(t-4)',
#  'Year cos(t-4)',
#  'p (mbar)(t-3)',
#  'T (degC)(t-3)',
#  'rh (%)(t-3)',
#  'Wx(t-3)',
#  'Wy(t-3)',
#  'Tpot (K)(t-3)',
#  'Tdew (degC)(t-3)',
#  'VPmax (mbar)(t-3)',
#  'VPact (mbar)(t-3)',
#  'VPdef (mbar)(t-3)',
#  'max Wx(t-3)',
#  'max Wy(t-3)',
#  'Day sin(t-3)',
#  'Day cos(t-3)',
#  'Year sin(t-3)',
#  'Year cos(t-3)',
#  'p (mbar)(t-2)',
#  'T (degC)(t-2)',
#  'rh (%)(t-2)',
#  'Wx(t-2)',
#  'Wy(t-2)',
#  'Tpot (K)(t-2)',
#  'Tdew (degC)(t-2)',
#  'VPmax (mbar)(t-2)',
#  'VPact (mbar)(t-2)',
#  'VPdef (mbar)(t-2)',
#  'max Wx(t-2)',
#  'max Wy(t-2)',
#  'Day sin(t-2)',
#  'Day cos(t-2)',
#  'Year sin(t-2)',
#  'Year cos(t-2)',
#  'p (mbar)(t-1)',
#  'T (degC)(t-1)',
#  'rh (%)(t-1)',
#  'Wx(t-1)',
#  'Wy(t-1)',
#  'Tpot (K)(t-1)',
#  'Tdew (degC)(t-1)',
#  'VPmax (mbar)(t-1)',
#  'VPact (mbar)(t-1)',
#  'VPdef (mbar)(t-1)',
#  'max Wx(t-1)',
#  'max Wy(t-1)',
#  'Day sin(t-1)',
#  'Day cos(t-1)',
#  'Year sin(t-1)',
#  'Year cos(t-1)']

# %%
# First we udpate the df
df2 = df2[all_cols]

# %%
df2.head()
# Out:
#    p (mbar)  T (degC)    rh (%)        Wx        Wy  Tpot (K)  Tdew (degC)  \
# 0  0.444197 -0.430952  0.921322  0.096388 -0.060593 -0.431170    -0.151826
# 1  0.443511 -0.432618  0.913454  0.191060 -0.007101 -0.432788    -0.156393
# 2  0.441454 -0.455114  0.926567  0.195335  0.002185 -0.454215    -0.183219
# 3  0.457912 -0.506769  0.923944  0.187611 -0.033013 -0.505963    -0.254566
# 4  0.463741 -0.498438  0.939680  0.201564 -0.017501 -0.498282    -0.238584
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  ...  Tdew (degC)(t-1)  \
# 0     -0.847363     -0.616981     -0.991234  ...               NaN
# 1     -0.847747     -0.619811     -0.990261  ...         -0.151826
# 2     -0.856951     -0.638679     -0.992208  ...         -0.156393
# 3     -0.876510     -0.685849     -0.992695  ...         -0.183219
# 4     -0.873442     -0.675472     -0.994156  ...         -0.254566
#
#    VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 0                NaN                NaN                NaN          NaN
# 1          -0.847363          -0.616981          -0.991234     0.043580
# 2          -0.847747          -0.619811          -0.990261     0.142289
# 3          -0.856951          -0.638679          -0.992208     0.157751
# 4          -0.876510          -0.685849          -0.992695     0.150023
#
#    max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0          NaN           NaN           NaN            NaN            NaN
# 1    -0.116223 -1.407980e-12      1.000000  -1.407980e-12       1.000000
# 2    -0.056098  2.588190e-01      0.965926   2.588190e-01       0.965926
# 3    -0.050215  5.000000e-01      0.866025   5.000000e-01       0.866025
# 4    -0.086466  7.071068e-01      0.707107   7.071068e-01       0.707107
#
# [5 rows x 144 columns]

# %%
print(df2.columns[:60])
# Out:
# Index(['p (mbar)', 'T (degC)', 'rh (%)', 'Wx', 'Wy', 'Tpot (K)', 'Tdew (degC)',
#        'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'max Wx', 'max Wy',
#        'Day sin', 'Day cos', 'Year sin', 'Year cos', 'p (mbar)(t-8)',
#        'T (degC)(t-8)', 'rh (%)(t-8)', 'Wx(t-8)', 'Wy(t-8)', 'Tpot (K)(t-8)',
#        'Tdew (degC)(t-8)', 'VPmax (mbar)(t-8)', 'VPact (mbar)(t-8)',
#        'VPdef (mbar)(t-8)', 'max Wx(t-8)', 'max Wy(t-8)', 'Day sin(t-8)',
#        'Day cos(t-8)', 'Year sin(t-8)', 'Year cos(t-8)', 'p (mbar)(t-7)',
#        'T (degC)(t-7)', 'rh (%)(t-7)', 'Wx(t-7)', 'Wy(t-7)', 'Tpot (K)(t-7)',
#        'Tdew (degC)(t-7)', 'VPmax (mbar)(t-7)', 'VPact (mbar)(t-7)',
#        'VPdef (mbar)(t-7)', 'max Wx(t-7)', 'max Wy(t-7)', 'Day sin(t-7)',
#        'Day cos(t-7)', 'Year sin(t-7)', 'Year cos(t-7)', 'p (mbar)(t-6)',
#        'T (degC)(t-6)', 'rh (%)(t-6)', 'Wx(t-6)', 'Wy(t-6)', 'Tpot (K)(t-6)',
#        'Tdew (degC)(t-6)', 'VPmax (mbar)(t-6)', 'VPact (mbar)(t-6)',
#        'VPdef (mbar)(t-6)', 'max Wx(t-6)', 'max Wy(t-6)'],
#       dtype='object')

# %%
shifted_df2 = df2.drop(df2.columns[5:16], axis=1) # We delete the custom features at timpoint t

# %%
shifted_df2.head(9)
# Out:
#    p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 0  0.444197 -0.430952  0.921322  0.096388 -0.060593            NaN
# 1  0.443511 -0.432618  0.913454  0.191060 -0.007101            NaN
# 2  0.441454 -0.455114  0.926567  0.195335  0.002185            NaN
# 3  0.457912 -0.506769  0.923944  0.187611 -0.033013            NaN
# 4  0.463741 -0.498438  0.939680  0.201564 -0.017501            NaN
# 5  0.464769 -0.507186  0.950170  0.126132 -0.036362            NaN
# 6  0.454140 -0.506353  0.950170  0.147457 -0.014563            NaN
# 7  0.463741 -0.489690  0.958038  0.123739 -0.171007            NaN
# 8  0.465112 -0.470944  0.952793  0.120035 -0.066790       0.444197
#
#    T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 0            NaN          NaN       NaN       NaN  ...               NaN
# 1            NaN          NaN       NaN       NaN  ...         -0.151826
# 2            NaN          NaN       NaN       NaN  ...         -0.156393
# 3            NaN          NaN       NaN       NaN  ...         -0.183219
# 4            NaN          NaN       NaN       NaN  ...         -0.254566
# 5            NaN          NaN       NaN       NaN  ...         -0.238584
# 6            NaN          NaN       NaN       NaN  ...         -0.247146
# 7            NaN          NaN       NaN       NaN  ...         -0.246005
# 8      -0.430952     0.921322  0.096388 -0.060593  ...         -0.220890
#
#    VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 0                NaN                NaN                NaN          NaN
# 1          -0.847363          -0.616981          -0.991234     0.043580
# 2          -0.847747          -0.619811          -0.990261     0.142289
# 3          -0.856951          -0.638679          -0.992208     0.157751
# 4          -0.876510          -0.685849          -0.992695     0.150023
# 5          -0.873442          -0.675472          -0.994156     0.155841
# 6          -0.876510          -0.681132          -0.995130     0.091968
# 7          -0.876510          -0.680189          -0.995130     0.093277
# 8          -0.870374          -0.664151          -0.996104     0.088612
#
#    max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 0          NaN           NaN           NaN            NaN            NaN
# 1    -0.116223 -1.407980e-12  1.000000e+00  -1.407980e-12   1.000000e+00
# 2    -0.056098  2.588190e-01  9.659258e-01   2.588190e-01   9.659258e-01
# 3    -0.050215  5.000000e-01  8.660254e-01   5.000000e-01   8.660254e-01
# 4    -0.086466  7.071068e-01  7.071068e-01   7.071068e-01   7.071068e-01
# 5    -0.069224  8.660254e-01  5.000000e-01   8.660254e-01   5.000000e-01
# 6    -0.088767  9.659258e-01  2.588190e-01   9.659258e-01   2.588190e-01
# 7    -0.066569  1.000000e+00  3.971375e-12   1.000000e+00   3.971375e-12
# 8    -0.216043  9.659258e-01 -2.588190e-01   9.659258e-01  -2.588190e-01
#
# [9 rows x 133 columns]

# %%
shifted_df2 = shifted_df2.dropna()

# %%
shifted_df2.head(9)
# Out:
#     p (mbar)  T (degC)    rh (%)        Wx        Wy  p (mbar)(t-8)  \
# 8   0.465112 -0.470944  0.952793  0.120035 -0.066790       0.444197
# 9   0.477799 -0.490523  0.955416  0.004206 -0.021658       0.443511
# 10  0.483971 -0.453447  0.958038  0.108342 -0.084333       0.441454
# 11  0.491171 -0.463862  0.947548 -0.011190  0.107134       0.457912
# 12  0.471970 -0.431785  0.947548  0.121641  0.017620       0.463741
# 13  0.455512 -0.366799  0.887228  0.147575  0.034328       0.464769
# 14  0.440082 -0.328890  0.897718  0.132310  0.020068       0.454140
# 15  0.445911 -0.337638  0.876737  0.153612 -0.042831       0.463741
# 16  0.445568 -0.339304  0.803304  0.158196 -0.016412       0.465112
#
#     T (degC)(t-8)  rh (%)(t-8)   Wx(t-8)   Wy(t-8)  ...  Tdew (degC)(t-1)  \
# 8       -0.430952     0.921322  0.096388 -0.060593  ...         -0.220890
# 9       -0.432618     0.913454  0.191060 -0.007101  ...         -0.196918
# 10      -0.455114     0.926567  0.195335  0.002185  ...         -0.222603
# 11      -0.506769     0.923944  0.187611 -0.033013  ...         -0.171804
# 12      -0.498438     0.939680  0.201564 -0.017501  ...         -0.188927
# 13      -0.507186     0.950170  0.126132 -0.036362  ...         -0.144977
# 14      -0.506353     0.950170  0.147457 -0.014563  ...         -0.074772
# 15      -0.489690     0.958038  0.123739 -0.171007  ...         -0.019977
# 16      -0.470944     0.952793  0.120035 -0.066790  ...         -0.038813
#
#     VPmax (mbar)(t-1)  VPact (mbar)(t-1)  VPdef (mbar)(t-1)  max Wx(t-1)  \
# 8           -0.870374          -0.664151          -0.996104     0.088612
# 9           -0.863087          -0.648113          -0.995130     0.079821
# 10          -0.870374          -0.665094          -0.995617    -0.022625
# 11          -0.856184          -0.630189          -0.995617     0.059576
# 12          -0.860403          -0.642453          -0.994643    -0.069379
# 13          -0.847747          -0.612264          -0.994156     0.055046
# 14          -0.819751          -0.559434          -0.985878     0.102564
# 15          -0.802109          -0.515094          -0.986365     0.070395
# 16          -0.806328          -0.530189          -0.983930     0.098137
#
#     max Wy(t-1)  Day sin(t-1)  Day cos(t-1)  Year sin(t-1)  Year cos(t-1)
# 8     -0.216043  9.659258e-01     -0.258819   9.659258e-01      -0.258819
# 9     -0.119448  8.660254e-01     -0.500000   8.660254e-01      -0.500000
# 10    -0.075033  7.071068e-01     -0.707107   7.071068e-01      -0.707107
# 11    -0.140359  5.000000e-01     -0.866025   5.000000e-01      -0.866025
# 12     0.056958  2.588190e-01     -0.965926   2.588190e-01      -0.965926
# 13    -0.027284  6.534489e-12     -1.000000   6.534489e-12      -1.000000
# 14    -0.015710 -2.588190e-01     -0.965926  -2.588190e-01      -0.965926
# 15    -0.024915 -5.000000e-01     -0.866025  -5.000000e-01      -0.866025
# 16    -0.099934 -7.071068e-01     -0.707107  -7.071068e-01      -0.707107
#
# [9 rows x 133 columns]

# %%
# We convert to numpy and print
shifted_df2_as_np = shifted_df2.to_numpy()
print(shifted_df2_as_np)
# Out:
# [[ 0.46511229 -0.47094355  0.95279308 ... -0.25881905  0.96592583
#   -0.25881905]
#  [ 0.47779873 -0.49052281  0.95541568 ... -0.5         0.8660254
#   -0.5       ]
#  [ 0.48397051 -0.4534472   0.95803829 ... -0.70710678  0.70710678
#   -0.70710678]
#  ...
#  [ 0.5165438  -0.54509477  0.29189614 ...  0.53729961 -0.84339145
#    0.53729961]
#  [ 0.49802846 -0.55092689  0.2761605  ...  0.73727734 -0.67559021
#    0.73727734]
#  [ 0.47951312 -0.5942512   0.28402832 ...  0.88701083 -0.46174861
#    0.88701083]]

# %%
print(shifted_df2_as_np.shape)
# Out:
# (8702, 133)

# %%
X_eval = shifted_df2_as_np[:, 5:]
y_eval = shifted_df2_as_np[:, :5]
print(X_eval.shape, y_eval.shape)
# Out:
# (8702, 128) (8702, 5)

# %%
# Because this is the LSTM model, we WILL reshape the the X values

X_eval = X_eval.reshape(-1, lookback, 16)

print(X_eval.shape)
print(y_eval.shape)
# Out:
# (8702, 8, 16)
# (8702, 5)

# %%
# Pytorch only deals with tensors, so we need to convert these last np arrays into torch floats:
X_eval = torch.tensor(X_eval).float()
y_eval = torch.tensor(y_eval).float()

print(X_eval.shape, y_eval.shape) #, y_train.shape, y_test.shape) # Inspect the shape once again
# Out:
# torch.Size([8702, 8, 16]) torch.Size([8702, 5])

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset): # Nothing fancy here, just making sure we can access length and individual items
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]
    
eval_dataset = TimeSeriesDataset(X_eval, y_eval)

# %%
from torch.utils.data import DataLoader

batch_size = batch_size # We will try batch_size values of 64 and 32

eval_loader = DataLoader(eval_dataset, batch_size=batch_size, shuffle=True)

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(eval_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([64, 8, 16]) torch.Size([64, 5])

# %%
def evaluate_model(model, dataloader, loss_function, num_epochs):
    model.eval()
    with torch.no_grad():
        for epoch in range(num_epochs):
            running_loss = 0.0
            running_correct = 0.0
            running_total = 0.0
            
            running_mae = np.zeros((5,))
            running_r2 = np.zeros((5,))
            running_counts = np.zeros((5,))
            
            for batch_index, batch in enumerate(dataloader):
                x_batch, y_batch = batch[0].to(device), batch[1].to(device)

                output = model(x_batch)
                loss = loss_function(output, y_batch)
                running_loss += loss.item()
                running_total += y_batch.size(0)

                y_pred = output.detach().cpu().numpy()
                y_true = y_batch.detach().cpu().numpy()
                
                for i in range(5):
                    running_mae[i] += mean_absolute_error(y_true[:, i], y_pred[:, i])
                    running_r2[i] += r2_score(y_true[:, i], y_pred[:, i])
                    running_counts[i] += 1
                    
                r2 = r2_score(y_true, y_pred)
                running_correct += r2*y_batch.size(0)

            avg_loss_across_batches = running_loss / len(dataloader)
            avg_r2_across_batches = running_correct / running_total
            avg_mae_across_targets = running_mae / running_counts
            avg_r2_across_targets = running_r2 / running_counts

            test_losses.append(avg_loss_across_batches)
            test_r2s.append(avg_r2_across_batches)

            print('Epoch {0}, Test MAE Loss: {1:.3f}'.format(epoch+1, avg_loss_across_batches))
            print('Epoch {0}, Test R2 Score: {1:.3f}'.format(epoch+1, avg_r2_across_batches))
            print('Test individual target MAEs:', avg_mae_across_targets)
            print('Test individual target R2s:', avg_r2_across_targets)
            print('***************************************************')

# %%
### We're ready to evaluate ! ###

loss_function = nn.L1Loss() 
num_epochs = 50

test_losses = []
test_r2s = []

evaluate_model(model=model, dataloader = eval_loader, loss_function = loss_function, num_epochs = num_epochs)
# Out:
# Epoch 1, Test MAE Loss: 0.079
# Epoch 1, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957392 0.0429847  0.10686335 0.08787337 0.09677647]
# Test individual target R2s: [0.95064908 0.97758833 0.89301135 0.70033816 0.68013524]
# ***************************************************
# Epoch 2, Test MAE Loss: 0.079
# Epoch 2, Test R2 Score: 0.842
# Test individual target MAEs: [0.05957448 0.04298416 0.1068669  0.08787606 0.0967809 ]
# Test individual target R2s: [0.95078331 0.97772808 0.894182   0.70426603 0.68151208]
# ***************************************************
# Epoch 3, Test MAE Loss: 0.079
# Epoch 3, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957424 0.04298345 0.10685984 0.0878753  0.09677896]
# Test individual target R2s: [0.95108381 0.97779304 0.89229702 0.70008399 0.679613  ]
# ***************************************************
# Epoch 4, Test MAE Loss: 0.079
# Epoch 4, Test R2 Score: 0.841
# Test individual target MAEs: [0.05957522 0.04298491 0.10686057 0.08787316 0.09677644]
# Test individual target R2s: [0.95117993 0.97776825 0.89241479 0.70218318 0.6790147 ]
# ***************************************************
# Epoch 5, Test MAE Loss: 0.079
# Epoch 5, Test R2 Score: 0.841
# Test individual target MAEs: [0.05957521 0.04298248 0.1068693  0.08787435 0.09677605]
# Test individual target R2s: [0.95115862 0.97774905 0.89307217 0.7044397  0.67983537]
# ***************************************************
# Epoch 6, Test MAE Loss: 0.079
# Epoch 6, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957555 0.04298508 0.10686374 0.08787371 0.09677857]
# Test individual target R2s: [0.95102291 0.97771706 0.89302569 0.69701799 0.67745833]
# ***************************************************
# Epoch 7, Test MAE Loss: 0.079
# Epoch 7, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957689 0.0429846  0.10686918 0.0878782  0.09677561]
# Test individual target R2s: [0.95102079 0.9777438  0.89359329 0.69798511 0.67782449]
# ***************************************************
# Epoch 8, Test MAE Loss: 0.079
# Epoch 8, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957528 0.04298456 0.10686697 0.08787465 0.09677831]
# Test individual target R2s: [0.95085398 0.97778207 0.89296036 0.69837182 0.68008972]
# ***************************************************
# Epoch 9, Test MAE Loss: 0.079
# Epoch 9, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957545 0.04298348 0.10686507 0.08787321 0.09677703]
# Test individual target R2s: [0.95098462 0.97771448 0.89321627 0.7000614  0.67872991]
# ***************************************************
# Epoch 10, Test MAE Loss: 0.079
# Epoch 10, Test R2 Score: 0.839
# Test individual target MAEs: [0.0595759  0.04298445 0.10686301 0.08787268 0.09677677]
# Test individual target R2s: [0.95032519 0.97760407 0.89286192 0.69916741 0.67679934]
# ***************************************************
# Epoch 11, Test MAE Loss: 0.079
# Epoch 11, Test R2 Score: 0.839
# Test individual target MAEs: [0.0595746  0.04298556 0.10686076 0.08787091 0.09677613]
# Test individual target R2s: [0.95067237 0.97773101 0.89358984 0.7002563  0.67292381]
# ***************************************************
# Epoch 12, Test MAE Loss: 0.079
# Epoch 12, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957544 0.04298472 0.10686817 0.08787725 0.09677625]
# Test individual target R2s: [0.95103104 0.97763369 0.89258413 0.69789718 0.67854572]
# ***************************************************
# Epoch 13, Test MAE Loss: 0.079
# Epoch 13, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957484 0.04298448 0.10686652 0.08787162 0.09677605]
# Test individual target R2s: [0.9506227  0.97761618 0.892899   0.70144252 0.67577049]
# ***************************************************
# Epoch 14, Test MAE Loss: 0.079
# Epoch 14, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957591 0.04298426 0.10686407 0.08787625 0.0967745 ]
# Test individual target R2s: [0.95094081 0.97783898 0.89267286 0.7016453  0.67633154]
# ***************************************************
# Epoch 15, Test MAE Loss: 0.079
# Epoch 15, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957458 0.04298473 0.10686511 0.08787808 0.09678104]
# Test individual target R2s: [0.95083445 0.97773402 0.89362916 0.70190837 0.67594322]
# ***************************************************
# Epoch 16, Test MAE Loss: 0.079
# Epoch 16, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957485 0.042985   0.10686426 0.08787156 0.09677598]
# Test individual target R2s: [0.95093296 0.97767522 0.89328459 0.7004141  0.67985695]
# ***************************************************
# Epoch 17, Test MAE Loss: 0.079
# Epoch 17, Test R2 Score: 0.840
# Test individual target MAEs: [0.0595764  0.04298412 0.10687145 0.08787661 0.09677807]
# Test individual target R2s: [0.95104765 0.97763757 0.89324639 0.69895225 0.67781425]
# ***************************************************
# Epoch 18, Test MAE Loss: 0.079
# Epoch 18, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957417 0.04298489 0.10686334 0.08787458 0.09677557]
# Test individual target R2s: [0.95078582 0.97761804 0.89240384 0.70078506 0.67793593]
# ***************************************************
# Epoch 19, Test MAE Loss: 0.079
# Epoch 19, Test R2 Score: 0.841
# Test individual target MAEs: [0.05957532 0.04298396 0.10686465 0.0878739  0.09678159]
# Test individual target R2s: [0.95079531 0.97761112 0.89326062 0.70115152 0.68015412]
# ***************************************************
# Epoch 20, Test MAE Loss: 0.079
# Epoch 20, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957391 0.04298587 0.10686452 0.08787192 0.09677787]
# Test individual target R2s: [0.95083948 0.97771066 0.89300492 0.69906642 0.67887005]
# ***************************************************
# Epoch 21, Test MAE Loss: 0.079
# Epoch 21, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957615 0.04298314 0.10686312 0.08787575 0.09677762]
# Test individual target R2s: [0.95052819 0.97771226 0.89396652 0.6978394  0.67682651]
# ***************************************************
# Epoch 22, Test MAE Loss: 0.079
# Epoch 22, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957439 0.04298455 0.10686259 0.08787256 0.09677605]
# Test individual target R2s: [0.95075918 0.97775702 0.89227626 0.70256861 0.67700915]
# ***************************************************
# Epoch 23, Test MAE Loss: 0.079
# Epoch 23, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957617 0.04298478 0.10686421 0.08787299 0.09677664]
# Test individual target R2s: [0.95097142 0.97777326 0.8932123  0.69656128 0.67472431]
# ***************************************************
# Epoch 24, Test MAE Loss: 0.079
# Epoch 24, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957535 0.0429849  0.10686543 0.08787391 0.09677448]
# Test individual target R2s: [0.95092536 0.97764558 0.8922332  0.69837905 0.67993117]
# ***************************************************
# Epoch 25, Test MAE Loss: 0.079
# Epoch 25, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957479 0.0429851  0.10686461 0.08787949 0.09678034]
# Test individual target R2s: [0.95090614 0.97762985 0.89261873 0.70236246 0.67741164]
# ***************************************************
# Epoch 26, Test MAE Loss: 0.079
# Epoch 26, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957466 0.04298359 0.10686865 0.08787552 0.09677451]
# Test individual target R2s: [0.95100826 0.97772029 0.89283884 0.70271891 0.6749725 ]
# ***************************************************
# Epoch 27, Test MAE Loss: 0.079
# Epoch 27, Test R2 Score: 0.839
# Test individual target MAEs: [0.0595762  0.04298539 0.10686619 0.0878774  0.09677587]
# Test individual target R2s: [0.95071236 0.97765506 0.89206513 0.69540401 0.67759211]
# ***************************************************
# Epoch 28, Test MAE Loss: 0.079
# Epoch 28, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957508 0.042986   0.10686036 0.08787113 0.09677862]
# Test individual target R2s: [0.95084669 0.97764578 0.8927066  0.70027629 0.67935396]
# ***************************************************
# Epoch 29, Test MAE Loss: 0.079
# Epoch 29, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957651 0.04298383 0.10686754 0.08787598 0.09677843]
# Test individual target R2s: [0.9512754  0.97774628 0.89306178 0.69679654 0.67725995]
# ***************************************************
# Epoch 30, Test MAE Loss: 0.079
# Epoch 30, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957409 0.04298454 0.10686302 0.08787468 0.096775  ]
# Test individual target R2s: [0.95070431 0.97761776 0.89276324 0.69620401 0.67719506]
# ***************************************************
# Epoch 31, Test MAE Loss: 0.079
# Epoch 31, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957388 0.04298427 0.10686455 0.08787856 0.09677771]
# Test individual target R2s: [0.95082793 0.97753512 0.89239452 0.6972891  0.67989933]
# ***************************************************
# Epoch 32, Test MAE Loss: 0.079
# Epoch 32, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957563 0.04298426 0.10686245 0.08787647 0.09677793]
# Test individual target R2s: [0.95068085 0.9776634  0.89259622 0.69871765 0.67810934]
# ***************************************************
# Epoch 33, Test MAE Loss: 0.079
# Epoch 33, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957497 0.04298398 0.10686683 0.08787224 0.09677791]
# Test individual target R2s: [0.95084388 0.97751413 0.89206005 0.69902686 0.6792129 ]
# ***************************************************
# Epoch 34, Test MAE Loss: 0.079
# Epoch 34, Test R2 Score: 0.841
# Test individual target MAEs: [0.0595748  0.04298363 0.10686604 0.08787537 0.09677771]
# Test individual target R2s: [0.95103543 0.97776441 0.89345548 0.70133466 0.68091443]
# ***************************************************
# Epoch 35, Test MAE Loss: 0.079
# Epoch 35, Test R2 Score: 0.840
# Test individual target MAEs: [0.0595744  0.04298375 0.10686555 0.08787632 0.09677469]
# Test individual target R2s: [0.95069649 0.97752508 0.89389562 0.69862298 0.67940168]
# ***************************************************
# Epoch 36, Test MAE Loss: 0.079
# Epoch 36, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957533 0.04298434 0.10686847 0.08787465 0.09677932]
# Test individual target R2s: [0.9510991  0.97767249 0.89380864 0.70030769 0.67690587]
# ***************************************************
# Epoch 37, Test MAE Loss: 0.079
# Epoch 37, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957496 0.04298456 0.10686698 0.08787998 0.09677789]
# Test individual target R2s: [0.9509714  0.97771331 0.89220251 0.69874632 0.68021684]
# ***************************************************
# Epoch 38, Test MAE Loss: 0.079
# Epoch 38, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957385 0.0429837  0.10686378 0.08787265 0.09677654]
# Test individual target R2s: [0.95076839 0.97773709 0.89282554 0.69686156 0.68021675]
# ***************************************************
# Epoch 39, Test MAE Loss: 0.079
# Epoch 39, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957442 0.042985   0.10686642 0.08787378 0.09677426]
# Test individual target R2s: [0.95058589 0.97756683 0.89310935 0.69893031 0.68184505]
# ***************************************************
# Epoch 40, Test MAE Loss: 0.079
# Epoch 40, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957648 0.04298613 0.10686464 0.08787098 0.0967757 ]
# Test individual target R2s: [0.9510266  0.97762165 0.89329783 0.69351692 0.67746659]
# ***************************************************
# Epoch 41, Test MAE Loss: 0.079
# Epoch 41, Test R2 Score: 0.841
# Test individual target MAEs: [0.05957499 0.04298378 0.1068664  0.08787252 0.09677696]
# Test individual target R2s: [0.95106911 0.9779395  0.89389931 0.69967376 0.68008029]
# ***************************************************
# Epoch 42, Test MAE Loss: 0.079
# Epoch 42, Test R2 Score: 0.839
# Test individual target MAEs: [0.0595746  0.04298409 0.1068665  0.08787771 0.0967811 ]
# Test individual target R2s: [0.95119403 0.97768877 0.89282045 0.69503961 0.67595619]
# ***************************************************
# Epoch 43, Test MAE Loss: 0.079
# Epoch 43, Test R2 Score: 0.841
# Test individual target MAEs: [0.05957575 0.04298442 0.10686629 0.087871   0.09677438]
# Test individual target R2s: [0.95112121 0.97762175 0.89208987 0.70313815 0.68022592]
# ***************************************************
# Epoch 44, Test MAE Loss: 0.079
# Epoch 44, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957449 0.04298433 0.10686389 0.08787564 0.09677323]
# Test individual target R2s: [0.95060588 0.9776804  0.8927617  0.70017332 0.6782964 ]
# ***************************************************
# Epoch 45, Test MAE Loss: 0.079
# Epoch 45, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957536 0.04298485 0.10686567 0.08787421 0.09677247]
# Test individual target R2s: [0.95085053 0.97779532 0.89412367 0.69598049 0.67614789]
# ***************************************************
# Epoch 46, Test MAE Loss: 0.079
# Epoch 46, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957564 0.04298493 0.10686422 0.08787361 0.09677889]
# Test individual target R2s: [0.9510858  0.97768559 0.89321211 0.70066854 0.67633333]
# ***************************************************
# Epoch 47, Test MAE Loss: 0.079
# Epoch 47, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957589 0.04298405 0.10686572 0.08787916 0.09677531]
# Test individual target R2s: [0.95096804 0.97782167 0.89317959 0.69701878 0.67759417]
# ***************************************************
# Epoch 48, Test MAE Loss: 0.079
# Epoch 48, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957365 0.04298319 0.10686711 0.08787561 0.09677453]
# Test individual target R2s: [0.95086558 0.97776619 0.89257546 0.69745414 0.67718044]
# ***************************************************
# Epoch 49, Test MAE Loss: 0.079
# Epoch 49, Test R2 Score: 0.840
# Test individual target MAEs: [0.05957474 0.04298479 0.10686261 0.08787171 0.09677486]
# Test individual target R2s: [0.95101414 0.97776931 0.8932389  0.70152594 0.67800213]
# ***************************************************
# Epoch 50, Test MAE Loss: 0.079
# Epoch 50, Test R2 Score: 0.839
# Test individual target MAEs: [0.05957447 0.04298364 0.10686368 0.08787868 0.09677991]
# Test individual target R2s: [0.95091614 0.97786263 0.89279655 0.69885822 0.67451691]
# ***************************************************
