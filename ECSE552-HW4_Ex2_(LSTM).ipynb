# %% [markdown]
# # MODEL 2: LSTM solution

# %% [markdown]
# In this exercise, we are asked to build a `Seq2Vec` model using at least one nn.LSTM() layer. Using the values of a set of features at timepoints $t-k$ through $t-1$, we are asked to predict the following targets at timepoint $t$:
#
# - `p(mbar)`, atmospheric pressure
# - `T (degC)`, air temperature
# - `rh (%)`, relative humidity
# - `wv(m/s)`, wind velocity
#
# For simplicity, we will first initialize this model at  $k=4$. Then, once we get that model working, we will set  `k`  as a hyperparameter and iterate through `{4, 6, 8}`, along with two learning rate values `{0.01, 0.001}` and batch size `{32, 64}` .

# %%
# First we will import the necessary dependencies
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
import torchmetrics
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import transforms
from torch.utils.data import SubsetRandomSampler
import pytorch_lightning as L
import torch.utils.data
import datetime

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

# %%
# We can check the current working directory
import os
print(os.getcwd())

# We determine whether CUDA is available 
if torch.cuda.is_available():
    device = torch.device("cuda")
    print (f"Using GPU: {torch.cuda.get_device_name(device)}")
else: 
    device = torch.device("cpu")
    print (f"Using CPU")

# We empty the cuda cache for good measure and make sure both the cache and the RAM are at zero
torch.cuda.empty_cache()
print(f"CUDA cache used: {torch.cuda.memory_reserved() / 1e6:.1f} MB")
print(f"CUDA RAM used: {torch.cuda.memory_allocated() / 1e6:.1f} MB")
# Out:
# C:\Users\usuario\RecogniChess
# Using GPU: NVIDIA GeForce GTX 960M
# CUDA cache used: 0.0 MB
# CUDA RAM used: 0.0 MB

# %% [markdown]
# Before we do anything else, we will import the data and take a look at it:

# %%
# We import the training data
df = pd.read_csv(r"C:\Users\usuario\RecogniChess\HW4\weather_train.csv", header=0, parse_dates=[0])
print(df.shape)
# Out:
# (56072, 15)

# %%
df.dropna(inplace=True)
print(df.shape)
# Out:
# (56072, 15)

# %%
print(df.shape)
# Out:
# (56072, 15)

# %%
# Let's take a look
df.tail()
# Out:
#                 Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 56067 2015-05-24 14:00:00    991.94     17.16    290.99         9.83   62.00
# 56068 2015-05-24 15:00:00    991.52     17.77    291.64         9.29   57.52
# 56069 2015-05-24 16:00:00    990.96     19.40    293.32         9.07   51.17
# 56070 2015-05-24 17:00:00    990.56     19.03    292.98         9.04   52.25
# 56071 2015-05-24 18:00:00    990.23     18.46    292.44         8.97   53.89
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 56067         19.60         12.15          7.45       7.66            12.25
# 56068         20.37         11.72          8.66       7.38            11.82
# 56069         22.56         11.55         11.02       7.28            11.65
# 56070         22.05         11.52         10.53       7.27            11.63
# 56071         21.28         11.47          9.81       7.23            11.58
#
#        rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 56067       1184.73      3.00           4.60     32.83
# 56068       1181.94      0.88           2.28     99.40
# 56069       1174.77      0.62           1.36    143.00
# 56070       1175.79      0.79           1.36    197.10
# 56071       1177.72      1.11           2.62     49.24

# %% [markdown]
# Data looks good, but we need to apply a couple of changes:
# - First, we need to separate out the first column, which doesn't hold feature values but rather keeps time
# - Second, we seriously need to minmax scale the other columns because they're on vastly different scales right now.

# %%
# First, we will turn the first column into a Pandas datetime object
df['Date Time'] = pd.to_datetime(df['Date Time'])

# %%
# Filter out entries whose time is not at noon, 6 PM, midnight, or 6 AM
df = df[(df['Date Time'].dt.hour == 12) | (df['Date Time'].dt.hour == 18) | (df['Date Time'].dt.hour == 0) | (df['Date Time'].dt.hour == 6)]

# Add a new column indicating whether the hour is 12/18 or 0/6
df['Time of Day'] = df['Date Time'].apply(lambda x: 1 if x.hour in [12, 18] else 0)

# Map months to time of year
def map_month_to_time_of_year(month):
    if month in range(1, 4):
        return 0
    elif month in range(4, 7):
        return 1
    elif month in range(7, 10):
        return 2
    else:
        return 3
    
# Add a new column indicating the time of year
df['Time of Year'] = df['Date Time'].apply(lambda x: map_month_to_time_of_year(x.month))

# Reset the index of the resulting dataframe
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 06:00:00    997.71     -9.67    263.66       -10.62    92.7
# 1 2009-01-01 12:00:00   1000.30     -6.87    266.27        -8.28    89.6
# 2 2009-01-01 18:00:00   1000.16     -5.25    267.90        -6.75    89.1
# 3 2009-02-01 00:00:00    999.59     -4.54    268.65        -5.46    93.2
# 4 2009-02-01 06:00:00    998.00     -4.43    268.88        -4.94    96.2
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          2.93          2.71          0.21       1.69             2.72
# 1          3.64          3.27          0.38       2.03             3.26
# 2          4.13          3.68          0.45       2.29             3.68
# 3          4.36          4.06          0.30       2.53             4.06
# 4          4.39          4.23          0.17       2.64             4.23
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)  Time of Day  Time of Year
# 0       1317.71      0.05           0.50    146.00            0             0
# 1       1306.98      1.84           2.63    184.40            1             0
# 2       1298.68      0.55           1.00    183.70            1             0
# 3       1294.33      0.41           0.88    155.00            0             0
# 4       1291.66      0.81           2.13     40.88            0             0

# %% [markdown]
# We see that we only have samples collected every 6 hours. This will help our model look further into the past and learn weather patterns that operate on a timeframe larger than 8 hours.

# %%
# Now we MinMax scale every column except the first column
scaler = MinMaxScaler(feature_range=(-1, 1)) # This is the scaler we will use to scale every column to values from 0 to 1
df_scaled = pd.DataFrame(scaler.fit_transform(df.iloc[:, 1:]), columns=df.columns[1:]) # Take all columns except the first
df_scaled.insert(0, 'Date Time', df['Date Time'], True) # Insert the first column into the new dataframe

# %%
# Let's take a look again
df_scaled.tail(7)
# Out:
#                Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)    rh (%)  \
# 9338 2015-05-23 06:00:00  0.421768  0.072778  0.064858     0.247344  0.406065
# 9339 2015-05-23 12:00:00  0.378232  0.418125  0.413319     0.310210 -0.399773
# 9340 2015-05-23 18:00:00  0.343755  0.373338  0.371935     0.418166 -0.080156
# 9341 2015-05-24 00:00:00  0.400438  0.223933  0.217527     0.458053  0.496665
# 9342 2015-05-24 06:00:00  0.408327  0.163751  0.157016     0.390418  0.511765
# 9343 2015-05-24 12:00:00  0.400438  0.320854  0.314206     0.458053  0.165723
# 9344 2015-05-24 18:00:00  0.321841  0.420224  0.420970     0.435508 -0.160438
#
#       VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 9338     -0.635050     -0.402344     -0.863801  -0.412844        -0.407920
# 9339     -0.271183     -0.332031     -0.389436  -0.341896        -0.337178
# 9340     -0.330443     -0.195312     -0.565510  -0.204893        -0.200308
# 9341     -0.500632     -0.139062     -0.846194  -0.151070        -0.145713
# 9342     -0.558085     -0.232031     -0.866908  -0.244037        -0.238754
# 9343     -0.395122     -0.139062     -0.694977  -0.151070        -0.145713
# 9344     -0.268293     -0.171094     -0.491973  -0.181651        -0.175702
#
#       rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)  Time of Day  \
# 9338     -0.162511 -0.819259      -0.853617 -0.174215         -1.0
# 9339     -0.467809 -0.534815      -0.445106 -0.902640          1.0
# 9340     -0.446826 -0.869630      -0.836596  0.181439          1.0
# 9341     -0.308970 -0.440000      -0.515745 -0.873743         -1.0
# 9342     -0.251897 -0.774815      -0.768511 -0.751542         -1.0
# 9343     -0.389753 -0.751111      -0.748085 -0.259794          1.0
# 9344     -0.492149 -0.835556      -0.777021 -0.726368          1.0
#
#       Time of Year
# 9338     -0.333333
# 9339     -0.333333
# 9340     -0.333333
# 9341     -0.333333
# 9342     -0.333333
# 9343     -0.333333
# 9344     -0.333333

# %% [markdown]
# Every variable is now on a scale from -1 to 1, which will make it much easier for our model to learn. Let us now subset the variables that we want. We will keep the model simple and just take the absolute minimum number of variables possible. That is, we will take only the targets and the two custom variables,  and use their previous timepoints to predict themselves. First, let's subset them:

# %%
# In comments are all the options tried, the reader may ignore these

# df = df_scaled[['Date Time', 'p (mbar)','T (degC)', 'rh (%)', 'wv (m/s)', 'Time of Day', 'Time of Year','Tpot (K)', 'Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)','max. wv (m/s)']] # Create a new dataframe that subsets the scaled dataframe
# df = df_scaled[['Date Time', 'p (mbar)','T (degC)', 'rh (%)', 'wv (m/s)', 'Time of Day', 'Time of Year','Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)','max. wv (m/s)']] # Create a new dataframe that subsets the scaled dataframe
# df_scaled = df_scaled[['Date Time', 'p (mbar)','T (degC)', 'rh (%)', 'wv (m/s)', 'Time of Day', 'Time of Year', 'VPact (mbar)', 'VPdef (mbar)','max. wv (m/s)']]
# df_scaled = df_scaled[['Date Time', 'p (mbar)','T (degC)', 'rh (%)', 'wv (m/s)', 'Time of Day', 'Time of Year', 'VPdef (mbar)','max. wv (m/s)']]
# df_scaled = df_scaled[['Date Time', 'p (mbar)','T (degC)', 'rh (%)', 'wv (m/s)', 'Time of Day', 'Time of Year', 'max. wv (m/s)']]

df_scaled = df_scaled[['Date Time', 'p (mbar)','T (degC)', 'rh (%)', 'wv (m/s)', 'Time of Day', 'Time of Year']]

df_scaled.tail() # We take a look
# Out:
#                Date Time  p (mbar)  T (degC)    rh (%)  wv (m/s)  Time of Day  \
# 9340 2015-05-23 18:00:00  0.343755  0.373338 -0.080156 -0.869630          1.0
# 9341 2015-05-24 00:00:00  0.400438  0.223933  0.496665 -0.440000         -1.0
# 9342 2015-05-24 06:00:00  0.408327  0.163751  0.511765 -0.774815         -1.0
# 9343 2015-05-24 12:00:00  0.400438  0.320854  0.165723 -0.751111          1.0
# 9344 2015-05-24 18:00:00  0.321841  0.420224 -0.160438 -0.835556          1.0
#
#       Time of Year
# 9340     -0.333333
# 9341     -0.333333
# 9342     -0.333333
# 9343     -0.333333
# 9344     -0.333333

# %% [markdown]
# From inspection the plots of the four targets, we see that there are some anomalies present in the data occurring when the year 2015 begins. Thus, we will trim off the samples corresponding to the year 2015, as we do not want to contaminate our validation set.

# %%
df_scaled = df_scaled[df_scaled['Date Time'].dt.year != 2015] # Remove all rows whose year is 2015
df_scaled.reset_index(drop=True, inplace=True) # Reset the index of the resulting dataframe

# %%
df_scaled.tail() # We take a look
# Out:
#                Date Time  p (mbar)  T (degC)    rh (%)  wv (m/s)  Time of Day  \
# 8764 2014-12-30 18:00:00  0.709861 -0.176697  0.856550 -0.568889          1.0
# 8765 2014-12-31 00:00:00  0.741709 -0.172148  0.748333 -0.685926         -1.0
# 8766 2014-12-31 06:00:00  0.737911 -0.189293  0.781049 -0.960000         -1.0
# 8767 2014-12-31 12:00:00  0.756026 -0.122113  0.710583 -0.875556          1.0
# 8768 2014-12-31 18:00:00  0.774142 -0.140308  0.949667 -0.885926          1.0
#
#       Time of Year
# 8764           1.0
# 8765           1.0
# 8766           1.0
# 8767           1.0
# 8768           1.0

# %% [markdown]
# The trimming worked, so we are now ready to create columns containing the prior timepoints:

# %%
from copy import deepcopy as dc

def prepare_dataframe_for_lstm(df, n_steps):
    # We first make a deep copy of the original dataframe to avoid any unintentional changes to the original DataFrame
    df = dc(df_scaled)
    
    # Now we set the DateTime column as the index
    df.set_index('Date Time', inplace=True)
    
    # We add columns for past values of pressure, temperature, relative humidity, and wind speed
    for i in range(1, n_steps+1):
        df[f'p (mbar)(t-{i})'] = df['p (mbar)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'T (degC)(t-{i})'] = df['T (degC)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'rh (%)(t-{i})'] = df['rh (%)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'wv (m/s)(t-{i})'] = df['wv (m/s)'].shift(i)

    for i in range(1, n_steps+1):
        df[f'Time of Day(t-{i})'] = df['Time of Day'].shift(i)
        
    for i in range(1, n_steps+1):
        df[f'Time of Year(t-{i})'] = df['Time of Year'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'Tpot (K)(t-{i})'] = df['Tpot (K)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'Tdew (degC)(t-{i})'] = df['Tdew (degC)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'VPact (mbar)(t-{i})'] = df['VPact (mbar)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'VPdef (mbar)(t-{i})'] = df['VPdef (mbar)'].shift(i)

#     for i in range(1, n_steps+1):
#         df[f'max. wv (m/s)(t-{i})'] = df['max. wv (m/s)'].shift(i)

    # It is also important to drop rows with any missing values
    df.dropna(inplace=True)
    
    # Return the shifted dataframe
    return df

# Define the lookback window size, which is equivalent to 'k' steps in our case
lookback = 4

# Prepare the dataframe for the LSTM model
shifted_df = prepare_dataframe_for_lstm(df, lookback)

# Return the shifted dataframe
shifted_df
# Out:
#                      p (mbar)  T (degC)    rh (%)  wv (m/s)  Time of Day  \
# Date Time
# 2009-02-01 06:00:00  0.548868 -0.380686  0.904366 -0.880000         -1.0
# 2009-02-01 12:00:00  0.575457 -0.334850  0.750849 -0.771852          1.0
# 2009-02-01 18:00:00  0.628926 -0.333100  0.806216 -0.560000          1.0
# 2009-03-01 00:00:00  0.675091 -0.390483  0.748333 -0.789630         -1.0
# 2009-03-01 06:00:00  0.644996 -0.512596  0.836416 -0.930370         -1.0
# ...                       ...       ...       ...       ...          ...
# 2014-12-30 18:00:00  0.709861 -0.176697  0.856550 -0.568889          1.0
# 2014-12-31 00:00:00  0.741709 -0.172148  0.748333 -0.685926         -1.0
# 2014-12-31 06:00:00  0.737911 -0.189293  0.781049 -0.960000         -1.0
# 2014-12-31 12:00:00  0.756026 -0.122113  0.710583 -0.875556          1.0
# 2014-12-31 18:00:00  0.774142 -0.140308  0.949667 -0.885926          1.0
#
#                      Time of Year  p (mbar)(t-1)  p (mbar)(t-2)  \
# Date Time
# 2009-02-01 06:00:00          -1.0       0.595325       0.611980
# 2009-02-01 12:00:00          -1.0       0.548868       0.595325
# 2009-02-01 18:00:00          -1.0       0.575457       0.548868
# 2009-03-01 00:00:00          -1.0       0.628926       0.575457
# 2009-03-01 06:00:00          -1.0       0.675091       0.628926
# ...                           ...            ...            ...
# 2014-12-30 18:00:00           1.0       0.710738       0.733820
# 2014-12-31 00:00:00           1.0       0.709861       0.710738
# 2014-12-31 06:00:00           1.0       0.741709       0.709861
# 2014-12-31 12:00:00           1.0       0.737911       0.741709
# 2014-12-31 18:00:00           1.0       0.756026       0.737911
#
#                      p (mbar)(t-3)  p (mbar)(t-4)  ...  wv (m/s)(t-3)  \
# Date Time                                          ...
# 2009-02-01 06:00:00       0.616070       0.540394  ...      -0.727407
# 2009-02-01 12:00:00       0.611980       0.616070  ...      -0.918519
# 2009-02-01 18:00:00       0.595325       0.611980  ...      -0.939259
# 2009-03-01 00:00:00       0.548868       0.595325  ...      -0.880000
# 2009-03-01 06:00:00       0.575457       0.548868  ...      -0.771852
# ...                            ...            ...  ...            ...
# 2014-12-30 18:00:00       0.820015       0.755150  ...      -0.890370
# 2014-12-31 00:00:00       0.733820       0.820015  ...      -0.727407
# 2014-12-31 06:00:00       0.710738       0.733820  ...      -0.817778
# 2014-12-31 12:00:00       0.709861       0.710738  ...      -0.568889
# 2014-12-31 18:00:00       0.741709       0.709861  ...      -0.685926
#
#                      wv (m/s)(t-4)  Time of Day(t-1)  Time of Day(t-2)  \
# Date Time
# 2009-02-01 06:00:00      -0.992593              -1.0               1.0
# 2009-02-01 12:00:00      -0.727407              -1.0              -1.0
# 2009-02-01 18:00:00      -0.918519               1.0              -1.0
# 2009-03-01 00:00:00      -0.939259               1.0               1.0
# 2009-03-01 06:00:00      -0.880000              -1.0               1.0
# ...                            ...               ...               ...
# 2014-12-30 18:00:00      -0.619259               1.0              -1.0
# 2014-12-31 00:00:00      -0.890370               1.0               1.0
# 2014-12-31 06:00:00      -0.727407              -1.0               1.0
# 2014-12-31 12:00:00      -0.817778              -1.0              -1.0
# 2014-12-31 18:00:00      -0.568889               1.0              -1.0
#
#                      Time of Day(t-3)  Time of Day(t-4)  Time of Year(t-1)  \
# Date Time
# 2009-02-01 06:00:00               1.0              -1.0               -1.0
# 2009-02-01 12:00:00               1.0               1.0               -1.0
# 2009-02-01 18:00:00              -1.0               1.0               -1.0
# 2009-03-01 00:00:00              -1.0              -1.0               -1.0
# 2009-03-01 06:00:00               1.0              -1.0               -1.0
# ...                               ...               ...                ...
# 2014-12-30 18:00:00              -1.0               1.0                1.0
# 2014-12-31 00:00:00              -1.0              -1.0                1.0
# 2014-12-31 06:00:00               1.0              -1.0                1.0
# 2014-12-31 12:00:00               1.0               1.0                1.0
# 2014-12-31 18:00:00              -1.0               1.0                1.0
#
#                      Time of Year(t-2)  Time of Year(t-3)  Time of Year(t-4)
# Date Time
# 2009-02-01 06:00:00               -1.0               -1.0               -1.0
# 2009-02-01 12:00:00               -1.0               -1.0               -1.0
# 2009-02-01 18:00:00               -1.0               -1.0               -1.0
# 2009-03-01 00:00:00               -1.0               -1.0               -1.0
# 2009-03-01 06:00:00               -1.0               -1.0               -1.0
# ...                                ...                ...                ...
# 2014-12-30 18:00:00                1.0                1.0                1.0
# 2014-12-31 00:00:00                1.0                1.0                1.0
# 2014-12-31 06:00:00                1.0                1.0                1.0
# 2014-12-31 12:00:00                1.0                1.0                1.0
# 2014-12-31 18:00:00                1.0                1.0                1.0
#
# [8765 rows x 30 columns]

# %% [markdown]
# That worked, but the problem is that columns are ordered from $t-1$ to $t-k$, which is the opposite direction we want. We want to feed the furthest timepoints first and end with the most recent timepoint. Moreover, as it stands, columns are ordered by feature, not by timepoint, so we need to fix these two things:

# %%
# Define a list of timepoints to group by
timepoints = [f't-{i}' for i in range(lookback, 0, -1)]

# In comments below are all the options tried. The reader may ignore these

# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year','Tpot (K)', 'Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)

# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year','Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)
    
# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)
    
# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year', 'VPdef (mbar)', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)  
    
# # Group the shifted columns by timepoint
# all_shifted_cols = []
# for timepoint in timepoints:
#     columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year', 'max. wv (m/s)']]
#     all_shifted_cols.extend(columns)



# Group the shifted columns by timepoint
all_shifted_cols = []
for timepoint in timepoints:
    columns = [f'{col}({timepoint})' for col in ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)','Time of Day', 'Time of Year']]
    all_shifted_cols.extend(columns)

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year','Tpot (K)', 'Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year','Tdew (degC)', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year', 'VPact (mbar)', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year', 'VPdef (mbar)', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols

# # Concatenate the target columns and the grouped columns
# target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
# feature_cols = ['Time of Day', 'Time of Year', 'max. wv (m/s)']
# all_cols = target_cols + feature_cols + all_shifted_cols


# Concatenate the target columns and the grouped columns
target_cols = ['p (mbar)', 'T (degC)', 'rh (%)', 'wv (m/s)']
feature_cols = ['Time of Day', 'Time of Year']
all_cols = target_cols + feature_cols + all_shifted_cols

# %%
# Let us take a look at the final variable 'all_cols'
all_cols
# Out:
# ['p (mbar)',
#  'T (degC)',
#  'rh (%)',
#  'wv (m/s)',
#  'Time of Day',
#  'Time of Year',
#  'p (mbar)(t-4)',
#  'T (degC)(t-4)',
#  'rh (%)(t-4)',
#  'wv (m/s)(t-4)',
#  'Time of Day(t-4)',
#  'Time of Year(t-4)',
#  'p (mbar)(t-3)',
#  'T (degC)(t-3)',
#  'rh (%)(t-3)',
#  'wv (m/s)(t-3)',
#  'Time of Day(t-3)',
#  'Time of Year(t-3)',
#  'p (mbar)(t-2)',
#  'T (degC)(t-2)',
#  'rh (%)(t-2)',
#  'wv (m/s)(t-2)',
#  'Time of Day(t-2)',
#  'Time of Year(t-2)',
#  'p (mbar)(t-1)',
#  'T (degC)(t-1)',
#  'rh (%)(t-1)',
#  'wv (m/s)(t-1)',
#  'Time of Day(t-1)',
#  'Time of Year(t-1)']

# %% [markdown]
# Feature columns are now grouped by tiempoint and the direction of time has been flipped. Good progress, but now we must delete the custom features at timepoint $t$, as we are not allowed to use current timepoints.

# %%
# First we udpate the df
shifted_df = shifted_df[all_cols]

# %%
#shifted_df = shifted_df.drop(shifted_df.columns[4:11], axis=1)
# shifted_df = shifted_df.drop(shifted_df.columns[4:10], axis=1)
#shifted_df = shifted_df.drop(shifted_df.columns[4:9], axis=1)
# shifted_df = shifted_df.drop(shifted_df.columns[4:8], axis=1)
# shifted_df = shifted_df.drop(shifted_df.columns[4:7], axis=1)

shifted_df = shifted_df.drop(shifted_df.columns[4:6], axis=1) # We delete the custom features at timpoint t

# %%
shifted_df
# Out:
#                      p (mbar)  T (degC)    rh (%)  wv (m/s)  p (mbar)(t-4)  \
# Date Time
# 2009-02-01 06:00:00  0.548868 -0.380686  0.904366 -0.880000       0.540394
# 2009-02-01 12:00:00  0.575457 -0.334850  0.750849 -0.771852       0.616070
# 2009-02-01 18:00:00  0.628926 -0.333100  0.806216 -0.560000       0.611980
# 2009-03-01 00:00:00  0.675091 -0.390483  0.748333 -0.789630       0.595325
# 2009-03-01 06:00:00  0.644996 -0.512596  0.836416 -0.930370       0.548868
# ...                       ...       ...       ...       ...            ...
# 2014-12-30 18:00:00  0.709861 -0.176697  0.856550 -0.568889       0.755150
# 2014-12-31 00:00:00  0.741709 -0.172148  0.748333 -0.685926       0.820015
# 2014-12-31 06:00:00  0.737911 -0.189293  0.781049 -0.960000       0.733820
# 2014-12-31 12:00:00  0.756026 -0.122113  0.710583 -0.875556       0.710738
# 2014-12-31 18:00:00  0.774142 -0.140308  0.949667 -0.885926       0.709861
#
#                      T (degC)(t-4)  rh (%)(t-4)  wv (m/s)(t-4)  \
# Date Time
# 2009-02-01 06:00:00      -0.564031     0.816283      -0.992593
# 2009-02-01 12:00:00      -0.466060     0.738266      -0.727407
# 2009-02-01 18:00:00      -0.409377     0.725683      -0.918519
# 2009-03-01 00:00:00      -0.384535     0.828866      -0.939259
# 2009-03-01 06:00:00      -0.380686     0.904366      -0.880000
# ...                            ...          ...            ...
# 2014-12-30 18:00:00      -0.339048     0.675349      -0.619259
# 2014-12-31 00:00:00      -0.403079     0.735749      -0.890370
# 2014-12-31 06:00:00      -0.363891     0.881716      -0.727407
# 2014-12-31 12:00:00      -0.305808     0.891783      -0.817778
# 2014-12-31 18:00:00      -0.176697     0.856550      -0.568889
#
#                      Time of Day(t-4)  Time of Year(t-4)  ...  rh (%)(t-2)  \
# Date Time                                                 ...
# 2009-02-01 06:00:00              -1.0               -1.0  ...     0.725683
# 2009-02-01 12:00:00               1.0               -1.0  ...     0.828866
# 2009-02-01 18:00:00               1.0               -1.0  ...     0.904366
# 2009-03-01 00:00:00              -1.0               -1.0  ...     0.750849
# 2009-03-01 06:00:00              -1.0               -1.0  ...     0.806216
# ...                               ...                ...  ...          ...
# 2014-12-30 18:00:00               1.0                1.0  ...     0.881716
# 2014-12-31 00:00:00              -1.0                1.0  ...     0.891783
# 2014-12-31 06:00:00              -1.0                1.0  ...     0.856550
# 2014-12-31 12:00:00               1.0                1.0  ...     0.748333
# 2014-12-31 18:00:00               1.0                1.0  ...     0.781049
#
#                      wv (m/s)(t-2)  Time of Day(t-2)  Time of Year(t-2)  \
# Date Time
# 2009-02-01 06:00:00      -0.918519               1.0               -1.0
# 2009-02-01 12:00:00      -0.939259              -1.0               -1.0
# 2009-02-01 18:00:00      -0.880000              -1.0               -1.0
# 2009-03-01 00:00:00      -0.771852               1.0               -1.0
# 2009-03-01 06:00:00      -0.560000               1.0               -1.0
# ...                            ...               ...                ...
# 2014-12-30 18:00:00      -0.727407              -1.0                1.0
# 2014-12-31 00:00:00      -0.817778               1.0                1.0
# 2014-12-31 06:00:00      -0.568889               1.0                1.0
# 2014-12-31 12:00:00      -0.685926              -1.0                1.0
# 2014-12-31 18:00:00      -0.960000              -1.0                1.0
#
#                      p (mbar)(t-1)  T (degC)(t-1)  rh (%)(t-1)  wv (m/s)(t-1)  \
# Date Time
# 2009-02-01 06:00:00       0.595325      -0.384535     0.828866      -0.939259
# 2009-02-01 12:00:00       0.548868      -0.380686     0.904366      -0.880000
# 2009-02-01 18:00:00       0.575457      -0.334850     0.750849      -0.771852
# 2009-03-01 00:00:00       0.628926      -0.333100     0.806216      -0.560000
# 2009-03-01 06:00:00       0.675091      -0.390483     0.748333      -0.789630
# ...                            ...            ...          ...            ...
# 2014-12-30 18:00:00       0.710738      -0.305808     0.891783      -0.817778
# 2014-12-31 00:00:00       0.709861      -0.176697     0.856550      -0.568889
# 2014-12-31 06:00:00       0.741709      -0.172148     0.748333      -0.685926
# 2014-12-31 12:00:00       0.737911      -0.189293     0.781049      -0.960000
# 2014-12-31 18:00:00       0.756026      -0.122113     0.710583      -0.875556
#
#                      Time of Day(t-1)  Time of Year(t-1)
# Date Time
# 2009-02-01 06:00:00              -1.0               -1.0
# 2009-02-01 12:00:00              -1.0               -1.0
# 2009-02-01 18:00:00               1.0               -1.0
# 2009-03-01 00:00:00               1.0               -1.0
# 2009-03-01 06:00:00              -1.0               -1.0
# ...                               ...                ...
# 2014-12-30 18:00:00               1.0                1.0
# 2014-12-31 00:00:00               1.0                1.0
# 2014-12-31 06:00:00              -1.0                1.0
# 2014-12-31 12:00:00              -1.0                1.0
# 2014-12-31 18:00:00               1.0                1.0
#
# [8765 rows x 28 columns]

# %% [markdown]
# That looks good. The first four columns contain our targets at timepoint $t$. Then, the other columns contain the $t-k$ ... $t-1$ values for each target variable. We're not done yet, though. Now we can turn this data into a Numpy array:

# %%
# We convert to numpy and print
shifted_df_as_np = shifted_df.to_numpy()
print(shifted_df_as_np)
# Out:
# [[ 0.54886779 -0.38068579  0.90436643 ... -0.93925926 -1.
#   -1.        ]
#  [ 0.57545654 -0.33484955  0.75084938 ... -0.88       -1.
#   -1.        ]
#  [ 0.62892622 -0.33310007  0.80621618 ... -0.77185185  1.
#   -1.        ]
#  ...
#  [ 0.73791088 -0.18929321  0.78104945 ... -0.68592593 -1.
#    1.        ]
#  [ 0.7560263  -0.12211337  0.71058261 ... -0.96       -1.
#    1.        ]
#  [ 0.77414171 -0.14030791  0.94966654 ... -0.87555556  1.
#    1.        ]]

# %%
# Let's take a look at the shape
shifted_df_as_np.shape
# Out:
# (8765, 28)

# %% [markdown]
# We have quite a few rows and 28 columns. That is, 4 targets in the first 4 columns plus $4*k$ columns which equals 24 in this case because we set $k$ to be equal to 6. Now we need to divide this into our `X` and `y` variables. For `X` we will take all columns but the first 4 and for `y` we will take just the first 4:

# %%
# We define X and y as mentioned
X = shifted_df_as_np[:, 4:]
y = shifted_df_as_np[:, :4]
# Print the shapes to inspect them
X.shape, y.shape
# Out:
# ((8765, 24), (8765, 4))

# %%
# Now we will split into train and val objects
split_index = int(len(X) * 0.9) # We define and index
print(split_index)
# Out:
# 7888

# %%
# Here we will use the index to split our Xs and ys:
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape) # Let us inspect the shapes of the splits
# Out:
# (7888, 24) (877, 24) (7888, 4) (877, 4)

# %% [markdown]
# The dimension match perfectly for Xs and their respective ys. Now we can reshape the data in the following way:

# %%
# We essentially want number_of_samples, lookback_size(k), and number of features for the Xs
X_train = X_train.reshape(-1, 4, 6)
X_test = X_test.reshape(-1, 4, 6)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (7888, 4, 6) (877, 4, 6)
# (7888, 4) (877, 4)

# %%
# Pytorch only deals with tensors, so we need to convert these last np arrays into torch floats:
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape) # Inspect the shape once again
# Out:
# torch.Size([7888, 4, 6]) torch.Size([877, 4, 6]) torch.Size([7888, 4]) torch.Size([877, 4])

# %% [markdown]
# Everything looks good now. The next steps are easy since we've already done a lot of pre-processing legwork. Essentially, we just need to pass our Xs and ys into a Dataset class and then wrap the Dataset class into a DataLoader object that will batch our data nicely:

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset): # Nothing fancy here, just making sure we can access length and individual items
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]
    
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
from torch.utils.data import DataLoader

batch_size =  32 # We will try batch_size values of 64 and 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) 
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([32, 4, 6]) torch.Size([32, 4])

# %% [markdown]
# Great, the first dimension of both X and y now correspond to batch length, not number of n_rows * n_columns. This means that the batching has worked well. Let's verify the same for the validation dataloader (here defined as test_loader):

# %%
# One last sanity check. Let us make sure we can retrieve batches and that they have the right size: 
for _, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([32, 4, 6]) torch.Size([32, 4])

# %% [markdown]
# All good. At long last, we can now define our model class. This next part is a bit finicky in standard PyTorch, compared to Lightning or even TensorFlow, as we need to initialize the hidden state `h0` cell state `c0`. That said, since our model is not too complex, we can live with it:

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        
        # Store the input parameters as instance variables
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        # Initialize an LSTM layer with the given input size, hidden size, and number of stacked layers. Set batch_first to True.
        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers, 
                            batch_first=True)
               
        # Initialize a linear layer to map the hidden state output from the LSTM to a scalar output. The output of this linear layer will be the 4 predicted values.
        self.fc1 = nn.Linear(hidden_size, 4)
    
    def forward(self, x):
        h_n = torch.zeros(self.num_stacked_layers, x.size(0), self.hidden_size)
        c_n = torch.zeros(self.num_stacked_layers, x.size(0), self.hidden_size)
        # Pass the input through the LSTM layer
        output, (h_n, c_n) = self.lstm(x)

        # Pass the LSTM output through the linear layer
        output = (self.fc1(output[:, -1, :]))
        
        return output

# Instantiate a new LSTM model with input size 4, hidden size 4, and 3 stacked LSTM layers (really these should be called LSTM cells, but I don't get to name things).
model = LSTM(6, 4, 3)

# Move the model to the device specified by the 'device' variable
model.to(device)

# Print the model
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(6, 4, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# Next we will define a standard training loop as a function called `train_and_validate` which will take number of epochs as input:

# %%
def train_and_validate(num_epochs):
    
    ##############
    # TRAINING LOOP #
    #############
      
    # We initialize lists to store training and validation losses and R2s for each epoch   
    model.train(True)
    
    for epoch in range(num_epochs):
        print(f'Epoch: {epoch + 1}')
        
        # Train the model for one epoch
        running_loss = 0.0  
        running_total = 0.0 
        running_correct = 0.0 
        
        for batch_index, batch in enumerate(train_loader):
            x_batch, y_batch = batch[0].to(device), batch[1].to(device)

            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item() 
            running_total += y_batch.size(0) 

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            y_pred = output.detach().cpu().numpy()
            y_true = y_batch.detach().cpu().numpy()
            r2 = r2_score(y_true, y_pred)
            running_correct += r2*y_batch.size(0)

            if batch_index % 1000 == 99:  
                avg_loss_across_batches = running_loss / 100
                avg_r2_across_batches = running_correct / running_total
                print('Batch {0}, MAE Loss: {1:.3f}, R2: {2:.3f}'.format(batch_index+1,
                                                                    avg_loss_across_batches,
                                                                    avg_r2_across_batches))
                running_loss = 0.0 
                running_correct = 0.0 
                running_total = 0.0 

        epoch_loss = running_loss / len(train_loader) 
        epoch_r2 = running_correct / running_total
        
        train_losses.append(epoch_loss)
        train_r2s.append(epoch_r2)
        
        print('Epoch Train MAE Loss: {0:.3f}, Epoch Train R2: {1:.3f}'.format(epoch_loss, epoch_r2))  
        print()
        
        ###############
        # VALIDATION LOOP #
        ###############
        
        # Validate the model for one epoch
        model.train(False)

        running_loss = 0.0 
        running_total = 0.0 
        running_correct = 0.0 
        
        for batch_index, batch in enumerate(test_loader):
            x_batch, y_batch = batch[0].to(device), batch[1].to(device)

            with torch.no_grad():
                output = model(x_batch)
                loss = loss_function(output, y_batch)
                running_loss += loss.item()
                running_total += y_batch.size(0)

                y_pred = output.detach().cpu().numpy()
                y_true = y_batch.detach().cpu().numpy()
                r2 = r2_score(y_true, y_pred)
                running_correct += r2*y_batch.size(0)

        avg_loss_across_batches = running_loss / len(test_loader)
        avg_r2_across_batches = running_correct / running_total
        
        val_losses.append(avg_loss_across_batches)
        val_r2s.append(avg_r2_across_batches)
               
        print('Val MAE Loss: {0:.3f}'.format(avg_loss_across_batches))
        print('Val R2 Score: {0:.3f}'.format(avg_r2_across_batches))
        print('***************************************************')
        print()
        
        model.train(True)

# %%
### We're ready to train ! ###
learning_rate = 0.01
loss_function = nn.L1Loss() 
num_epochs = 1000
weight_decay = 1e-5
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

train_losses = []
val_losses = []
train_r2s = []
val_r2s = []

train_and_validate(num_epochs = num_epochs)
# Out:
# Epoch: 1
# Batch 100, MAE Loss: 0.229, R2: -0.052
# Epoch Train MAE Loss: 0.099, Epoch Train R2: 0.425
#
# Val MAE Loss: 0.153
# Val R2 Score: 0.415
# ***************************************************
#
# Epoch: 2
# Batch 100, MAE Loss: 0.147, R2: 0.505
# Epoch Train MAE Loss: 0.080, Epoch Train R2: 0.552
#
# Val MAE Loss: 0.132
# Val R2 Score: 0.524
# ***************************************************
#
# Epoch: 3
# Batch 100, MAE Loss: 0.123, R2: 0.602
# Epoch Train MAE Loss: 0.071, Epoch Train R2: 0.621
#
# Val MAE Loss: 0.107
# Val R2 Score: 0.631
# ***************************************************
#
# Epoch: 4
# Batch 100, MAE Loss: 0.115, R2: 0.635
# Epoch Train MAE Loss: 0.068, Epoch Train R2: 0.647
#
# Val MAE Loss: 0.103
# Val R2 Score: 0.606
# ***************************************************
#
# Epoch: 5
# Batch 100, MAE Loss: 0.115, R2: 0.640
# Epoch Train MAE Loss: 0.067, Epoch Train R2: 0.652
#
# Val MAE Loss: 0.103
# Val R2 Score: 0.653
# ***************************************************
#
# Epoch: 6
# Batch 100, MAE Loss: 0.112, R2: 0.652
# Epoch Train MAE Loss: 0.066, Epoch Train R2: 0.651
#
# Val MAE Loss: 0.102
# Val R2 Score: 0.654
# ***************************************************
#
# Epoch: 7
# Batch 100, MAE Loss: 0.112, R2: 0.644
# Epoch Train MAE Loss: 0.066, Epoch Train R2: 0.651
#
# Val MAE Loss: 0.101
# Val R2 Score: 0.655
# ***************************************************
#
# Epoch: 8
# Batch 100, MAE Loss: 0.112, R2: 0.654
# Epoch Train MAE Loss: 0.065, Epoch Train R2: 0.657
#
# Val MAE Loss: 0.104
# Val R2 Score: 0.646
# ***************************************************
#
# Epoch: 9
# Batch 100, MAE Loss: 0.108, R2: 0.656
# Epoch Train MAE Loss: 0.066, Epoch Train R2: 0.648
#
# Val MAE Loss: 0.103
# Val R2 Score: 0.644
# ***************************************************
#
# Epoch: 10
# Batch 100, MAE Loss: 0.107, R2: 0.667
# Epoch Train MAE Loss: 0.065, Epoch Train R2: 0.654
#
# Val MAE Loss: 0.102
# Val R2 Score: 0.656
# ***************************************************
#
# Epoch: 11
# Batch 100, MAE Loss: 0.110, R2: 0.653
# Epoch Train MAE Loss: 0.065, Epoch Train R2: 0.657
#
# Val MAE Loss: 0.108
# Val R2 Score: 0.640
# ***************************************************
#
# Epoch: 12
# Batch 100, MAE Loss: 0.107, R2: 0.660
# Epoch Train MAE Loss: 0.065, Epoch Train R2: 0.658
#
# Val MAE Loss: 0.102
# Val R2 Score: 0.646
# ***************************************************
#
# Epoch: 13
# Batch 100, MAE Loss: 0.111, R2: 0.655
# Epoch Train MAE Loss: 0.064, Epoch Train R2: 0.658
#
# Val MAE Loss: 0.102
# Val R2 Score: 0.653
# ***************************************************
#
# Epoch: 14
# Batch 100, MAE Loss: 0.109, R2: 0.653
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.668
#
# Val MAE Loss: 0.101
# Val R2 Score: 0.628
# ***************************************************
#
# Epoch: 15
# Batch 100, MAE Loss: 0.108, R2: 0.658
# Epoch Train MAE Loss: 0.064, Epoch Train R2: 0.660
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.657
# ***************************************************
#
# Epoch: 16
# Batch 100, MAE Loss: 0.108, R2: 0.662
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.665
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.647
# ***************************************************
#
# Epoch: 17
# Batch 100, MAE Loss: 0.108, R2: 0.657
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.666
#
# Val MAE Loss: 0.104
# Val R2 Score: 0.648
# ***************************************************
#
# Epoch: 18
# Batch 100, MAE Loss: 0.108, R2: 0.662
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.664
#
# Val MAE Loss: 0.101
# Val R2 Score: 0.657
# ***************************************************
#
# Epoch: 19
# Batch 100, MAE Loss: 0.108, R2: 0.661
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.669
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.652
# ***************************************************
#
# Epoch: 20
# Batch 100, MAE Loss: 0.105, R2: 0.669
# Epoch Train MAE Loss: 0.064, Epoch Train R2: 0.661
#
# Val MAE Loss: 0.101
# Val R2 Score: 0.655
# ***************************************************
#
# Epoch: 21
# Batch 100, MAE Loss: 0.105, R2: 0.671
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.665
#
# Val MAE Loss: 0.102
# Val R2 Score: 0.639
# ***************************************************
#
# Epoch: 22
# Batch 100, MAE Loss: 0.106, R2: 0.663
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.669
#
# Val MAE Loss: 0.102
# Val R2 Score: 0.660
# ***************************************************
#
# Epoch: 23
# Batch 100, MAE Loss: 0.105, R2: 0.666
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.669
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.663
# ***************************************************
#
# Epoch: 24
# Batch 100, MAE Loss: 0.106, R2: 0.663
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.672
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.659
# ***************************************************
#
# Epoch: 25
# Batch 100, MAE Loss: 0.106, R2: 0.668
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.660
#
# Val MAE Loss: 0.104
# Val R2 Score: 0.647
# ***************************************************
#
# Epoch: 26
# Batch 100, MAE Loss: 0.105, R2: 0.675
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.663
#
# Val MAE Loss: 0.102
# Val R2 Score: 0.660
# ***************************************************
#
# Epoch: 27
# Batch 100, MAE Loss: 0.107, R2: 0.664
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.671
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.638
# ***************************************************
#
# Epoch: 28
# Batch 100, MAE Loss: 0.105, R2: 0.668
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.668
#
# Val MAE Loss: 0.104
# Val R2 Score: 0.651
# ***************************************************
#
# Epoch: 29
# Batch 100, MAE Loss: 0.108, R2: 0.661
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.669
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.649
# ***************************************************
#
# Epoch: 30
# Batch 100, MAE Loss: 0.104, R2: 0.671
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.671
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.653
# ***************************************************
#
# Epoch: 31
# Batch 100, MAE Loss: 0.105, R2: 0.667
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.671
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.649
# ***************************************************
#
# Epoch: 32
# Batch 100, MAE Loss: 0.105, R2: 0.669
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.669
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.663
# ***************************************************
#
# Epoch: 33
# Batch 100, MAE Loss: 0.105, R2: 0.668
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.673
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.647
# ***************************************************
#
# Epoch: 34
# Batch 100, MAE Loss: 0.105, R2: 0.672
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.665
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.667
# ***************************************************
#
# Epoch: 35
# Batch 100, MAE Loss: 0.103, R2: 0.680
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.669
#
# Val MAE Loss: 0.103
# Val R2 Score: 0.651
# ***************************************************
#
# Epoch: 36
# Batch 100, MAE Loss: 0.104, R2: 0.675
# Epoch Train MAE Loss: 0.063, Epoch Train R2: 0.667
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.638
# ***************************************************
#
# Epoch: 37
# Batch 100, MAE Loss: 0.106, R2: 0.669
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.670
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.658
# ***************************************************
#
# Epoch: 38
# Batch 100, MAE Loss: 0.104, R2: 0.679
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.672
#
# Val MAE Loss: 0.106
# Val R2 Score: 0.643
# ***************************************************
#
# Epoch: 39
# Batch 100, MAE Loss: 0.105, R2: 0.668
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.677
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.667
# ***************************************************
#
# Epoch: 40
# Batch 100, MAE Loss: 0.105, R2: 0.671
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.675
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.650
# ***************************************************
#
# Epoch: 41
# Batch 100, MAE Loss: 0.104, R2: 0.669
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.675
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.669
# ***************************************************
#
# Epoch: 42
# Batch 100, MAE Loss: 0.104, R2: 0.676
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.674
#
# Val MAE Loss: 0.105
# Val R2 Score: 0.645
# ***************************************************
#
# Epoch: 43
# Batch 100, MAE Loss: 0.105, R2: 0.670
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.675
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.661
# ***************************************************
#
# Epoch: 44
# Batch 100, MAE Loss: 0.103, R2: 0.668
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.675
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.655
# ***************************************************
#
# Epoch: 45
# Batch 100, MAE Loss: 0.104, R2: 0.676
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.677
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.666
# ***************************************************
#
# Epoch: 46
# Batch 100, MAE Loss: 0.104, R2: 0.678
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.675
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.669
# ***************************************************
#
# Epoch: 47
# Batch 100, MAE Loss: 0.102, R2: 0.673
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.672
#
# Val MAE Loss: 0.101
# Val R2 Score: 0.655
# ***************************************************
#
# Epoch: 48
# Batch 100, MAE Loss: 0.102, R2: 0.680
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.677
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.666
# ***************************************************
#
# Epoch: 49
# Batch 100, MAE Loss: 0.104, R2: 0.668
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.676
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 50
# Batch 100, MAE Loss: 0.103, R2: 0.679
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.672
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.657
# ***************************************************
#
# Epoch: 51
# Batch 100, MAE Loss: 0.104, R2: 0.674
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.674
#
# Val MAE Loss: 0.106
# Val R2 Score: 0.641
# ***************************************************
#
# Epoch: 52
# Batch 100, MAE Loss: 0.104, R2: 0.678
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.677
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.664
# ***************************************************
#
# Epoch: 53
# Batch 100, MAE Loss: 0.101, R2: 0.681
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.673
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.665
# ***************************************************
#
# Epoch: 54
# Batch 100, MAE Loss: 0.106, R2: 0.664
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.663
# ***************************************************
#
# Epoch: 55
# Batch 100, MAE Loss: 0.103, R2: 0.683
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.676
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.657
# ***************************************************
#
# Epoch: 56
# Batch 100, MAE Loss: 0.103, R2: 0.682
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.673
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.668
# ***************************************************
#
# Epoch: 57
# Batch 100, MAE Loss: 0.103, R2: 0.676
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 58
# Batch 100, MAE Loss: 0.102, R2: 0.676
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.678
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.674
# ***************************************************
#
# Epoch: 59
# Batch 100, MAE Loss: 0.104, R2: 0.682
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.683
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.669
# ***************************************************
#
# Epoch: 60
# Batch 100, MAE Loss: 0.100, R2: 0.691
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.671
#
# Val MAE Loss: 0.105
# Val R2 Score: 0.653
# ***************************************************
#
# Epoch: 61
# Batch 100, MAE Loss: 0.104, R2: 0.682
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.665
# ***************************************************
#
# Epoch: 62
# Batch 100, MAE Loss: 0.103, R2: 0.673
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.674
# ***************************************************
#
# Epoch: 63
# Batch 100, MAE Loss: 0.102, R2: 0.678
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 64
# Batch 100, MAE Loss: 0.102, R2: 0.675
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.665
# ***************************************************
#
# Epoch: 65
# Batch 100, MAE Loss: 0.104, R2: 0.675
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.652
# ***************************************************
#
# Epoch: 66
# Batch 100, MAE Loss: 0.103, R2: 0.683
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.673
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.676
# ***************************************************
#
# Epoch: 67
# Batch 100, MAE Loss: 0.101, R2: 0.683
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.676
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.661
# ***************************************************
#
# Epoch: 68
# Batch 100, MAE Loss: 0.103, R2: 0.675
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.683
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.673
# ***************************************************
#
# Epoch: 69
# Batch 100, MAE Loss: 0.101, R2: 0.678
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.677
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.667
# ***************************************************
#
# Epoch: 70
# Batch 100, MAE Loss: 0.102, R2: 0.685
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.675
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.667
# ***************************************************
#
# Epoch: 71
# Batch 100, MAE Loss: 0.100, R2: 0.690
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.673
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.674
# ***************************************************
#
# Epoch: 72
# Batch 100, MAE Loss: 0.101, R2: 0.683
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.677
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 73
# Batch 100, MAE Loss: 0.101, R2: 0.681
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.678
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.679
# ***************************************************
#
# Epoch: 74
# Batch 100, MAE Loss: 0.101, R2: 0.689
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.677
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 75
# Batch 100, MAE Loss: 0.101, R2: 0.678
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.679
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.673
# ***************************************************
#
# Epoch: 76
# Batch 100, MAE Loss: 0.101, R2: 0.676
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.665
# ***************************************************
#
# Epoch: 77
# Batch 100, MAE Loss: 0.102, R2: 0.675
# Epoch Train MAE Loss: 0.062, Epoch Train R2: 0.678
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.654
# ***************************************************
#
# Epoch: 78
# Batch 100, MAE Loss: 0.103, R2: 0.679
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.676
# ***************************************************
#
# Epoch: 79
# Batch 100, MAE Loss: 0.101, R2: 0.686
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.670
# ***************************************************
#
# Epoch: 80
# Batch 100, MAE Loss: 0.101, R2: 0.686
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.676
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.666
# ***************************************************
#
# Epoch: 81
# Batch 100, MAE Loss: 0.103, R2: 0.679
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 82
# Batch 100, MAE Loss: 0.100, R2: 0.687
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.671
# ***************************************************
#
# Epoch: 83
# Batch 100, MAE Loss: 0.101, R2: 0.690
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.679
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 84
# Batch 100, MAE Loss: 0.102, R2: 0.679
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 85
# Batch 100, MAE Loss: 0.102, R2: 0.680
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.683
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 86
# Batch 100, MAE Loss: 0.102, R2: 0.682
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.681
# ***************************************************
#
# Epoch: 87
# Batch 100, MAE Loss: 0.103, R2: 0.684
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 88
# Batch 100, MAE Loss: 0.102, R2: 0.683
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.681
# ***************************************************
#
# Epoch: 89
# Batch 100, MAE Loss: 0.100, R2: 0.685
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.659
# ***************************************************
#
# Epoch: 90
# Batch 100, MAE Loss: 0.102, R2: 0.680
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.678
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 91
# Batch 100, MAE Loss: 0.103, R2: 0.679
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 92
# Batch 100, MAE Loss: 0.102, R2: 0.675
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.681
# ***************************************************
#
# Epoch: 93
# Batch 100, MAE Loss: 0.101, R2: 0.682
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.682
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.664
# ***************************************************
#
# Epoch: 94
# Batch 100, MAE Loss: 0.100, R2: 0.684
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 95
# Batch 100, MAE Loss: 0.102, R2: 0.690
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.683
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.671
# ***************************************************
#
# Epoch: 96
# Batch 100, MAE Loss: 0.101, R2: 0.682
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.687
# ***************************************************
#
# Epoch: 97
# Batch 100, MAE Loss: 0.101, R2: 0.685
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 98
# Batch 100, MAE Loss: 0.102, R2: 0.683
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.679
# ***************************************************
#
# Epoch: 99
# Batch 100, MAE Loss: 0.103, R2: 0.679
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 100
# Batch 100, MAE Loss: 0.102, R2: 0.680
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 101
# Batch 100, MAE Loss: 0.101, R2: 0.681
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.673
# ***************************************************
#
# Epoch: 102
# Batch 100, MAE Loss: 0.102, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 103
# Batch 100, MAE Loss: 0.100, R2: 0.694
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.670
# ***************************************************
#
# Epoch: 104
# Batch 100, MAE Loss: 0.101, R2: 0.684
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 105
# Batch 100, MAE Loss: 0.100, R2: 0.688
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.676
# ***************************************************
#
# Epoch: 106
# Batch 100, MAE Loss: 0.100, R2: 0.694
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.679
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 107
# Batch 100, MAE Loss: 0.101, R2: 0.681
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 108
# Batch 100, MAE Loss: 0.100, R2: 0.691
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.679
# ***************************************************
#
# Epoch: 109
# Batch 100, MAE Loss: 0.102, R2: 0.680
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 110
# Batch 100, MAE Loss: 0.101, R2: 0.683
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 111
# Batch 100, MAE Loss: 0.099, R2: 0.692
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 112
# Batch 100, MAE Loss: 0.101, R2: 0.680
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.692
# ***************************************************
#
# Epoch: 113
# Batch 100, MAE Loss: 0.102, R2: 0.694
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.691
# ***************************************************
#
# Epoch: 114
# Batch 100, MAE Loss: 0.100, R2: 0.692
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 115
# Batch 100, MAE Loss: 0.104, R2: 0.676
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.698
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.696
# ***************************************************
#
# Epoch: 116
# Batch 100, MAE Loss: 0.101, R2: 0.690
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 117
# Batch 100, MAE Loss: 0.100, R2: 0.694
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.683
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 118
# Batch 100, MAE Loss: 0.101, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 119
# Batch 100, MAE Loss: 0.101, R2: 0.686
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 120
# Batch 100, MAE Loss: 0.099, R2: 0.702
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 121
# Batch 100, MAE Loss: 0.101, R2: 0.685
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 122
# Batch 100, MAE Loss: 0.102, R2: 0.679
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 123
# Batch 100, MAE Loss: 0.101, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.679
# ***************************************************
#
# Epoch: 124
# Batch 100, MAE Loss: 0.102, R2: 0.678
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 125
# Batch 100, MAE Loss: 0.102, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.676
# ***************************************************
#
# Epoch: 126
# Batch 100, MAE Loss: 0.101, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.698
# ***************************************************
#
# Epoch: 127
# Batch 100, MAE Loss: 0.099, R2: 0.692
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.692
# ***************************************************
#
# Epoch: 128
# Batch 100, MAE Loss: 0.100, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 129
# Batch 100, MAE Loss: 0.101, R2: 0.694
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.682
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 130
# Batch 100, MAE Loss: 0.100, R2: 0.691
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.691
# ***************************************************
#
# Epoch: 131
# Batch 100, MAE Loss: 0.100, R2: 0.694
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.684
# ***************************************************
#
# Epoch: 132
# Batch 100, MAE Loss: 0.101, R2: 0.686
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 133
# Batch 100, MAE Loss: 0.100, R2: 0.700
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.670
# ***************************************************
#
# Epoch: 134
# Batch 100, MAE Loss: 0.101, R2: 0.683
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 135
# Batch 100, MAE Loss: 0.101, R2: 0.698
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.680
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 136
# Batch 100, MAE Loss: 0.100, R2: 0.690
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.672
# ***************************************************
#
# Epoch: 137
# Batch 100, MAE Loss: 0.101, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 138
# Batch 100, MAE Loss: 0.100, R2: 0.692
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 139
# Batch 100, MAE Loss: 0.101, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.674
# ***************************************************
#
# Epoch: 140
# Batch 100, MAE Loss: 0.100, R2: 0.697
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.678
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.666
# ***************************************************
#
# Epoch: 141
# Batch 100, MAE Loss: 0.101, R2: 0.681
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.687
# ***************************************************
#
# Epoch: 142
# Batch 100, MAE Loss: 0.101, R2: 0.682
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.679
# ***************************************************
#
# Epoch: 143
# Batch 100, MAE Loss: 0.101, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.682
# ***************************************************
#
# Epoch: 144
# Batch 100, MAE Loss: 0.100, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 145
# Batch 100, MAE Loss: 0.101, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 146
# Batch 100, MAE Loss: 0.102, R2: 0.682
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.671
# ***************************************************
#
# Epoch: 147
# Batch 100, MAE Loss: 0.100, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 148
# Batch 100, MAE Loss: 0.101, R2: 0.698
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.684
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 149
# Batch 100, MAE Loss: 0.101, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.695
# ***************************************************
#
# Epoch: 150
# Batch 100, MAE Loss: 0.102, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 151
# Batch 100, MAE Loss: 0.100, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 152
# Batch 100, MAE Loss: 0.102, R2: 0.684
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.685
# ***************************************************
#
# Epoch: 153
# Batch 100, MAE Loss: 0.102, R2: 0.685
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 154
# Batch 100, MAE Loss: 0.100, R2: 0.688
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 155
# Batch 100, MAE Loss: 0.102, R2: 0.693
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 156
# Batch 100, MAE Loss: 0.101, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.682
# ***************************************************
#
# Epoch: 157
# Batch 100, MAE Loss: 0.100, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 158
# Batch 100, MAE Loss: 0.099, R2: 0.697
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.673
# ***************************************************
#
# Epoch: 159
# Batch 100, MAE Loss: 0.100, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.662
# ***************************************************
#
# Epoch: 160
# Batch 100, MAE Loss: 0.102, R2: 0.693
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 161
# Batch 100, MAE Loss: 0.101, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.692
# ***************************************************
#
# Epoch: 162
# Batch 100, MAE Loss: 0.101, R2: 0.686
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.672
# ***************************************************
#
# Epoch: 163
# Batch 100, MAE Loss: 0.100, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.688
# ***************************************************
#
# Epoch: 164
# Batch 100, MAE Loss: 0.102, R2: 0.687
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.679
# ***************************************************
#
# Epoch: 165
# Batch 100, MAE Loss: 0.101, R2: 0.693
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 166
# Batch 100, MAE Loss: 0.100, R2: 0.692
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 167
# Batch 100, MAE Loss: 0.100, R2: 0.684
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.682
# ***************************************************
#
# Epoch: 168
# Batch 100, MAE Loss: 0.101, R2: 0.690
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 169
# Batch 100, MAE Loss: 0.101, R2: 0.693
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 170
# Batch 100, MAE Loss: 0.100, R2: 0.684
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 171
# Batch 100, MAE Loss: 0.101, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.660
# ***************************************************
#
# Epoch: 172
# Batch 100, MAE Loss: 0.100, R2: 0.692
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.688
# ***************************************************
#
# Epoch: 173
# Batch 100, MAE Loss: 0.103, R2: 0.682
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.696
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.687
# ***************************************************
#
# Epoch: 174
# Batch 100, MAE Loss: 0.102, R2: 0.692
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.696
# ***************************************************
#
# Epoch: 175
# Batch 100, MAE Loss: 0.101, R2: 0.686
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.695
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.672
# ***************************************************
#
# Epoch: 176
# Batch 100, MAE Loss: 0.101, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.684
# ***************************************************
#
# Epoch: 177
# Batch 100, MAE Loss: 0.100, R2: 0.695
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.685
# ***************************************************
#
# Epoch: 178
# Batch 100, MAE Loss: 0.100, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.694
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 179
# Batch 100, MAE Loss: 0.101, R2: 0.688
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.697
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 180
# Batch 100, MAE Loss: 0.100, R2: 0.692
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 181
# Batch 100, MAE Loss: 0.101, R2: 0.680
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 182
# Batch 100, MAE Loss: 0.100, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.695
# ***************************************************
#
# Epoch: 183
# Batch 100, MAE Loss: 0.100, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.696
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.676
# ***************************************************
#
# Epoch: 184
# Batch 100, MAE Loss: 0.101, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.672
# ***************************************************
#
# Epoch: 185
# Batch 100, MAE Loss: 0.099, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 186
# Batch 100, MAE Loss: 0.102, R2: 0.680
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 187
# Batch 100, MAE Loss: 0.101, R2: 0.692
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.694
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.687
# ***************************************************
#
# Epoch: 188
# Batch 100, MAE Loss: 0.100, R2: 0.690
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.672
# ***************************************************
#
# Epoch: 189
# Batch 100, MAE Loss: 0.098, R2: 0.703
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.099
# Val R2 Score: 0.664
# ***************************************************
#
# Epoch: 190
# Batch 100, MAE Loss: 0.101, R2: 0.698
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.684
# ***************************************************
#
# Epoch: 191
# Batch 100, MAE Loss: 0.100, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.685
# ***************************************************
#
# Epoch: 192
# Batch 100, MAE Loss: 0.099, R2: 0.693
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 193
# Batch 100, MAE Loss: 0.102, R2: 0.692
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.675
# ***************************************************
#
# Epoch: 194
# Batch 100, MAE Loss: 0.099, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.684
# ***************************************************
#
# Epoch: 195
# Batch 100, MAE Loss: 0.101, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 196
# Batch 100, MAE Loss: 0.101, R2: 0.694
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.685
# ***************************************************
#
# Epoch: 197
# Batch 100, MAE Loss: 0.100, R2: 0.682
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.698
# ***************************************************
#
# Epoch: 198
# Batch 100, MAE Loss: 0.099, R2: 0.698
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 199
# Batch 100, MAE Loss: 0.099, R2: 0.688
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.697
# ***************************************************
#
# Epoch: 200
# Batch 100, MAE Loss: 0.100, R2: 0.690
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 201
# Batch 100, MAE Loss: 0.101, R2: 0.697
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.689
# ***************************************************
#
# Epoch: 202
# Batch 100, MAE Loss: 0.102, R2: 0.690
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.688
# ***************************************************
#
# Epoch: 203
# Batch 100, MAE Loss: 0.100, R2: 0.698
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.693
# ***************************************************
#
# Epoch: 204
# Batch 100, MAE Loss: 0.099, R2: 0.703
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.685
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.698
# ***************************************************
#
# Epoch: 205
# Batch 100, MAE Loss: 0.100, R2: 0.694
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.691
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.701
# ***************************************************
#
# Epoch: 206
# Batch 100, MAE Loss: 0.100, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.677
# ***************************************************
#
# Epoch: 207
# Batch 100, MAE Loss: 0.100, R2: 0.684
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.698
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.681
# ***************************************************
#
# Epoch: 208
# Batch 100, MAE Loss: 0.100, R2: 0.694
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.695
# ***************************************************
#
# Epoch: 209
# Batch 100, MAE Loss: 0.101, R2: 0.692
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.693
# ***************************************************
#
# Epoch: 210
# Batch 100, MAE Loss: 0.101, R2: 0.690
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.695
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.692
# ***************************************************
#
# Epoch: 211
# Batch 100, MAE Loss: 0.099, R2: 0.693
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.685
# ***************************************************
#
# Epoch: 212
# Batch 100, MAE Loss: 0.101, R2: 0.692
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.681
# ***************************************************
#
# Epoch: 213
# Batch 100, MAE Loss: 0.100, R2: 0.703
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.681
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.685
# ***************************************************
#
# Epoch: 214
# Batch 100, MAE Loss: 0.100, R2: 0.689
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.696
#
# Val MAE Loss: 0.098
# Val R2 Score: 0.659
# ***************************************************
#
# Epoch: 215
# Batch 100, MAE Loss: 0.099, R2: 0.693
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.689
#
# Val MAE Loss: 0.103
# Val R2 Score: 0.661
# ***************************************************
#
# Epoch: 216
# Batch 100, MAE Loss: 0.099, R2: 0.699
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.696
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.691
# ***************************************************
#
# Epoch: 217
# Batch 100, MAE Loss: 0.100, R2: 0.697
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.693
# ***************************************************
#
# Epoch: 218
# Batch 100, MAE Loss: 0.100, R2: 0.687
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.692
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 219
# Batch 100, MAE Loss: 0.101, R2: 0.700
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.688
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 220
# Batch 100, MAE Loss: 0.100, R2: 0.700
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.678
# ***************************************************
#
# Epoch: 221
# Batch 100, MAE Loss: 0.101, R2: 0.691
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.696
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.691
# ***************************************************
#
# Epoch: 222
# Batch 100, MAE Loss: 0.100, R2: 0.695
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.688
# ***************************************************
#
# Epoch: 223
# Batch 100, MAE Loss: 0.100, R2: 0.704
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.692
# ***************************************************
#
# Epoch: 224
# Batch 100, MAE Loss: 0.101, R2: 0.692
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.691
# ***************************************************
#
# Epoch: 225
# Batch 100, MAE Loss: 0.100, R2: 0.699
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.687
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.691
# ***************************************************
#
# Epoch: 226
# Batch 100, MAE Loss: 0.100, R2: 0.689
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.695
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.658
# ***************************************************
#
# Epoch: 227
# Batch 100, MAE Loss: 0.100, R2: 0.695
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.686
#
# Val MAE Loss: 0.096
# Val R2 Score: 0.688
# ***************************************************
#
# Epoch: 228
# Batch 100, MAE Loss: 0.100, R2: 0.700
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.694
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.691
# ***************************************************
#
# Epoch: 229
# Batch 100, MAE Loss: 0.099, R2: 0.697
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.693
# ***************************************************
#
# Epoch: 230
# Batch 100, MAE Loss: 0.100, R2: 0.698
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.695
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 231
# Batch 100, MAE Loss: 0.101, R2: 0.693
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.694
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.699
# ***************************************************
#
# Epoch: 232
# Batch 100, MAE Loss: 0.100, R2: 0.693
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.697
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 233
# Batch 100, MAE Loss: 0.101, R2: 0.700
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.690
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.682
# ***************************************************
#
# Epoch: 234
# Batch 100, MAE Loss: 0.100, R2: 0.687
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.700
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.693
# ***************************************************
#
# Epoch: 235
# Batch 100, MAE Loss: 0.099, R2: 0.698
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.694
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.688
# ***************************************************
#
# Epoch: 236
# Batch 100, MAE Loss: 0.101, R2: 0.693
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.697
# ***************************************************
#
# Epoch: 237
# Batch 100, MAE Loss: 0.099, R2: 0.697
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.697
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 238
# Batch 100, MAE Loss: 0.099, R2: 0.695
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.697
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.671
# ***************************************************
#
# Epoch: 239
# Batch 100, MAE Loss: 0.099, R2: 0.697
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.686
# ***************************************************
#
# Epoch: 240
# Batch 100, MAE Loss: 0.101, R2: 0.693
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.696
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.642
# ***************************************************
#
# Epoch: 241
# Batch 100, MAE Loss: 0.100, R2: 0.699
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.694
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 242
# Batch 100, MAE Loss: 0.098, R2: 0.702
# Epoch Train MAE Loss: 0.061, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 243
# Batch 100, MAE Loss: 0.101, R2: 0.697
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.697
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.685
# ***************************************************
#
# Epoch: 244
# Batch 100, MAE Loss: 0.101, R2: 0.689
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.699
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.683
# ***************************************************
#
# Epoch: 245
# Batch 100, MAE Loss: 0.099, R2: 0.699
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.694
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.703
# ***************************************************
#
# Epoch: 246
# Batch 100, MAE Loss: 0.099, R2: 0.699
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.693
#
# Val MAE Loss: 0.100
# Val R2 Score: 0.684
# ***************************************************
#
# Epoch: 247
# Batch 100, MAE Loss: 0.100, R2: 0.701
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.696
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.680
# ***************************************************
#
# Epoch: 248
# Batch 100, MAE Loss: 0.101, R2: 0.690
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.703
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.686
# ...
#
# Epoch: 534
# Batch 100, MAE Loss: 0.098, R2: 0.710
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.694
# ***************************************************
#
# Epoch: 535
# Batch 100, MAE Loss: 0.099, R2: 0.708
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.706
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.715
# ***************************************************
#
# Epoch: 536
# Batch 100, MAE Loss: 0.100, R2: 0.714
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.714
# ***************************************************
#
# Epoch: 537
# Batch 100, MAE Loss: 0.099, R2: 0.713
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.712
# ***************************************************
#
# Epoch: 538
# Batch 100, MAE Loss: 0.099, R2: 0.711
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.709
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.713
# ***************************************************
#
# Epoch: 539
# Batch 100, MAE Loss: 0.099, R2: 0.713
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.713
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.704
# ***************************************************
#
# Epoch: 540
# Batch 100, MAE Loss: 0.098, R2: 0.713
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.709
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.708
# ***************************************************
#
# Epoch: 541
# Batch 100, MAE Loss: 0.099, R2: 0.711
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.707
# ***************************************************
#
# Epoch: 542
# Batch 100, MAE Loss: 0.097, R2: 0.709
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.703
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.722
# ***************************************************
#
# Epoch: 543
# Batch 100, MAE Loss: 0.098, R2: 0.705
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.720
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.702
# ***************************************************
#
# Epoch: 544
# Batch 100, MAE Loss: 0.097, R2: 0.723
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.699
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.713
# ***************************************************
#
# Epoch: 545
# Batch 100, MAE Loss: 0.098, R2: 0.708
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.700
# ***************************************************
#
# Epoch: 546
# Batch 100, MAE Loss: 0.100, R2: 0.707
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.715
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.702
# ***************************************************
#
# Epoch: 547
# Batch 100, MAE Loss: 0.099, R2: 0.710
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.703
# ***************************************************
#
# Epoch: 548
# Batch 100, MAE Loss: 0.097, R2: 0.716
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.718
# ***************************************************
#
# Epoch: 549
# Batch 100, MAE Loss: 0.097, R2: 0.717
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.089
# Val R2 Score: 0.731
# ***************************************************
#
# Epoch: 550
# Batch 100, MAE Loss: 0.098, R2: 0.711
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.693
# ***************************************************
#
# Epoch: 551
# Batch 100, MAE Loss: 0.098, R2: 0.717
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.704
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.711
# ***************************************************
#
# Epoch: 552
# Batch 100, MAE Loss: 0.098, R2: 0.712
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.715
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.711
# ***************************************************
#
# Epoch: 553
# Batch 100, MAE Loss: 0.098, R2: 0.717
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.709
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.701
# ***************************************************
#
# Epoch: 554
# Batch 100, MAE Loss: 0.097, R2: 0.713
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.713
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 555
# Batch 100, MAE Loss: 0.099, R2: 0.708
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.726
# ***************************************************
#
# Epoch: 556
# Batch 100, MAE Loss: 0.099, R2: 0.711
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.713
#
# Val MAE Loss: 0.097
# Val R2 Score: 0.704
# ***************************************************
#
# Epoch: 557
# Batch 100, MAE Loss: 0.097, R2: 0.715
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.707
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.709
# ***************************************************
#
# Epoch: 558
# Batch 100, MAE Loss: 0.098, R2: 0.714
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.716
# ***************************************************
#
# Epoch: 559
# Batch 100, MAE Loss: 0.097, R2: 0.706
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.714
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.717
# ***************************************************
#
# Epoch: 560
# Batch 100, MAE Loss: 0.099, R2: 0.703
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.717
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.724
# ***************************************************
#
# Epoch: 561
# Batch 100, MAE Loss: 0.099, R2: 0.710
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.706
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.706
# ***************************************************
#
# Epoch: 562
# Batch 100, MAE Loss: 0.097, R2: 0.716
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.711
# ***************************************************
#
# Epoch: 563
# Batch 100, MAE Loss: 0.099, R2: 0.706
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.719
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.721
# ***************************************************
#
# Epoch: 564
# Batch 100, MAE Loss: 0.099, R2: 0.710
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.720
# ***************************************************
#
# Epoch: 565
# Batch 100, MAE Loss: 0.099, R2: 0.711
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.715
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.699
# ***************************************************
#
# Epoch: 566
# Batch 100, MAE Loss: 0.101, R2: 0.702
# Epoch Train MAE Loss: 0.057, Epoch Train R2: 0.719
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.721
# ***************************************************
#
# Epoch: 567
# Batch 100, MAE Loss: 0.098, R2: 0.711
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.706
#
# Val MAE Loss: 0.089
# Val R2 Score: 0.725
# ***************************************************
#
# Epoch: 568
# Batch 100, MAE Loss: 0.099, R2: 0.711
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.707
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.717
# ***************************************************
#
# Epoch: 569
# Batch 100, MAE Loss: 0.098, R2: 0.722
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.719
# ***************************************************
#
# Epoch: 570
# Batch 100, MAE Loss: 0.099, R2: 0.719
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.705
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.719
# ***************************************************
#
# Epoch: 571
# Batch 100, MAE Loss: 0.100, R2: 0.707
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.695
# ***************************************************
#
# Epoch: 572
# Batch 100, MAE Loss: 0.098, R2: 0.707
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.714
# ***************************************************
#
# Epoch: 573
# Batch 100, MAE Loss: 0.098, R2: 0.713
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.706
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.712
# ***************************************************
#
# Epoch: 574
# Batch 100, MAE Loss: 0.100, R2: 0.708
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.713
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.712
# ***************************************************
#
# Epoch: 575
# Batch 100, MAE Loss: 0.099, R2: 0.708
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.713
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.701
# ***************************************************
#
# Epoch: 576
# Batch 100, MAE Loss: 0.098, R2: 0.714
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.729
# ***************************************************
#
# Epoch: 577
# Batch 100, MAE Loss: 0.097, R2: 0.719
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.706
# ***************************************************
#
# Epoch: 578
# Batch 100, MAE Loss: 0.100, R2: 0.701
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.713
#
# Val MAE Loss: 0.088
# Val R2 Score: 0.720
# ***************************************************
#
# Epoch: 579
# Batch 100, MAE Loss: 0.099, R2: 0.715
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.697
# ***************************************************
#
# Epoch: 580
# Batch 100, MAE Loss: 0.098, R2: 0.706
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.717
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.714
# ***************************************************
#
# Epoch: 581
# Batch 100, MAE Loss: 0.099, R2: 0.710
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.714
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.717
# ***************************************************
#
# Epoch: 582
# Batch 100, MAE Loss: 0.098, R2: 0.708
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.708
# ***************************************************
#
# Epoch: 583
# Batch 100, MAE Loss: 0.097, R2: 0.713
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.720
# ***************************************************
#
# Epoch: 584
# Batch 100, MAE Loss: 0.099, R2: 0.713
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 585
# Batch 100, MAE Loss: 0.098, R2: 0.713
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.713
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.721
# ***************************************************
#
# Epoch: 586
# Batch 100, MAE Loss: 0.098, R2: 0.716
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.709
# ***************************************************
#
# Epoch: 587
# Batch 100, MAE Loss: 0.099, R2: 0.706
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.709
# ***************************************************
#
# Epoch: 588
# Batch 100, MAE Loss: 0.100, R2: 0.709
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.715
#
# Val MAE Loss: 0.089
# Val R2 Score: 0.715
# ***************************************************
#
# Epoch: 589
# Batch 100, MAE Loss: 0.097, R2: 0.706
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.715
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.716
# ***************************************************
#
# Epoch: 590
# Batch 100, MAE Loss: 0.099, R2: 0.720
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.706
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.702
# ***************************************************
#
# Epoch: 591
# Batch 100, MAE Loss: 0.098, R2: 0.712
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.709
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.707
# ***************************************************
#
# Epoch: 592
# Batch 100, MAE Loss: 0.098, R2: 0.719
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.700
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.704
# ***************************************************
#
# Epoch: 593
# Batch 100, MAE Loss: 0.098, R2: 0.710
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.722
# ***************************************************
#
# Epoch: 594
# Batch 100, MAE Loss: 0.098, R2: 0.716
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.719
# ***************************************************
#
# Epoch: 595
# Batch 100, MAE Loss: 0.100, R2: 0.704
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.719
# ***************************************************
#
# Epoch: 596
# Batch 100, MAE Loss: 0.097, R2: 0.717
# Epoch Train MAE Loss: 0.060, Epoch Train R2: 0.701
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.705
# ***************************************************
#
# Epoch: 597
# Batch 100, MAE Loss: 0.097, R2: 0.716
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.715
# ***************************************************
#
# Epoch: 598
# Batch 100, MAE Loss: 0.098, R2: 0.710
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.714
#
# Val MAE Loss: 0.090
# Val R2 Score: 0.723
# ***************************************************
#
# Epoch: 599
# Batch 100, MAE Loss: 0.098, R2: 0.708
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.702
# ***************************************************
#
# Epoch: 600
# Batch 100, MAE Loss: 0.100, R2: 0.709
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.719
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.690
# ***************************************************
#
# Epoch: 601
# Batch 100, MAE Loss: 0.098, R2: 0.715
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.714
# ***************************************************
#
# Epoch: 602
# Batch 100, MAE Loss: 0.097, R2: 0.719
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.709
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.711
# ***************************************************
#
# Epoch: 603
# Batch 100, MAE Loss: 0.099, R2: 0.711
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.697
# ***************************************************
#
# Epoch: 604
# Batch 100, MAE Loss: 0.099, R2: 0.713
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.725
# ***************************************************
#
# Epoch: 605
# Batch 100, MAE Loss: 0.097, R2: 0.714
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.708
# ***************************************************
#
# Epoch: 606
# Batch 100, MAE Loss: 0.100, R2: 0.702
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.723
#
# Val MAE Loss: 0.092
# Val R2 Score: 0.700
# ***************************************************
#
# Epoch: 607
# Batch 100, MAE Loss: 0.098, R2: 0.701
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.710
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.705
# ***************************************************
#
# Epoch: 608
# Batch 100, MAE Loss: 0.099, R2: 0.707
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.714
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.707
# ***************************************************
#
# Epoch: 609
# Batch 100, MAE Loss: 0.098, R2: 0.722
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.095
# Val R2 Score: 0.674
# ***************************************************
#
# Epoch: 610
# Batch 100, MAE Loss: 0.099, R2: 0.715
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.712
# ***************************************************
#
# Epoch: 611
# Batch 100, MAE Loss: 0.099, R2: 0.713
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.708
#
# Val MAE Loss: 0.094
# Val R2 Score: 0.718
# ***************************************************
#
# Epoch: 612
# Batch 100, MAE Loss: 0.099, R2: 0.700
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.719
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.720
# ***************************************************
#
# Epoch: 613
# Batch 100, MAE Loss: 0.098, R2: 0.712
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.711
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.718
# ***************************************************
#
# Epoch: 614
# Batch 100, MAE Loss: 0.098, R2: 0.707
# Epoch Train MAE Loss: 0.058, Epoch Train R2: 0.715
#
# Val MAE Loss: 0.091
# Val R2 Score: 0.710
# ***************************************************
#
# Epoch: 615
# Batch 100, MAE Loss: 0.099, R2: 0.707
# Epoch Train MAE Loss: 0.059, Epoch Train R2: 0.712
#
# Val MAE Loss: 0.093
# Val R2 Score: 0.710
# ***************************************************
#
# Epoch: 616
# Batch 100, MAE Loss: 0.098, R2: 0.715

# %%
# We can now plot and save the results

# plot the training and validation loss
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Loss value at every epoch')
plt.xlabel('Epoch (1-1000)')
plt.ylabel('Average MAE')

# save the plot to a local directory
dir_path = r'C:\Users\usuario\RecogniChess\HW4\Snapshots\LSTM\k=6\TEST3'
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
plt.savefig(os.path.join(dir_path, 'loss.png'))

# plot the training and validation R2 scores
plt.figure()
plt.plot(train_r2s, label='Training R2')
plt.plot(val_r2s, label='Validation R2')
plt.legend()
plt.title('R2 Score at every epoch')
plt.xlabel('Epoch (1-1000)')
plt.ylabel('Average Coefficient of determination (R2) value')

# save the plot to a local directory
plt.savefig(os.path.join(dir_path, 'r2.png'))

# %%
# Find highest training and validation R2 values
highest_train_r2 = max(train_r2s)
highest_val_r2 = max(val_r2s)

# Find lowest training and validation losses
lowest_train_loss = min(train_losses)
lowest_val_loss = min(val_losses)

# %%
# Set directory path and filename for output file
output_dir = "C:/Users/usuario/RecogniChess/HW4/Snapshots/LSTM/k=6/TEST3"
output_filename = "results.txt"

# Create output directory if it doesn't already exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Open output file for writing
with open(os.path.join(output_dir, output_filename), 'w') as f:
    
    # Write highest train R2 to file
    f.write("The highest train R2 was: " + str(highest_train_r2) + "\n")
    
    # Write highest val R2 to file
    f.write("The highest val R2 was: " + str(highest_val_r2) + "\n")
    
    # Write lowest train loss to file
    f.write("The lowest train loss was: " + str(lowest_train_loss) + "\n")
    
    # Write lowest val loss to file
    f.write("The lowest val loss was: " + str(lowest_val_loss) + "\n")
    
# Print confirmation message
print("Results saved to " + os.path.join(output_dir, output_filename))
